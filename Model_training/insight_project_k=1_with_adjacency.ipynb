# %%
import os
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
from PIL import Image
import matplotlib
from sklearn.model_selection import StratifiedKFold
import keras
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, TensorBoard
from keras import optimizers
from keras.models import Model
from keras.layers import Input, Dropout, UpSampling2D, BatchNormalization, Activation, Dense, Lambda, TimeDistributed, Flatten
from keras.layers import LSTM, GRU, RNN, Reshape, CuDNNGRU, CuDNNLSTM
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, MaxPooling3D
from keras.layers.merge import concatenate
from keras.models import Sequential
from keras.layers.convolutional import Conv3D
from keras.layers.convolutional_recurrent import ConvLSTM2D
from keras import backend as K
from keras.losses import binary_crossentropy
from keras.optimizers import Adam
from keras.optimizers import Adam
from keras.callbacks import Callback
import tensorflow as tf
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import confusion_matrix
import tensorflow as tf
import gc
import torch
from torch.utils.data import Dataset, DataLoader
from keras import layers, models, applications
from keras.layers import concatenate
from matplotlib import pyplot as plt
import tensorflow as tf
from torch.utils.data import Dataset, DataLoader
from keras import layers, models, applications
import albumentations
from albumentations import (
    HorizontalFlip, VerticalFlip, IAAPerspective, ShiftScaleRotate, CLAHE, RandomRotate90, ToFloat,
    Transpose, ShiftScaleRotate, Blur, OpticalDistortion, GridDistortion, HueSaturationValue,
    IAAAdditiveGaussianNoise, GaussNoise, MotionBlur, MedianBlur, IAAPiecewiseAffine, 
    IAASharpen, IAAEmboss, RandomContrast, RandomBrightness, Flip, OneOf, Compose, RandomGamma, ElasticTransform, ChannelShuffle,RGBShift, Rotate
)

from keras.backend.tensorflow_backend import set_session
from keras.backend.tensorflow_backend import clear_session
from keras.backend.tensorflow_backend import get_session
import tensorflow
# Reset Keras Session
def reset_keras():
    sess = get_session()
    clear_session()
    sess.close()
    sess = get_session()
    try:
        del classifier # this is from global space - change this as you need
    except:
        pass

    print(gc.collect()) # if it's done something you should see a number being outputted

    # use the same config as you used to create the session
    config = tensorflow.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 1
    config.gpu_options.visible_device_list = "0"
    set_session(tensorflow.Session(config=config))

def random_everything(seed=42):
  os.environ['PYTHONHASHSEED'] = str(42)
  random.seed(42)
  np.random.seed(42)
  tf.set_random_seed(42)

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

def f2_m(y_true, y_pred, beta=2):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return (1+beta**2) * (precision*recall) / ((beta**2)*(precision)+recall+K.epsilon())

'''
a = []
while(1):
  a.append('1')
'''
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# "\na = []\nwhile(1):\n  a.append('1')\n"

# %%
from google.colab import drive
#drive.mount('/content/gdrive')
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
def generate_sector(imgs, labs, idx=0):
  assert idx <= 24
  alphabets = "ABCDEFGHIJKLMNOPQRSTUVW"
  name = alphabets[idx]
  row_idx = idx//5
  col_idx = idx%5
  return imgs[:108, row_idx*200:(row_idx+1)*200, col_idx*200:(col_idx+1)*200, :], labs[:, row_idx*200:(row_idx+1)*200, col_idx*200:(col_idx+1)*200, :]

def calculate_burnt_ratio(labs):
  ratio = np.zeros((labs.shape[0],))
  for i in range(len(labs)):
    ratio[i] = labs[i,:,:,:].mean()
  return ratio

def generate_sectos_combined(imgs, labs, indices=np.arange(20)):
  combined_imgs, combined_labs = generate_sector(imgs, labs, indices[0])
  for idx in range(1, len(indices)):
    sector_imgs, sector_labs = generate_sector(imgs, labs, idx)
    combined_imgs = np.concatenate([combined_imgs, sector_imgs], 0)
    combined_labs = np.concatenate([combined_labs, sector_labs], 0)
  combined_area = calculate_burnt_ratio(combined_labs)
  return combined_imgs, combined_area

def binarize(y, thres=0.05):
  return (y>thres).astype(int)

def dissect_data(imgs, labs, size=108):
  idx = np.array([i for i in range(len(imgs)) if i%size not in [size-2, size-1, size]])
  imgs_0 = imgs[idx, :,:,:]
  imgs_1 = imgs[idx+1, :,:,:]
  imgs_2 = imgs[idx+2, :,:,:]
  labs   = binarize(labs[idx+2])
  return imgs_0, imgs_1, imgs_2, labs

# %%
water_mask = np.load('/content/gdrive/My Drive/water_mask_based_on_ndvi_565.npy')
water_mask = np.expand_dims(water_mask, 2)

# %%
I = 1
#I = 4
trn_idx = [i for i in range(25) if i not in range(5*I, 5*I+5)]
val_idx = [i for i in range(25) if i in range(5*I, 5*I+5)]

imgs = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['imgs']
dnbr = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['dnbr']
labs = (dnbr>0.66).astype(int)
del dnbr
gc.collect()
### apply water mask
for i in range(len(labs)):
  labs[i,:][water_mask==1] = 0

x_trn, y_trn = generate_sectos_combined(imgs, labs, indices=trn_idx)
del imgs, labs
gc.collect()
## normalize
x_trn = x_trn.astype('float32')
x_trn = x_trn / x_trn.max()

x_trn_0, x_trn_1, x_trn_2, y_trn = dissect_data(x_trn, y_trn)
del x_trn
gc.collect()
# Out:
# 0

# %%
imgs = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['imgs']
dnbr = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['dnbr']
labs = (dnbr>0.66).astype(int)
del dnbr
gc.collect()
### apply water mask
for i in range(len(labs)):
  labs[i,:][water_mask==1] = 0

x_val, y_val = generate_sectos_combined(imgs, labs, indices=val_idx)
del imgs, labs
gc.collect()
## normalize
x_val = x_val.astype('float32')
x_val = x_val / x_val.max()

x_val_0, x_val_1, x_val_2, y_val = dissect_data(x_val, y_val)
del x_val
gc.collect()

del water_mask
gc.collect()
# Out:
# 0

# %%
print(y_trn.mean())
print(y_val.mean())
# Out:
# 0.051415094339622644
# 0.07169811320754717

# %%
gsod = pd.read_csv('/content/gdrive/My Drive/flinders_chase_clean_5day.csv').values
gsod = np.array(gsod, dtype='float')
## normalize
gsod = gsod/gsod.max(axis=0)

num_trn_0, num_trn_1, num_trn_2 = gsod[:-2,:], gsod[1:-1,:], gsod[2:,:10]
num_val_0, num_val_1, num_val_2 = gsod[:-2,:], gsod[1:-1,:], gsod[2:,:10]
for i in range(len(trn_idx)-1):
  num_trn_0 = np.concatenate([num_trn_0, gsod[:-2,:]])
  num_trn_1 = np.concatenate([num_trn_1, gsod[1:-1,:]])
  ### the last series should only have day_0 data!
  num_trn_2 = np.concatenate([num_trn_2, gsod[2:,:10]])
for i in range(len(val_idx)-1):
  num_val_0 = np.concatenate([num_val_0, gsod[:-2,:]])
  num_val_1 = np.concatenate([num_val_1, gsod[1:-1,:]])
  ### the last series should only have day_0 data!
  num_val_2 = np.concatenate([num_val_2, gsod[2:,:10]])

# %%
trn_adjacency = pd.read_csv('/content/gdrive/My Drive/trn_adjacency.csv')
val_adjacency = pd.read_csv('/content/gdrive/My Drive/val_adjacency.csv')
sub_columns = [i for i in trn_adjacency.columns if i.startswith(f"f_{I}")]
trn_adjacency = trn_adjacency[sub_columns]
val_adjacency = val_adjacency[sub_columns]

## normalize
MAX = pd.concat([trn_adjacency, val_adjacency], 0).max()
trn_adjacency = trn_adjacency/MAX
val_adjacency = val_adjacency/MAX


s = 0
adj_trn_0 = trn_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 1
adj_trn_1 = trn_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 2
adj_trn_2 = trn_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]

s = 0
adj_val_0 = val_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 1
adj_val_1 = val_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 2
adj_val_2 = val_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]

# %%
def ConvBlock(inputs, suffix=0, prefix="cnn"):
    """no final linear dense layer!"""
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_1a")(inputs)
    conv1 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_1a")(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_1b")(conv1)
    conv1 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_1b")(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2), name=f"{prefix}_{suffix}_maxpool_1")(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_2a")(pool1)
    conv2 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_2a")(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_2b")(conv2)
    conv2 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_2b")(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2), name=f"index_{suffix}_maxpool_2")(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_3a")(pool2)
    conv3 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_3a")(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_3b")(conv3)
    conv3 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_3b")(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2), name=f"index_{suffix}_maxpool_3")(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_4a")(pool3)
    conv4 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_4a")(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_4b")(conv4)
    conv4 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_4b")(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2), name=f"{prefix}_{suffix}_maxpool_4")(conv4)    
    
    flatten= Flatten(name=f"{prefix}_{suffix}_flatten")(pool4)
    dense1 = Dense(64, activation="relu", name=f"{prefix}_{suffix}_relu_1")(flatten)
    drop1  = Dropout(0.4, name=f"{prefix}_{suffix}_drop_1")(dense1)
    dense2 = Dense(32, activation="relu", name=f"{prefix}_{suffix}_relu_2")(drop1)
    drop2  = Dropout(0.3, name=f"{prefix}_{suffix}_drop_2")(dense2)
    dense3 = Dense(16, activation="relu", name=f"{prefix}_{suffix}_relu_3")(drop2)
    drop3  = Dropout(0.2, name=f"{prefix}_{suffix}_drop_3")(dense3)
    dense4 = Dense(8, activation="relu",  name=f"{prefix}_{suffix}_relu_4")(drop3)
    #dense4 = Dense(1, activation="linear", name=f"{prefix}_{suffix}_linear")(drop3)
    return dense4

def MLP(inputs, suffix=0, prefix='mlp'):
    dense = Dense(8, activation='relu', name=f"{prefix}_{suffix}_relu_1")(inputs)
    dense = Dense(4, activation='relu', name=f"{prefix}_{suffix}_relu_2")(dense)
    #dense = Dense(1, activation='linear', name=f"{prefix}_{suffix}_linear")(dense)
    return dense

# %%
n_channels = 14
sector_dim = 200

img_0 = Input((sector_dim,sector_dim,n_channels), name="cnn_input_0")
img_1 = Input((sector_dim,sector_dim,n_channels), name="cnn_input_1")
img_2 = Input((sector_dim,sector_dim,n_channels), name="cnn_input_2")

num_0 = Input((50,), name="gsod_input_0")
num_1 = Input((50,), name="gsod_input_1")
num_2 = Input((10,), name="gsod_input_2")

adj_0 = Input((8,), name="adj_input_0")
adj_1 = Input((8,), name="adj_input_1")
adj_2 = Input((8,), name="adj_input_2")

cnn_0 = ConvBlock(img_0, suffix=0)
cnn_1 = ConvBlock(img_1, suffix=1)
cnn_2 = ConvBlock(img_2, suffix=2)

num_0_m = MLP(num_0, suffix=0, prefix="gsod")
num_1_m = MLP(num_1, suffix=1, prefix="gsod")
num_2_m = MLP(num_2, suffix=2, prefix="gsod")

adj_0_m = MLP(adj_0, suffix=0, prefix="adj")
adj_1_m = MLP(adj_1, suffix=1, prefix="adj")
adj_2_m = MLP(adj_2, suffix=2, prefix="adj")

mixed_0 = concatenate([cnn_0, num_0_m, adj_0_m], name='mixed_0')
mixed_1 = concatenate([cnn_1, num_1_m, adj_1_m], name='mixed_1')
mixed_2 = concatenate([cnn_2, num_2_m, adj_2_m], name='mixed_2')

concat   = concatenate([mixed_0, mixed_1, mixed_2], name="concat_mixed")
reshape    = Reshape((3, -1), name="reshape")(concat)
lstm       = CuDNNLSTM(256, name='lstm_1', return_sequences=True)(reshape)
lstm       = Dropout(0.4, name='lstm_drop_1')(lstm)
lstm       = CuDNNLSTM(256, name='lstm_2')(lstm)
lstm       = Dropout(0.4, name='lstm_drop_2')(lstm)
dense      = Dense(10, activation="relu", name="fc_relu")(lstm)
dense      = Dense(1, activation="sigmoid", name="fc_sigmoid")(dense)

model = Model(inputs=[img_0, img_1, img_2, num_0, num_1, num_2, adj_0, adj_1, adj_2], output=dense)
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# cnn_input_0 (InputLayer)        (None, 200, 200, 14) 0
# __________________________________________________________________________________________________
# cnn_input_1 (InputLayer)        (None, 200, 200, 14) 0
# __________________________________________________________________________________________________
# cnn_input_2 (InputLayer)        (None, 200, 200, 14) 0
# __________________________________________________________________________________________________
# cnn_0_conv_1a (Conv2D)          (None, 200, 200, 64) 8128        cnn_input_0[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_1a (Conv2D)          (None, 200, 200, 64) 8128        cnn_input_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_1a (Conv2D)          (None, 200, 200, 64) 8128        cnn_input_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_1a (BatchNormal (None, 200, 200, 64) 256         cnn_0_conv_1a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_1a (BatchNormal (None, 200, 200, 64) 256         cnn_1_conv_1a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_1a (BatchNormal (None, 200, 200, 64) 256         cnn_2_conv_1a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_1b (Conv2D)          (None, 200, 200, 64) 36928       cnn_0_batchnorm_1a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_1b (Conv2D)          (None, 200, 200, 64) 36928       cnn_1_batchnorm_1a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_1b (Conv2D)          (None, 200, 200, 64) 36928       cnn_2_batchnorm_1a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_1b (BatchNormal (None, 200, 200, 64) 256         cnn_0_conv_1b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_1b (BatchNormal (None, 200, 200, 64) 256         cnn_1_conv_1b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_1b (BatchNormal (None, 200, 200, 64) 256         cnn_2_conv_1b[0][0]
# __________________________________________________________________________________________________
# cnn_0_maxpool_1 (MaxPooling2D)  (None, 100, 100, 64) 0           cnn_0_batchnorm_1b[0][0]
# __________________________________________________________________________________________________
# cnn_1_maxpool_1 (MaxPooling2D)  (None, 100, 100, 64) 0           cnn_1_batchnorm_1b[0][0]
# __________________________________________________________________________________________________
# cnn_2_maxpool_1 (MaxPooling2D)  (None, 100, 100, 64) 0           cnn_2_batchnorm_1b[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_2a (Conv2D)          (None, 100, 100, 128 73856       cnn_0_maxpool_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_2a (Conv2D)          (None, 100, 100, 128 73856       cnn_1_maxpool_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_2a (Conv2D)          (None, 100, 100, 128 73856       cnn_2_maxpool_1[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_2a (BatchNormal (None, 100, 100, 128 512         cnn_0_conv_2a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_2a (BatchNormal (None, 100, 100, 128 512         cnn_1_conv_2a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_2a (BatchNormal (None, 100, 100, 128 512         cnn_2_conv_2a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_2b (Conv2D)          (None, 100, 100, 128 147584      cnn_0_batchnorm_2a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_2b (Conv2D)          (None, 100, 100, 128 147584      cnn_1_batchnorm_2a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_2b (Conv2D)          (None, 100, 100, 128 147584      cnn_2_batchnorm_2a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_2b (BatchNormal (None, 100, 100, 128 512         cnn_0_conv_2b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_2b (BatchNormal (None, 100, 100, 128 512         cnn_1_conv_2b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_2b (BatchNormal (None, 100, 100, 128 512         cnn_2_conv_2b[0][0]
# __________________________________________________________________________________________________
# index_0_maxpool_2 (MaxPooling2D (None, 50, 50, 128)  0           cnn_0_batchnorm_2b[0][0]
# __________________________________________________________________________________________________
# index_1_maxpool_2 (MaxPooling2D (None, 50, 50, 128)  0           cnn_1_batchnorm_2b[0][0]
# __________________________________________________________________________________________________
# index_2_maxpool_2 (MaxPooling2D (None, 50, 50, 128)  0           cnn_2_batchnorm_2b[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_3a (Conv2D)          (None, 50, 50, 256)  295168      index_0_maxpool_2[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_3a (Conv2D)          (None, 50, 50, 256)  295168      index_1_maxpool_2[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_3a (Conv2D)          (None, 50, 50, 256)  295168      index_2_maxpool_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_3a (BatchNormal (None, 50, 50, 256)  1024        cnn_0_conv_3a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_3a (BatchNormal (None, 50, 50, 256)  1024        cnn_1_conv_3a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_3a (BatchNormal (None, 50, 50, 256)  1024        cnn_2_conv_3a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_3b (Conv2D)          (None, 50, 50, 256)  590080      cnn_0_batchnorm_3a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_3b (Conv2D)          (None, 50, 50, 256)  590080      cnn_1_batchnorm_3a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_3b (Conv2D)          (None, 50, 50, 256)  590080      cnn_2_batchnorm_3a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_3b (BatchNormal (None, 50, 50, 256)  1024        cnn_0_conv_3b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_3b (BatchNormal (None, 50, 50, 256)  1024        cnn_1_conv_3b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_3b (BatchNormal (None, 50, 50, 256)  1024        cnn_2_conv_3b[0][0]
# __________________________________________________________________________________________________
# index_0_maxpool_3 (MaxPooling2D (None, 25, 25, 256)  0           cnn_0_batchnorm_3b[0][0]
# __________________________________________________________________________________________________
# index_1_maxpool_3 (MaxPooling2D (None, 25, 25, 256)  0           cnn_1_batchnorm_3b[0][0]
# __________________________________________________________________________________________________
# index_2_maxpool_3 (MaxPooling2D (None, 25, 25, 256)  0           cnn_2_batchnorm_3b[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_4a (Conv2D)          (None, 25, 25, 512)  1180160     index_0_maxpool_3[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_4a (Conv2D)          (None, 25, 25, 512)  1180160     index_1_maxpool_3[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_4a (Conv2D)          (None, 25, 25, 512)  1180160     index_2_maxpool_3[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_4a (BatchNormal (None, 25, 25, 512)  2048        cnn_0_conv_4a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_4a (BatchNormal (None, 25, 25, 512)  2048        cnn_1_conv_4a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_4a (BatchNormal (None, 25, 25, 512)  2048        cnn_2_conv_4a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_4b (Conv2D)          (None, 25, 25, 512)  2359808     cnn_0_batchnorm_4a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_4b (Conv2D)          (None, 25, 25, 512)  2359808     cnn_1_batchnorm_4a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_4b (Conv2D)          (None, 25, 25, 512)  2359808     cnn_2_batchnorm_4a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_4b (BatchNormal (None, 25, 25, 512)  2048        cnn_0_conv_4b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_4b (BatchNormal (None, 25, 25, 512)  2048        cnn_1_conv_4b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_4b (BatchNormal (None, 25, 25, 512)  2048        cnn_2_conv_4b[0][0]
# __________________________________________________________________________________________________
# cnn_0_maxpool_4 (MaxPooling2D)  (None, 12, 12, 512)  0           cnn_0_batchnorm_4b[0][0]
# __________________________________________________________________________________________________
# cnn_1_maxpool_4 (MaxPooling2D)  (None, 12, 12, 512)  0           cnn_1_batchnorm_4b[0][0]
# __________________________________________________________________________________________________
# cnn_2_maxpool_4 (MaxPooling2D)  (None, 12, 12, 512)  0           cnn_2_batchnorm_4b[0][0]
# __________________________________________________________________________________________________
# cnn_0_flatten (Flatten)         (None, 73728)        0           cnn_0_maxpool_4[0][0]
# __________________________________________________________________________________________________
# cnn_1_flatten (Flatten)         (None, 73728)        0           cnn_1_maxpool_4[0][0]
# __________________________________________________________________________________________________
# cnn_2_flatten (Flatten)         (None, 73728)        0           cnn_2_maxpool_4[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_1 (Dense)            (None, 64)           4718656     cnn_0_flatten[0][0]
# __________________________________________________________________________________________________
# cnn_1_relu_1 (Dense)            (None, 64)           4718656     cnn_1_flatten[0][0]
# __________________________________________________________________________________________________
# cnn_2_relu_1 (Dense)            (None, 64)           4718656     cnn_2_flatten[0][0]
# __________________________________________________________________________________________________
# cnn_0_drop_1 (Dropout)          (None, 64)           0           cnn_0_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_drop_1 (Dropout)          (None, 64)           0           cnn_1_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_drop_1 (Dropout)          (None, 64)           0           cnn_2_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_2 (Dense)            (None, 32)           2080        cnn_0_drop_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_relu_2 (Dense)            (None, 32)           2080        cnn_1_drop_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_relu_2 (Dense)            (None, 32)           2080        cnn_2_drop_1[0][0]
# __________________________________________________________________________________________________
# cnn_0_drop_2 (Dropout)          (None, 32)           0           cnn_0_relu_2[0][0]
# __________________________________________________________________________________________________
# cnn_1_drop_2 (Dropout)          (None, 32)           0           cnn_1_relu_2[0][0]
# __________________________________________________________________________________________________
# cnn_2_drop_2 (Dropout)          (None, 32)           0           cnn_2_relu_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_3 (Dense)            (None, 16)           528         cnn_0_drop_2[0][0]
# __________________________________________________________________________________________________
# gsod_input_0 (InputLayer)       (None, 50)           0
# __________________________________________________________________________________________________
# adj_input_0 (InputLayer)        (None, 8)            0
# __________________________________________________________________________________________________
# cnn_1_relu_3 (Dense)            (None, 16)           528         cnn_1_drop_2[0][0]
# __________________________________________________________________________________________________
# gsod_input_1 (InputLayer)       (None, 50)           0
# __________________________________________________________________________________________________
# adj_input_1 (InputLayer)        (None, 8)            0
# __________________________________________________________________________________________________
# cnn_2_relu_3 (Dense)            (None, 16)           528         cnn_2_drop_2[0][0]
# __________________________________________________________________________________________________
# gsod_input_2 (InputLayer)       (None, 10)           0
# __________________________________________________________________________________________________
# adj_input_2 (InputLayer)        (None, 8)            0
# __________________________________________________________________________________________________
# cnn_0_drop_3 (Dropout)          (None, 16)           0           cnn_0_relu_3[0][0]
# __________________________________________________________________________________________________
# gsod_0_relu_1 (Dense)           (None, 8)            408         gsod_input_0[0][0]
# __________________________________________________________________________________________________
# adj_0_relu_1 (Dense)            (None, 8)            72          adj_input_0[0][0]
# __________________________________________________________________________________________________
# cnn_1_drop_3 (Dropout)          (None, 16)           0           cnn_1_relu_3[0][0]
# __________________________________________________________________________________________________
# gsod_1_relu_1 (Dense)           (None, 8)            408         gsod_input_1[0][0]
# __________________________________________________________________________________________________
# adj_1_relu_1 (Dense)            (None, 8)            72          adj_input_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_drop_3 (Dropout)          (None, 16)           0           cnn_2_relu_3[0][0]
# __________________________________________________________________________________________________
# gsod_2_relu_1 (Dense)           (None, 8)            88          gsod_input_2[0][0]
# __________________________________________________________________________________________________
# adj_2_relu_1 (Dense)            (None, 8)            72          adj_input_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_4 (Dense)            (None, 8)            136         cnn_0_drop_3[0][0]
# __________________________________________________________________________________________________
# gsod_0_relu_2 (Dense)           (None, 4)            36          gsod_0_relu_1[0][0]
# __________________________________________________________________________________________________
# adj_0_relu_2 (Dense)            (None, 4)            36          adj_0_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_relu_4 (Dense)            (None, 8)            136         cnn_1_drop_3[0][0]
# __________________________________________________________________________________________________
# gsod_1_relu_2 (Dense)           (None, 4)            36          gsod_1_relu_1[0][0]
# __________________________________________________________________________________________________
# adj_1_relu_2 (Dense)            (None, 4)            36          adj_1_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_relu_4 (Dense)            (None, 8)            136         cnn_2_drop_3[0][0]
# __________________________________________________________________________________________________
# gsod_2_relu_2 (Dense)           (None, 4)            36          gsod_2_relu_1[0][0]
# __________________________________________________________________________________________________
# adj_2_relu_2 (Dense)            (None, 4)            36          adj_2_relu_1[0][0]
# __________________________________________________________________________________________________
# mixed_0 (Concatenate)           (None, 16)           0           cnn_0_relu_4[0][0]
#                                                                  gsod_0_relu_2[0][0]
#                                                                  adj_0_relu_2[0][0]
# __________________________________________________________________________________________________
# mixed_1 (Concatenate)           (None, 16)           0           cnn_1_relu_4[0][0]
#                                                                  gsod_1_relu_2[0][0]
#                                                                  adj_1_relu_2[0][0]
# __________________________________________________________________________________________________
# mixed_2 (Concatenate)           (None, 16)           0           cnn_2_relu_4[0][0]
#                                                                  gsod_2_relu_2[0][0]
#                                                                  adj_2_relu_2[0][0]
# __________________________________________________________________________________________________
# concat_mixed (Concatenate)      (None, 48)           0           mixed_0[0][0]
#                                                                  mixed_1[0][0]
#                                                                  mixed_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 3, 16)        0           concat_mixed[0][0]
# __________________________________________________________________________________________________
# lstm_1 (CuDNNLSTM)              (None, 3, 256)       280576      reshape[0][0]
# __________________________________________________________________________________________________
# lstm_drop_1 (Dropout)           (None, 3, 256)       0           lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (CuDNNLSTM)              (None, 256)          526336      lstm_drop_1[0][0]
# __________________________________________________________________________________________________
# lstm_drop_2 (Dropout)           (None, 256)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# fc_relu (Dense)                 (None, 10)           2570        lstm_drop_2[0][0]
# __________________________________________________________________________________________________
# fc_sigmoid (Dense)              (None, 1)            11          fc_relu[0][0]
# ==================================================================================================
# Total params: 29,073,205
# Trainable params: 29,061,685
# Non-trainable params: 11,520
# __________________________________________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("fc...)`

# %%
def custom_loss(y_true, y_pred):
  crossentropy_loss = K.binary_crossentropy(y_true, y_pred)
  weight  = (y_true*9)+1
  return crossentropy_loss*(weight)

# %%
random_everything(seed=42)
#model = Model(inputs=[img_0, img_1, img_2, num_0, num_1, num_2, adj_0, adj_1, adj_2], output=dense)

model.compile(optimizer = Adam(lr=1e-4, decay=1e-6), 
              loss=custom_loss,
              metrics=['acc', recall_m, precision_m, f1_m, f2_m])

ckpt = ModelCheckpoint(f"/content/gdrive/My Drive/CNN_LSTM_{I}_adj_watermask_5day.hdf5", monitor = "val_loss", save_best_only = True, mode = "min", save_weights_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

history = model.fit([x_trn_0, x_trn_1, x_trn_2, num_trn_0, num_trn_1, num_trn_2, adj_trn_0, adj_trn_1, adj_trn_2], y_trn,
                        validation_data=([x_val_0, x_val_1, x_val_2, num_val_0, num_val_1, num_val_2, adj_val_0, adj_val_1, adj_val_2], y_val),
                        batch_size=24, epochs=300,
                        callbacks=[es, ckpt, 
                                   keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7)
                                   ]
                        )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 2120 samples, validate on 530 samples
# Epoch 1/300
# 2120/2120 [==============================] - 74s 35ms/step - loss: 0.9673 - acc: 0.8741 - recall_m: 0.0513 - precision_m: 0.0134 - f1_m: 0.0188 - f2_m: 0.0282 - val_loss: 1.1373 - val_acc: 0.9283 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_f1_m: 0.0000e+00 - val_f2_m: 0.0000e+00
# Epoch 2/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.9160 - acc: 0.9491 - recall_m: 0.0057 - precision_m: 0.0113 - f1_m: 0.0075 - f2_m: 0.0063 - val_loss: 1.1148 - val_acc: 0.9283 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_f1_m: 0.0000e+00 - val_f2_m: 0.0000e+00
# Epoch 3/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8657 - acc: 0.9382 - recall_m: 0.0849 - precision_m: 0.0858 - f1_m: 0.0806 - f2_m: 0.0821 - val_loss: 0.9664 - val_acc: 0.9151 - val_recall_m: 0.0377 - val_precision_m: 0.0340 - val_f1_m: 0.0332 - val_f2_m: 0.0350
# Epoch 4/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8068 - acc: 0.8783 - recall_m: 0.3019 - precision_m: 0.1884 - f1_m: 0.2094 - f2_m: 0.2466 - val_loss: 0.9024 - val_acc: 0.9000 - val_recall_m: 0.2938 - val_precision_m: 0.2681 - val_f1_m: 0.2620 - val_f2_m: 0.2741
# Epoch 5/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7529 - acc: 0.8755 - recall_m: 0.3123 - precision_m: 0.1949 - f1_m: 0.2104 - f2_m: 0.2488 - val_loss: 0.8027 - val_acc: 0.8906 - val_recall_m: 0.3089 - val_precision_m: 0.3265 - val_f1_m: 0.2839 - val_f2_m: 0.2901
# Epoch 6/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7210 - acc: 0.8750 - recall_m: 0.4283 - precision_m: 0.2628 - f1_m: 0.2894 - f2_m: 0.3446 - val_loss: 1.0034 - val_acc: 0.5717 - val_recall_m: 0.5315 - val_precision_m: 0.1145 - val_f1_m: 0.1781 - val_f2_m: 0.2836
# Epoch 7/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7940 - acc: 0.8113 - recall_m: 0.3547 - precision_m: 0.1605 - f1_m: 0.2008 - f2_m: 0.2568 - val_loss: 0.8600 - val_acc: 0.8226 - val_recall_m: 0.3941 - val_precision_m: 0.1581 - val_f1_m: 0.2112 - val_f2_m: 0.2808
# Epoch 8/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7644 - acc: 0.8330 - recall_m: 0.4181 - precision_m: 0.1888 - f1_m: 0.2416 - f2_m: 0.3116 - val_loss: 0.7647 - val_acc: 0.8698 - val_recall_m: 0.3984 - val_precision_m: 0.2228 - val_f1_m: 0.2677 - val_f2_m: 0.3224
# Epoch 9/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6827 - acc: 0.8472 - recall_m: 0.4302 - precision_m: 0.1997 - f1_m: 0.2550 - f2_m: 0.3258 - val_loss: 0.7029 - val_acc: 0.8604 - val_recall_m: 0.4728 - val_precision_m: 0.2292 - val_f1_m: 0.2948 - val_f2_m: 0.3723
# Epoch 10/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7006 - acc: 0.8415 - recall_m: 0.3830 - precision_m: 0.1832 - f1_m: 0.2330 - f2_m: 0.2948 - val_loss: 0.9320 - val_acc: 0.8660 - val_recall_m: 0.3892 - val_precision_m: 0.2403 - val_f1_m: 0.2590 - val_f2_m: 0.3093
# Epoch 11/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6671 - acc: 0.8392 - recall_m: 0.5387 - precision_m: 0.2199 - f1_m: 0.2923 - f2_m: 0.3876 - val_loss: 0.9529 - val_acc: 0.8755 - val_recall_m: 0.3353 - val_precision_m: 0.2311 - val_f1_m: 0.2466 - val_f2_m: 0.2816
# Epoch 12/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6804 - acc: 0.8604 - recall_m: 0.4925 - precision_m: 0.2293 - f1_m: 0.2913 - f2_m: 0.3708 - val_loss: 0.8951 - val_acc: 0.9094 - val_recall_m: 0.2647 - val_precision_m: 0.2065 - val_f1_m: 0.2070 - val_f2_m: 0.2284
# Epoch 13/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7157 - acc: 0.8571 - recall_m: 0.4857 - precision_m: 0.2454 - f1_m: 0.2945 - f2_m: 0.3687 - val_loss: 0.9507 - val_acc: 0.9264 - val_recall_m: 0.3186 - val_precision_m: 0.2483 - val_f1_m: 0.2564 - val_f2_m: 0.2830
# Epoch 14/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6020 - acc: 0.8807 - recall_m: 0.5264 - precision_m: 0.2632 - f1_m: 0.3246 - f2_m: 0.4068 - val_loss: 0.7030 - val_acc: 0.9132 - val_recall_m: 0.4636 - val_precision_m: 0.3458 - val_f1_m: 0.3655 - val_f2_m: 0.4052
# Epoch 15/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5602 - acc: 0.8637 - recall_m: 0.5396 - precision_m: 0.2588 - f1_m: 0.3270 - f2_m: 0.4128 - val_loss: 0.6235 - val_acc: 0.9170 - val_recall_m: 0.4296 - val_precision_m: 0.3577 - val_f1_m: 0.3538 - val_f2_m: 0.3806
# Epoch 16/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5612 - acc: 0.8816 - recall_m: 0.5132 - precision_m: 0.2805 - f1_m: 0.3377 - f2_m: 0.4117 - val_loss: 0.6964 - val_acc: 0.8660 - val_recall_m: 0.4927 - val_precision_m: 0.2310 - val_f1_m: 0.2897 - val_f2_m: 0.3736
# Epoch 17/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5030 - acc: 0.9019 - recall_m: 0.5670 - precision_m: 0.3223 - f1_m: 0.3914 - f2_m: 0.4699 - val_loss: 0.5531 - val_acc: 0.9189 - val_recall_m: 0.5315 - val_precision_m: 0.3563 - val_f1_m: 0.4053 - val_f2_m: 0.4619
# Epoch 18/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4953 - acc: 0.8873 - recall_m: 0.6340 - precision_m: 0.2841 - f1_m: 0.3732 - f2_m: 0.4819 - val_loss: 0.6356 - val_acc: 0.8547 - val_recall_m: 0.4927 - val_precision_m: 0.2099 - val_f1_m: 0.2814 - val_f2_m: 0.3680
# Epoch 19/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5163 - acc: 0.8844 - recall_m: 0.5700 - precision_m: 0.2962 - f1_m: 0.3571 - f2_m: 0.4420 - val_loss: 0.5932 - val_acc: 0.9094 - val_recall_m: 0.4410 - val_precision_m: 0.3061 - val_f1_m: 0.3354 - val_f2_m: 0.3826
# Epoch 20/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5079 - acc: 0.8934 - recall_m: 0.4809 - precision_m: 0.2962 - f1_m: 0.3394 - f2_m: 0.3970 - val_loss: 0.7254 - val_acc: 0.8642 - val_recall_m: 0.4070 - val_precision_m: 0.3420 - val_f1_m: 0.3285 - val_f2_m: 0.3589
# Epoch 21/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4849 - acc: 0.8939 - recall_m: 0.5736 - precision_m: 0.3091 - f1_m: 0.3763 - f2_m: 0.4595 - val_loss: 0.5620 - val_acc: 0.8811 - val_recall_m: 0.5342 - val_precision_m: 0.2978 - val_f1_m: 0.3625 - val_f2_m: 0.4379
# Epoch 22/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4694 - acc: 0.8976 - recall_m: 0.5604 - precision_m: 0.3164 - f1_m: 0.3792 - f2_m: 0.4560 - val_loss: 0.4661 - val_acc: 0.8774 - val_recall_m: 0.5860 - val_precision_m: 0.2984 - val_f1_m: 0.3753 - val_f2_m: 0.4667
# Epoch 23/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4426 - acc: 0.9033 - recall_m: 0.6406 - precision_m: 0.3273 - f1_m: 0.4077 - f2_m: 0.5075 - val_loss: 0.3947 - val_acc: 0.8868 - val_recall_m: 0.5774 - val_precision_m: 0.2696 - val_f1_m: 0.3545 - val_f2_m: 0.4529
# Epoch 24/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4368 - acc: 0.9071 - recall_m: 0.5802 - precision_m: 0.3534 - f1_m: 0.4078 - f2_m: 0.4829 - val_loss: 0.5312 - val_acc: 0.9019 - val_recall_m: 0.4588 - val_precision_m: 0.2548 - val_f1_m: 0.3161 - val_f2_m: 0.3821
# Epoch 25/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5253 - acc: 0.8976 - recall_m: 0.5834 - precision_m: 0.3193 - f1_m: 0.3844 - f2_m: 0.4670 - val_loss: 0.4743 - val_acc: 0.8660 - val_recall_m: 0.5493 - val_precision_m: 0.2597 - val_f1_m: 0.3426 - val_f2_m: 0.4357
# Epoch 26/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3517 - acc: 0.9292 - recall_m: 0.6472 - precision_m: 0.4247 - f1_m: 0.4869 - f2_m: 0.5595 - val_loss: 0.4502 - val_acc: 0.8679 - val_recall_m: 0.6011 - val_precision_m: 0.2711 - val_f1_m: 0.3631 - val_f2_m: 0.4688
# Epoch 27/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4681 - acc: 0.9090 - recall_m: 0.6255 - precision_m: 0.3628 - f1_m: 0.4280 - f2_m: 0.5137 - val_loss: 0.5454 - val_acc: 0.8679 - val_recall_m: 0.5644 - val_precision_m: 0.2543 - val_f1_m: 0.3416 - val_f2_m: 0.4411
# Epoch 28/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3801 - acc: 0.9212 - recall_m: 0.6755 - precision_m: 0.4051 - f1_m: 0.4807 - f2_m: 0.5679 - val_loss: 0.4965 - val_acc: 0.8868 - val_recall_m: 0.5795 - val_precision_m: 0.2550 - val_f1_m: 0.3463 - val_f2_m: 0.4511
# Epoch 29/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3786 - acc: 0.9292 - recall_m: 0.5519 - precision_m: 0.3591 - f1_m: 0.4152 - f2_m: 0.4781 - val_loss: 0.4134 - val_acc: 0.8774 - val_recall_m: 0.5795 - val_precision_m: 0.2528 - val_f1_m: 0.3442 - val_f2_m: 0.4497
# Epoch 30/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3632 - acc: 0.9170 - recall_m: 0.6906 - precision_m: 0.3770 - f1_m: 0.4633 - f2_m: 0.5637 - val_loss: 0.3808 - val_acc: 0.9283 - val_recall_m: 0.5580 - val_precision_m: 0.3542 - val_f1_m: 0.4206 - val_f2_m: 0.4863
# Epoch 31/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3486 - acc: 0.9363 - recall_m: 0.6200 - precision_m: 0.4430 - f1_m: 0.4914 - f2_m: 0.5504 - val_loss: 0.4036 - val_acc: 0.8943 - val_recall_m: 0.5709 - val_precision_m: 0.2899 - val_f1_m: 0.3719 - val_f2_m: 0.4621
# Epoch 32/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2944 - acc: 0.9340 - recall_m: 0.6962 - precision_m: 0.4306 - f1_m: 0.5048 - f2_m: 0.5911 - val_loss: 0.3392 - val_acc: 0.9189 - val_recall_m: 0.5774 - val_precision_m: 0.2986 - val_f1_m: 0.3807 - val_f2_m: 0.4708
# Epoch 33/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3402 - acc: 0.9302 - recall_m: 0.6057 - precision_m: 0.3764 - f1_m: 0.4373 - f2_m: 0.5127 - val_loss: 0.3277 - val_acc: 0.9302 - val_recall_m: 0.5925 - val_precision_m: 0.3633 - val_f1_m: 0.4343 - val_f2_m: 0.5084
# Epoch 34/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3508 - acc: 0.9250 - recall_m: 0.6594 - precision_m: 0.3999 - f1_m: 0.4750 - f2_m: 0.5597 - val_loss: 0.4397 - val_acc: 0.8792 - val_recall_m: 0.5984 - val_precision_m: 0.3461 - val_f1_m: 0.4164 - val_f2_m: 0.4951
# Epoch 35/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3350 - acc: 0.9217 - recall_m: 0.6462 - precision_m: 0.3747 - f1_m: 0.4455 - f2_m: 0.5322 - val_loss: 0.3012 - val_acc: 0.9264 - val_recall_m: 0.5596 - val_precision_m: 0.3631 - val_f1_m: 0.4221 - val_f2_m: 0.4851
# Epoch 36/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3363 - acc: 0.9344 - recall_m: 0.5858 - precision_m: 0.4123 - f1_m: 0.4559 - f2_m: 0.5139 - val_loss: 0.3271 - val_acc: 0.8906 - val_recall_m: 0.6226 - val_precision_m: 0.3093 - val_f1_m: 0.4036 - val_f2_m: 0.5046
# Epoch 37/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3114 - acc: 0.9325 - recall_m: 0.7349 - precision_m: 0.4288 - f1_m: 0.5151 - f2_m: 0.6149 - val_loss: 0.2549 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4304 - val_f1_m: 0.4933 - val_f2_m: 0.5548
# Epoch 38/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3111 - acc: 0.9269 - recall_m: 0.5906 - precision_m: 0.3660 - f1_m: 0.4313 - f2_m: 0.5037 - val_loss: 0.3166 - val_acc: 0.8906 - val_recall_m: 0.6377 - val_precision_m: 0.3087 - val_f1_m: 0.4109 - val_f2_m: 0.5184
# Epoch 39/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2929 - acc: 0.9325 - recall_m: 0.6783 - precision_m: 0.4158 - f1_m: 0.4921 - f2_m: 0.5771 - val_loss: 0.3167 - val_acc: 0.9019 - val_recall_m: 0.5925 - val_precision_m: 0.2967 - val_f1_m: 0.3873 - val_f2_m: 0.4831
# Epoch 40/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3070 - acc: 0.9344 - recall_m: 0.7066 - precision_m: 0.4530 - f1_m: 0.5166 - f2_m: 0.6003 - val_loss: 0.2736 - val_acc: 0.9170 - val_recall_m: 0.6377 - val_precision_m: 0.3859 - val_f1_m: 0.4635 - val_f2_m: 0.5453
# Epoch 41/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2699 - acc: 0.9288 - recall_m: 0.6549 - precision_m: 0.3877 - f1_m: 0.4640 - f2_m: 0.5504 - val_loss: 0.3090 - val_acc: 0.9377 - val_recall_m: 0.5833 - val_precision_m: 0.4382 - val_f1_m: 0.4808 - val_f2_m: 0.5284
# Epoch 42/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2675 - acc: 0.9472 - recall_m: 0.6811 - precision_m: 0.4806 - f1_m: 0.5400 - f2_m: 0.6064 - val_loss: 0.2613 - val_acc: 0.9151 - val_recall_m: 0.6377 - val_precision_m: 0.3514 - val_f1_m: 0.4421 - val_f2_m: 0.5353
# Epoch 43/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2758 - acc: 0.9297 - recall_m: 0.7160 - precision_m: 0.4289 - f1_m: 0.5117 - f2_m: 0.6044 - val_loss: 0.4907 - val_acc: 0.8925 - val_recall_m: 0.5795 - val_precision_m: 0.2957 - val_f1_m: 0.3804 - val_f2_m: 0.4725
# Epoch 44/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2495 - acc: 0.9410 - recall_m: 0.6836 - precision_m: 0.4328 - f1_m: 0.5117 - f2_m: 0.5938 - val_loss: 0.2734 - val_acc: 0.9264 - val_recall_m: 0.6226 - val_precision_m: 0.3965 - val_f1_m: 0.4704 - val_f2_m: 0.5440
# Epoch 45/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2712 - acc: 0.9363 - recall_m: 0.6962 - precision_m: 0.4448 - f1_m: 0.5180 - f2_m: 0.5997 - val_loss: 0.2456 - val_acc: 0.9245 - val_recall_m: 0.6377 - val_precision_m: 0.3882 - val_f1_m: 0.4629 - val_f2_m: 0.5427
# Epoch 46/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2669 - acc: 0.9467 - recall_m: 0.5830 - precision_m: 0.3868 - f1_m: 0.4470 - f2_m: 0.5118 - val_loss: 0.2438 - val_acc: 0.9340 - val_recall_m: 0.6226 - val_precision_m: 0.4209 - val_f1_m: 0.4834 - val_f2_m: 0.5483
# Epoch 47/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2722 - acc: 0.9434 - recall_m: 0.6917 - precision_m: 0.4251 - f1_m: 0.4999 - f2_m: 0.5871 - val_loss: 0.4310 - val_acc: 0.9283 - val_recall_m: 0.5795 - val_precision_m: 0.3487 - val_f1_m: 0.4220 - val_f2_m: 0.4963
# Epoch 48/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2649 - acc: 0.9387 - recall_m: 0.5811 - precision_m: 0.4079 - f1_m: 0.4593 - f2_m: 0.5158 - val_loss: 0.2692 - val_acc: 0.9189 - val_recall_m: 0.6377 - val_precision_m: 0.3465 - val_f1_m: 0.4329 - val_f2_m: 0.5274
# Epoch 49/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2716 - acc: 0.9406 - recall_m: 0.6783 - precision_m: 0.4413 - f1_m: 0.5110 - f2_m: 0.5887 - val_loss: 0.2328 - val_acc: 0.9377 - val_recall_m: 0.6377 - val_precision_m: 0.4130 - val_f1_m: 0.4846 - val_f2_m: 0.5580
# Epoch 50/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2424 - acc: 0.9481 - recall_m: 0.6538 - precision_m: 0.4558 - f1_m: 0.5088 - f2_m: 0.5740 - val_loss: 0.2479 - val_acc: 0.9377 - val_recall_m: 0.6226 - val_precision_m: 0.4321 - val_f1_m: 0.4965 - val_f2_m: 0.5584
# Epoch 51/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2282 - acc: 0.9533 - recall_m: 0.6660 - precision_m: 0.4840 - f1_m: 0.5385 - f2_m: 0.5984 - val_loss: 0.2332 - val_acc: 0.9528 - val_recall_m: 0.5774 - val_precision_m: 0.4067 - val_f1_m: 0.4665 - val_f2_m: 0.5218
# Epoch 52/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2452 - acc: 0.9467 - recall_m: 0.6975 - precision_m: 0.4847 - f1_m: 0.5448 - f2_m: 0.6161 - val_loss: 0.2310 - val_acc: 0.9509 - val_recall_m: 0.6226 - val_precision_m: 0.4547 - val_f1_m: 0.5116 - val_f2_m: 0.5655
# Epoch 53/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2468 - acc: 0.9410 - recall_m: 0.6785 - precision_m: 0.4342 - f1_m: 0.5006 - f2_m: 0.5804 - val_loss: 0.2606 - val_acc: 0.9415 - val_recall_m: 0.6226 - val_precision_m: 0.4405 - val_f1_m: 0.5006 - val_f2_m: 0.5598
# Epoch 54/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2491 - acc: 0.9396 - recall_m: 0.6615 - precision_m: 0.4415 - f1_m: 0.5000 - f2_m: 0.5710 - val_loss: 0.2570 - val_acc: 0.9472 - val_recall_m: 0.6162 - val_precision_m: 0.4509 - val_f1_m: 0.5072 - val_f2_m: 0.5606
# Epoch 55/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2808 - acc: 0.9425 - recall_m: 0.6547 - precision_m: 0.4642 - f1_m: 0.5211 - f2_m: 0.5838 - val_loss: 0.2146 - val_acc: 0.9415 - val_recall_m: 0.6226 - val_precision_m: 0.4600 - val_f1_m: 0.5133 - val_f2_m: 0.5654
# Epoch 56/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2559 - acc: 0.9500 - recall_m: 0.7519 - precision_m: 0.5270 - f1_m: 0.5857 - f2_m: 0.6598 - val_loss: 0.2343 - val_acc: 0.9415 - val_recall_m: 0.6226 - val_precision_m: 0.4320 - val_f1_m: 0.4970 - val_f2_m: 0.5585
# Epoch 57/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2559 - acc: 0.9415 - recall_m: 0.6953 - precision_m: 0.4708 - f1_m: 0.5327 - f2_m: 0.6057 - val_loss: 0.2209 - val_acc: 0.9434 - val_recall_m: 0.6377 - val_precision_m: 0.4393 - val_f1_m: 0.5053 - val_f2_m: 0.5694
# Epoch 58/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2662 - acc: 0.9420 - recall_m: 0.6462 - precision_m: 0.4370 - f1_m: 0.4944 - f2_m: 0.5644 - val_loss: 0.2963 - val_acc: 0.9094 - val_recall_m: 0.6377 - val_precision_m: 0.3593 - val_f1_m: 0.4480 - val_f2_m: 0.5382
# Epoch 59/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2361 - acc: 0.9392 - recall_m: 0.6355 - precision_m: 0.4315 - f1_m: 0.4909 - f2_m: 0.5579 - val_loss: 0.2397 - val_acc: 0.9453 - val_recall_m: 0.6226 - val_precision_m: 0.4197 - val_f1_m: 0.4902 - val_f2_m: 0.5563
# Epoch 60/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2415 - acc: 0.9533 - recall_m: 0.6726 - precision_m: 0.4868 - f1_m: 0.5444 - f2_m: 0.6059 - val_loss: 0.2243 - val_acc: 0.9377 - val_recall_m: 0.6226 - val_precision_m: 0.4342 - val_f1_m: 0.4952 - val_f2_m: 0.5559
# Epoch 61/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2685 - acc: 0.9410 - recall_m: 0.6377 - precision_m: 0.4492 - f1_m: 0.5025 - f2_m: 0.5642 - val_loss: 0.2153 - val_acc: 0.9377 - val_recall_m: 0.6226 - val_precision_m: 0.4350 - val_f1_m: 0.4962 - val_f2_m: 0.5570
# Epoch 62/300
# 2120/2120 [==============================] - 56s 26ms/step - loss: 0.2233 - acc: 0.9434 - recall_m: 0.7236 - precision_m: 0.4579 - f1_m: 0.5331 - f2_m: 0.6194 - val_loss: 0.2287 - val_acc: 0.9302 - val_recall_m: 0.6226 - val_precision_m: 0.3972 - val_f1_m: 0.4708 - val_f2_m: 0.5441
# Epoch 63/300
# 2120/2120 [==============================] - 56s 26ms/step - loss: 0.2252 - acc: 0.9415 - recall_m: 0.7274 - precision_m: 0.4611 - f1_m: 0.5383 - f2_m: 0.6249 - val_loss: 0.2160 - val_acc: 0.9358 - val_recall_m: 0.6226 - val_precision_m: 0.4132 - val_f1_m: 0.4822 - val_f2_m: 0.5506
# Epoch 64/300
# 2120/2120 [==============================] - 56s 26ms/step - loss: 0.2451 - acc: 0.9434 - recall_m: 0.7057 - precision_m: 0.4883 - f1_m: 0.5483 - f2_m: 0.6192 - val_loss: 0.2318 - val_acc: 0.9283 - val_recall_m: 0.6226 - val_precision_m: 0.3923 - val_f1_m: 0.4681 - val_f2_m: 0.5433
# Epoch 65/300
# 2120/2120 [==============================] - 56s 26ms/step - loss: 0.2495 - acc: 0.9415 - recall_m: 0.6179 - precision_m: 0.4428 - f1_m: 0.4922 - f2_m: 0.5510 - val_loss: 0.2419 - val_acc: 0.9264 - val_recall_m: 0.6226 - val_precision_m: 0.3943 - val_f1_m: 0.4697 - val_f2_m: 0.5443
# Epoch 66/300
# 2120/2120 [==============================] - 56s 26ms/step - loss: 0.2240 - acc: 0.9420 - recall_m: 0.7142 - precision_m: 0.4774 - f1_m: 0.5418 - f2_m: 0.6186 - val_loss: 0.2249 - val_acc: 0.9302 - val_recall_m: 0.6226 - val_precision_m: 0.4057 - val_f1_m: 0.4762 - val_f2_m: 0.5471
# Epoch 67/300
# 2120/2120 [==============================] - 56s 26ms/step - loss: 0.2405 - acc: 0.9505 - recall_m: 0.6755 - precision_m: 0.5030 - f1_m: 0.5515 - f2_m: 0.6079 - val_loss: 0.2283 - val_acc: 0.9302 - val_recall_m: 0.6226 - val_precision_m: 0.4057 - val_f1_m: 0.4762 - val_f2_m: 0.5471
# Epoch 68/300
# 2120/2120 [==============================] - 56s 26ms/step - loss: 0.2282 - acc: 0.9467 - recall_m: 0.7151 - precision_m: 0.4828 - f1_m: 0.5517 - f2_m: 0.6270 - val_loss: 0.2285 - val_acc: 0.9302 - val_recall_m: 0.6226 - val_precision_m: 0.4011 - val_f1_m: 0.4719 - val_f2_m: 0.5442
# Epoch 69/300
# 2120/2120 [==============================] - 56s 26ms/step - loss: 0.2546 - acc: 0.9448 - recall_m: 0.6755 - precision_m: 0.4723 - f1_m: 0.5323 - f2_m: 0.5985 - val_loss: 0.2248 - val_acc: 0.9302 - val_recall_m: 0.6226 - val_precision_m: 0.4011 - val_f1_m: 0.4719 - val_f2_m: 0.5442
# Epoch 70/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2409 - acc: 0.9462 - recall_m: 0.6930 - precision_m: 0.4542 - f1_m: 0.5219 - f2_m: 0.5998 - val_loss: 0.2221 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 71/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2071 - acc: 0.9533 - recall_m: 0.6817 - precision_m: 0.4840 - f1_m: 0.5408 - f2_m: 0.6070 - val_loss: 0.2187 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 72/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2321 - acc: 0.9458 - recall_m: 0.6491 - precision_m: 0.4517 - f1_m: 0.5121 - f2_m: 0.5765 - val_loss: 0.2224 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 73/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2072 - acc: 0.9538 - recall_m: 0.7123 - precision_m: 0.5147 - f1_m: 0.5732 - f2_m: 0.6375 - val_loss: 0.2190 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 74/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2454 - acc: 0.9481 - recall_m: 0.6025 - precision_m: 0.4745 - f1_m: 0.5089 - f2_m: 0.5524 - val_loss: 0.2172 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 75/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2452 - acc: 0.9472 - recall_m: 0.6415 - precision_m: 0.4779 - f1_m: 0.5200 - f2_m: 0.5752 - val_loss: 0.2201 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 76/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2372 - acc: 0.9453 - recall_m: 0.6594 - precision_m: 0.4349 - f1_m: 0.4986 - f2_m: 0.5717 - val_loss: 0.2201 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 77/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2170 - acc: 0.9462 - recall_m: 0.6009 - precision_m: 0.4334 - f1_m: 0.4878 - f2_m: 0.5432 - val_loss: 0.2230 - val_acc: 0.9302 - val_recall_m: 0.6226 - val_precision_m: 0.4001 - val_f1_m: 0.4715 - val_f2_m: 0.5445
# Epoch 78/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2622 - acc: 0.9505 - recall_m: 0.6119 - precision_m: 0.4472 - f1_m: 0.4969 - f2_m: 0.5506 - val_loss: 0.2222 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 79/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2121 - acc: 0.9476 - recall_m: 0.6321 - precision_m: 0.4611 - f1_m: 0.5168 - f2_m: 0.5738 - val_loss: 0.2211 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 80/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2614 - acc: 0.9500 - recall_m: 0.6245 - precision_m: 0.4594 - f1_m: 0.5072 - f2_m: 0.5619 - val_loss: 0.2213 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 81/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2529 - acc: 0.9453 - recall_m: 0.6264 - precision_m: 0.4402 - f1_m: 0.4924 - f2_m: 0.5553 - val_loss: 0.2191 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 82/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2545 - acc: 0.9406 - recall_m: 0.6062 - precision_m: 0.4436 - f1_m: 0.4824 - f2_m: 0.5367 - val_loss: 0.2199 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 83/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2423 - acc: 0.9434 - recall_m: 0.6726 - precision_m: 0.4668 - f1_m: 0.5244 - f2_m: 0.5927 - val_loss: 0.2200 - val_acc: 0.9302 - val_recall_m: 0.6226 - val_precision_m: 0.3976 - val_f1_m: 0.4689 - val_f2_m: 0.5426
# Epoch 84/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2252 - acc: 0.9500 - recall_m: 0.6590 - precision_m: 0.4596 - f1_m: 0.5171 - f2_m: 0.5832 - val_loss: 0.2216 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 85/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2132 - acc: 0.9481 - recall_m: 0.7096 - precision_m: 0.4828 - f1_m: 0.5536 - f2_m: 0.6282 - val_loss: 0.2208 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 86/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2349 - acc: 0.9415 - recall_m: 0.6458 - precision_m: 0.4368 - f1_m: 0.4971 - f2_m: 0.5659 - val_loss: 0.2231 - val_acc: 0.9283 - val_recall_m: 0.6226 - val_precision_m: 0.3966 - val_f1_m: 0.4676 - val_f2_m: 0.5413
# Epoch 87/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2348 - acc: 0.9410 - recall_m: 0.6349 - precision_m: 0.4519 - f1_m: 0.5060 - f2_m: 0.5673 - val_loss: 0.2194 - val_acc: 0.9302 - val_recall_m: 0.6226 - val_precision_m: 0.3976 - val_f1_m: 0.4689 - val_f2_m: 0.5426
# Epoch 88/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2426 - acc: 0.9434 - recall_m: 0.6160 - precision_m: 0.3858 - f1_m: 0.4556 - f2_m: 0.5311 - val_loss: 0.2190 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 89/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2024 - acc: 0.9552 - recall_m: 0.7047 - precision_m: 0.4726 - f1_m: 0.5471 - f2_m: 0.6227 - val_loss: 0.2200 - val_acc: 0.9302 - val_recall_m: 0.6226 - val_precision_m: 0.3976 - val_f1_m: 0.4689 - val_f2_m: 0.5426
# Epoch 90/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2136 - acc: 0.9429 - recall_m: 0.6538 - precision_m: 0.4332 - f1_m: 0.5036 - f2_m: 0.5766 - val_loss: 0.2208 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 91/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2257 - acc: 0.9425 - recall_m: 0.6675 - precision_m: 0.4536 - f1_m: 0.5198 - f2_m: 0.5899 - val_loss: 0.2204 - val_acc: 0.9302 - val_recall_m: 0.6226 - val_precision_m: 0.3976 - val_f1_m: 0.4689 - val_f2_m: 0.5426
# Epoch 92/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2617 - acc: 0.9410 - recall_m: 0.6509 - precision_m: 0.4647 - f1_m: 0.5195 - f2_m: 0.5814 - val_loss: 0.2189 - val_acc: 0.9302 - val_recall_m: 0.6226 - val_precision_m: 0.3976 - val_f1_m: 0.4689 - val_f2_m: 0.5426
# Epoch 93/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2101 - acc: 0.9453 - recall_m: 0.7425 - precision_m: 0.5087 - f1_m: 0.5730 - f2_m: 0.6499 - val_loss: 0.2192 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 94/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2137 - acc: 0.9495 - recall_m: 0.7113 - precision_m: 0.4736 - f1_m: 0.5436 - f2_m: 0.6210 - val_loss: 0.2192 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 95/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2288 - acc: 0.9509 - recall_m: 0.7566 - precision_m: 0.4991 - f1_m: 0.5779 - f2_m: 0.6624 - val_loss: 0.2200 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 96/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2249 - acc: 0.9472 - recall_m: 0.6575 - precision_m: 0.4500 - f1_m: 0.5195 - f2_m: 0.5880 - val_loss: 0.2223 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 97/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2273 - acc: 0.9481 - recall_m: 0.6430 - precision_m: 0.4577 - f1_m: 0.5072 - f2_m: 0.5689 - val_loss: 0.2214 - val_acc: 0.9302 - val_recall_m: 0.6226 - val_precision_m: 0.3976 - val_f1_m: 0.4689 - val_f2_m: 0.5426
# Epoch 98/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2250 - acc: 0.9500 - recall_m: 0.6736 - precision_m: 0.4955 - f1_m: 0.5463 - f2_m: 0.6049 - val_loss: 0.2207 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 99/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2022 - acc: 0.9519 - recall_m: 0.6632 - precision_m: 0.4717 - f1_m: 0.5293 - f2_m: 0.5915 - val_loss: 0.2206 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 100/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2312 - acc: 0.9491 - recall_m: 0.6528 - precision_m: 0.4553 - f1_m: 0.5107 - f2_m: 0.5748 - val_loss: 0.2217 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 101/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2679 - acc: 0.9425 - recall_m: 0.6143 - precision_m: 0.4562 - f1_m: 0.5040 - f2_m: 0.5557 - val_loss: 0.2213 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 102/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2352 - acc: 0.9453 - recall_m: 0.6689 - precision_m: 0.4306 - f1_m: 0.5047 - f2_m: 0.5823 - val_loss: 0.2193 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 103/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2479 - acc: 0.9443 - recall_m: 0.6019 - precision_m: 0.4096 - f1_m: 0.4683 - f2_m: 0.5314 - val_loss: 0.2174 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 104/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2205 - acc: 0.9443 - recall_m: 0.6481 - precision_m: 0.4492 - f1_m: 0.5108 - f2_m: 0.5758 - val_loss: 0.2211 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4022 - val_f1_m: 0.4732 - val_f2_m: 0.5455
# Epoch 105/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2279 - acc: 0.9500 - recall_m: 0.6684 - precision_m: 0.4342 - f1_m: 0.5034 - f2_m: 0.5797 - val_loss: 0.2207 - val_acc: 0.9302 - val_recall_m: 0.6226 - val_precision_m: 0.3976 - val_f1_m: 0.4689 - val_f2_m: 0.5426
# Epoch 00105: early stopping

# %%
def plot_history(history):
  plt.figure(figsize=(12,15))
  plt.subplot(3,2,1)
  name = 'loss'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,2)
  name = 'acc'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,3)
  name = 'recall_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,4)
  name = 'precision_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,5)
  name = 'f1_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,6)
  name = 'f2_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

plot_history(history)

# %%
from sklearn.metrics import recall_score, precision_score, f1_score, fbeta_score, cohen_kappa_score, roc_auc_score, accuracy_score

model.load_weights(f"/content/gdrive/My Drive/CNN_LSTM_{I}_adj_watermask_5day.hdf5")
preds = model.predict([x_val_0, x_val_1, x_val_2, num_val_0, num_val_1, num_val_2, adj_val_0, adj_val_1, adj_val_2])

print(recall_score(y_val, preds.round()))
print(fbeta_score(y_val, preds.round(), 2))
print(f1_score(y_val, preds.round()))
print(cohen_kappa_score(y_val, preds.round().flatten()))
print(roc_auc_score(y_val, preds.round()))
print(accuracy_score(y_val, preds.round()))
print(precision_score(y_val, preds.round()))
np.save(f'/content/gdrive/My Drive/preds_{I}', preds.flatten())
# Out:
# 0.9736842105263158
# 0.8447488584474886
# 0.7047619047619047
# 0.6750267020056173
# 0.9563543003851092
# 0.9415094339622642
# 0.5522388059701493
