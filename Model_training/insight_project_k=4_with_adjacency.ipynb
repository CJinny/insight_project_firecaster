# %%
import os
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
from PIL import Image
import matplotlib
from sklearn.model_selection import StratifiedKFold
import keras
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, TensorBoard
from keras import optimizers
from keras.models import Model
from keras.layers import Input, Dropout, UpSampling2D, BatchNormalization, Activation, Dense, Lambda, TimeDistributed, Flatten
from keras.layers import LSTM, GRU, RNN, Reshape, CuDNNGRU, CuDNNLSTM
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, MaxPooling3D
from keras.layers.merge import concatenate
from keras.models import Sequential
from keras.layers.convolutional import Conv3D
from keras.layers.convolutional_recurrent import ConvLSTM2D
from keras import backend as K
from keras.losses import binary_crossentropy
from keras.optimizers import Adam
from keras.optimizers import Adam
from keras.callbacks import Callback
import tensorflow as tf
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import confusion_matrix
import tensorflow as tf
import gc
import torch
from torch.utils.data import Dataset, DataLoader
from keras import layers, models, applications
from keras.layers import concatenate
from matplotlib import pyplot as plt
import tensorflow as tf
from torch.utils.data import Dataset, DataLoader
from keras import layers, models, applications
import albumentations
from albumentations import (
    HorizontalFlip, VerticalFlip, IAAPerspective, ShiftScaleRotate, CLAHE, RandomRotate90, ToFloat,
    Transpose, ShiftScaleRotate, Blur, OpticalDistortion, GridDistortion, HueSaturationValue,
    IAAAdditiveGaussianNoise, GaussNoise, MotionBlur, MedianBlur, IAAPiecewiseAffine, 
    IAASharpen, IAAEmboss, RandomContrast, RandomBrightness, Flip, OneOf, Compose, RandomGamma, ElasticTransform, ChannelShuffle,RGBShift, Rotate
)

from keras.backend.tensorflow_backend import set_session
from keras.backend.tensorflow_backend import clear_session
from keras.backend.tensorflow_backend import get_session
import tensorflow
# Reset Keras Session
def reset_keras():
    sess = get_session()
    clear_session()
    sess.close()
    sess = get_session()
    try:
        del classifier # this is from global space - change this as you need
    except:
        pass

    print(gc.collect()) # if it's done something you should see a number being outputted

    # use the same config as you used to create the session
    config = tensorflow.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 1
    config.gpu_options.visible_device_list = "0"
    set_session(tensorflow.Session(config=config))

def random_everything(seed=42):
  os.environ['PYTHONHASHSEED'] = str(42)
  random.seed(42)
  np.random.seed(42)
  tf.set_random_seed(42)

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

def f2_m(y_true, y_pred, beta=2):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return (1+beta**2) * (precision*recall) / ((beta**2)*(precision)+recall+K.epsilon())

'''
a = []
while(1):
  a.append('1')
'''
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# "\na = []\nwhile(1):\n  a.append('1')\n"

# %%
from google.colab import drive
#drive.mount('/content/gdrive')
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
def generate_sector(imgs, labs, idx=0):
  assert idx <= 24
  alphabets = "ABCDEFGHIJKLMNOPQRSTUVW"
  name = alphabets[idx]
  row_idx = idx//5
  col_idx = idx%5
  return imgs[:108, row_idx*200:(row_idx+1)*200, col_idx*200:(col_idx+1)*200, :], labs[:, row_idx*200:(row_idx+1)*200, col_idx*200:(col_idx+1)*200, :]

def calculate_burnt_ratio(labs):
  ratio = np.zeros((labs.shape[0],))
  for i in range(len(labs)):
    ratio[i] = labs[i,:,:,:].mean()
  return ratio

def generate_sectos_combined(imgs, labs, indices=np.arange(20)):
  combined_imgs, combined_labs = generate_sector(imgs, labs, indices[0])
  for idx in range(1, len(indices)):
    sector_imgs, sector_labs = generate_sector(imgs, labs, idx)
    combined_imgs = np.concatenate([combined_imgs, sector_imgs], 0)
    combined_labs = np.concatenate([combined_labs, sector_labs], 0)
  combined_area = calculate_burnt_ratio(combined_labs)
  return combined_imgs, combined_area

def binarize(y, thres=0.05):
  return (y>thres).astype(int)

def dissect_data(imgs, labs, size=108):
  idx = np.array([i for i in range(len(imgs)) if i%size not in [size-2, size-1, size]])
  imgs_0 = imgs[idx, :,:,:]
  imgs_1 = imgs[idx+1, :,:,:]
  imgs_2 = imgs[idx+2, :,:,:]
  labs   = binarize(labs[idx+2])
  return imgs_0, imgs_1, imgs_2, labs

# %%
water_mask = np.load('/content/gdrive/My Drive/water_mask_based_on_ndvi_565.npy')
water_mask = np.expand_dims(water_mask, 2)

# %%
I = 4
trn_idx = [i for i in range(25) if i not in range(5*I, 5*I+5)]
val_idx = [i for i in range(25) if i in range(5*I, 5*I+5)]

imgs = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['imgs']
dnbr = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['dnbr']
labs = (dnbr>0.66).astype(int)
del dnbr
gc.collect()
### apply water mask
for i in range(len(labs)):
  labs[i,:][water_mask==1] = 0

x_trn, y_trn = generate_sectos_combined(imgs, labs, indices=trn_idx)
del imgs, labs
gc.collect()
## normalize
x_trn = x_trn.astype('float32')
x_trn = x_trn / x_trn.max()

x_trn_0, x_trn_1, x_trn_2, y_trn = dissect_data(x_trn, y_trn)
del x_trn
gc.collect()
# Out:
# 0

# %%
imgs = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['imgs']
dnbr = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['dnbr']
labs = (dnbr>0.66).astype(int)
del dnbr
gc.collect()
### apply water mask
for i in range(len(labs)):
  labs[i,:][water_mask==1] = 0

x_val, y_val = generate_sectos_combined(imgs, labs, indices=val_idx)
del imgs, labs
gc.collect()
## normalize
x_val = x_val.astype('float32')
x_val = x_val / x_val.max()

x_val_0, x_val_1, x_val_2, y_val = dissect_data(x_val, y_val)
del x_val
gc.collect()

del water_mask
gc.collect()
# Out:
# 0

# %%
gsod = pd.read_csv('/content/gdrive/My Drive/flinders_chase_clean_5day.csv').values
gsod = np.array(gsod, dtype='float')
## normalize
gsod = gsod/gsod.max(axis=0)

num_trn_0, num_trn_1, num_trn_2 = gsod[:-2,:], gsod[1:-1,:], gsod[2:,:10]
num_val_0, num_val_1, num_val_2 = gsod[:-2,:], gsod[1:-1,:], gsod[2:,:10]
for i in range(len(trn_idx)-1):
  num_trn_0 = np.concatenate([num_trn_0, gsod[:-2,:]])
  num_trn_1 = np.concatenate([num_trn_1, gsod[1:-1,:]])
  ### the last series should only have day_0 data!
  num_trn_2 = np.concatenate([num_trn_2, gsod[2:,:10]])
for i in range(len(val_idx)-1):
  num_val_0 = np.concatenate([num_val_0, gsod[:-2,:]])
  num_val_1 = np.concatenate([num_val_1, gsod[1:-1,:]])
  ### the last series should only have day_0 data!
  num_val_2 = np.concatenate([num_val_2, gsod[2:,:10]])

# %%
trn_adjacency = pd.read_csv('/content/gdrive/My Drive/trn_adjacency.csv')
val_adjacency = pd.read_csv('/content/gdrive/My Drive/val_adjacency.csv')
sub_columns = [i for i in trn_adjacency.columns if i.startswith(f"f_{I}")]
trn_adjacency = trn_adjacency[sub_columns]
val_adjacency = val_adjacency[sub_columns]

## normalize
MAX = pd.concat([trn_adjacency, val_adjacency], 0).max()
trn_adjacency = trn_adjacency/MAX
val_adjacency = val_adjacency/MAX

s = 0
adj_trn_0 = trn_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 1
adj_trn_1 = trn_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 2
adj_trn_2 = trn_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]

s = 0
adj_val_0 = val_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 1
adj_val_1 = val_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 2
adj_val_2 = val_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]

# %%
def ConvBlock(inputs, suffix=0, prefix="cnn"):
    """no final linear dense layer!"""
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_1a")(inputs)
    conv1 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_1a")(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_1b")(conv1)
    conv1 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_1b")(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2), name=f"{prefix}_{suffix}_maxpool_1")(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_2a")(pool1)
    conv2 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_2a")(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_2b")(conv2)
    conv2 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_2b")(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2), name=f"index_{suffix}_maxpool_2")(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_3a")(pool2)
    conv3 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_3a")(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_3b")(conv3)
    conv3 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_3b")(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2), name=f"index_{suffix}_maxpool_3")(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_4a")(pool3)
    conv4 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_4a")(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_4b")(conv4)
    conv4 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_4b")(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2), name=f"{prefix}_{suffix}_maxpool_4")(conv4)    
    
    flatten= Flatten(name=f"{prefix}_{suffix}_flatten")(pool4)
    dense1 = Dense(64, activation="relu", name=f"{prefix}_{suffix}_relu_1")(flatten)
    drop1  = Dropout(0.4, name=f"{prefix}_{suffix}_drop_1")(dense1)
    dense2 = Dense(32, activation="relu", name=f"{prefix}_{suffix}_relu_2")(drop1)
    drop2  = Dropout(0.3, name=f"{prefix}_{suffix}_drop_2")(dense2)
    dense3 = Dense(16, activation="relu", name=f"{prefix}_{suffix}_relu_3")(drop2)
    drop3  = Dropout(0.2, name=f"{prefix}_{suffix}_drop_3")(dense3)
    dense4 = Dense(8, activation="relu",  name=f"{prefix}_{suffix}_relu_4")(drop3)
    #dense4 = Dense(1, activation="linear", name=f"{prefix}_{suffix}_linear")(drop3)
    return dense4

def MLP(inputs, suffix=0, prefix='mlp'):
    dense = Dense(8, activation='relu', name=f"{prefix}_{suffix}_relu_1")(inputs)
    dense = Dense(4, activation='relu', name=f"{prefix}_{suffix}_relu_2")(dense)
    #dense = Dense(1, activation='linear', name=f"{prefix}_{suffix}_linear")(dense)
    return dense

# %%
n_channels = 14
sector_dim = 200

img_0 = Input((sector_dim,sector_dim,n_channels), name="cnn_input_0")
img_1 = Input((sector_dim,sector_dim,n_channels), name="cnn_input_1")
img_2 = Input((sector_dim,sector_dim,n_channels), name="cnn_input_2")

num_0 = Input((50,), name="gsod_input_0")
num_1 = Input((50,), name="gsod_input_1")
num_2 = Input((10,), name="gsod_input_2")

adj_0 = Input((8,), name="adj_input_0")
adj_1 = Input((8,), name="adj_input_1")
adj_2 = Input((8,), name="adj_input_2")

cnn_0 = ConvBlock(img_0, suffix=0)
cnn_1 = ConvBlock(img_1, suffix=1)
cnn_2 = ConvBlock(img_2, suffix=2)

num_0_m = MLP(num_0, suffix=0, prefix="gsod")
num_1_m = MLP(num_1, suffix=1, prefix="gsod")
num_2_m = MLP(num_2, suffix=2, prefix="gsod")

adj_0_m = MLP(adj_0, suffix=0, prefix="adj")
adj_1_m = MLP(adj_1, suffix=1, prefix="adj")
adj_2_m = MLP(adj_2, suffix=2, prefix="adj")

mixed_0 = concatenate([cnn_0, num_0_m, adj_0_m], name='mixed_0')
mixed_1 = concatenate([cnn_1, num_1_m, adj_1_m], name='mixed_1')
mixed_2 = concatenate([cnn_2, num_2_m, adj_2_m], name='mixed_2')

concat   = concatenate([mixed_0, mixed_1, mixed_2], name="concat_mixed")
reshape    = Reshape((3, -1), name="reshape")(concat)
lstm       = CuDNNLSTM(256, name='lstm_1', return_sequences=True)(reshape)
lstm       = Dropout(0.4, name='lstm_drop_1')(lstm)
lstm       = CuDNNLSTM(256, name='lstm_2')(lstm)
lstm       = Dropout(0.4, name='lstm_drop_2')(lstm)
dense      = Dense(10, activation="relu", name="fc_relu")(lstm)
dense      = Dense(1, activation="sigmoid", name="fc_sigmoid")(dense)

model = Model(inputs=[img_0, img_1, img_2, num_0, num_1, num_2, adj_0, adj_1, adj_2], output=dense)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# cnn_input_0 (InputLayer)        (None, 200, 200, 14) 0
# __________________________________________________________________________________________________
# cnn_input_1 (InputLayer)        (None, 200, 200, 14) 0
# __________________________________________________________________________________________________
# cnn_input_2 (InputLayer)        (None, 200, 200, 14) 0
# __________________________________________________________________________________________________
# cnn_0_conv_1a (Conv2D)          (None, 200, 200, 64) 8128        cnn_input_0[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_1a (Conv2D)          (None, 200, 200, 64) 8128        cnn_input_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_1a (Conv2D)          (None, 200, 200, 64) 8128        cnn_input_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_1a (BatchNormal (None, 200, 200, 64) 256         cnn_0_conv_1a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_1a (BatchNormal (None, 200, 200, 64) 256         cnn_1_conv_1a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_1a (BatchNormal (None, 200, 200, 64) 256         cnn_2_conv_1a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_1b (Conv2D)          (None, 200, 200, 64) 36928       cnn_0_batchnorm_1a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_1b (Conv2D)          (None, 200, 200, 64) 36928       cnn_1_batchnorm_1a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_1b (Conv2D)          (None, 200, 200, 64) 36928       cnn_2_batchnorm_1a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_1b (BatchNormal (None, 200, 200, 64) 256         cnn_0_conv_1b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_1b (BatchNormal (None, 200, 200, 64) 256         cnn_1_conv_1b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_1b (BatchNormal (None, 200, 200, 64) 256         cnn_2_conv_1b[0][0]
# __________________________________________________________________________________________________
# cnn_0_maxpool_1 (MaxPooling2D)  (None, 100, 100, 64) 0           cnn_0_batchnorm_1b[0][0]
# __________________________________________________________________________________________________
# cnn_1_maxpool_1 (MaxPooling2D)  (None, 100, 100, 64) 0           cnn_1_batchnorm_1b[0][0]
# __________________________________________________________________________________________________
# cnn_2_maxpool_1 (MaxPooling2D)  (None, 100, 100, 64) 0           cnn_2_batchnorm_1b[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_2a (Conv2D)          (None, 100, 100, 128 73856       cnn_0_maxpool_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_2a (Conv2D)          (None, 100, 100, 128 73856       cnn_1_maxpool_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_2a (Conv2D)          (None, 100, 100, 128 73856       cnn_2_maxpool_1[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_2a (BatchNormal (None, 100, 100, 128 512         cnn_0_conv_2a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_2a (BatchNormal (None, 100, 100, 128 512         cnn_1_conv_2a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_2a (BatchNormal (None, 100, 100, 128 512         cnn_2_conv_2a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_2b (Conv2D)          (None, 100, 100, 128 147584      cnn_0_batchnorm_2a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_2b (Conv2D)          (None, 100, 100, 128 147584      cnn_1_batchnorm_2a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_2b (Conv2D)          (None, 100, 100, 128 147584      cnn_2_batchnorm_2a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_2b (BatchNormal (None, 100, 100, 128 512         cnn_0_conv_2b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_2b (BatchNormal (None, 100, 100, 128 512         cnn_1_conv_2b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_2b (BatchNormal (None, 100, 100, 128 512         cnn_2_conv_2b[0][0]
# __________________________________________________________________________________________________
# index_0_maxpool_2 (MaxPooling2D (None, 50, 50, 128)  0           cnn_0_batchnorm_2b[0][0]
# __________________________________________________________________________________________________
# index_1_maxpool_2 (MaxPooling2D (None, 50, 50, 128)  0           cnn_1_batchnorm_2b[0][0]
# __________________________________________________________________________________________________
# index_2_maxpool_2 (MaxPooling2D (None, 50, 50, 128)  0           cnn_2_batchnorm_2b[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_3a (Conv2D)          (None, 50, 50, 256)  295168      index_0_maxpool_2[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_3a (Conv2D)          (None, 50, 50, 256)  295168      index_1_maxpool_2[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_3a (Conv2D)          (None, 50, 50, 256)  295168      index_2_maxpool_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_3a (BatchNormal (None, 50, 50, 256)  1024        cnn_0_conv_3a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_3a (BatchNormal (None, 50, 50, 256)  1024        cnn_1_conv_3a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_3a (BatchNormal (None, 50, 50, 256)  1024        cnn_2_conv_3a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_3b (Conv2D)          (None, 50, 50, 256)  590080      cnn_0_batchnorm_3a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_3b (Conv2D)          (None, 50, 50, 256)  590080      cnn_1_batchnorm_3a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_3b (Conv2D)          (None, 50, 50, 256)  590080      cnn_2_batchnorm_3a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_3b (BatchNormal (None, 50, 50, 256)  1024        cnn_0_conv_3b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_3b (BatchNormal (None, 50, 50, 256)  1024        cnn_1_conv_3b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_3b (BatchNormal (None, 50, 50, 256)  1024        cnn_2_conv_3b[0][0]
# __________________________________________________________________________________________________
# index_0_maxpool_3 (MaxPooling2D (None, 25, 25, 256)  0           cnn_0_batchnorm_3b[0][0]
# __________________________________________________________________________________________________
# index_1_maxpool_3 (MaxPooling2D (None, 25, 25, 256)  0           cnn_1_batchnorm_3b[0][0]
# __________________________________________________________________________________________________
# index_2_maxpool_3 (MaxPooling2D (None, 25, 25, 256)  0           cnn_2_batchnorm_3b[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_4a (Conv2D)          (None, 25, 25, 512)  1180160     index_0_maxpool_3[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_4a (Conv2D)          (None, 25, 25, 512)  1180160     index_1_maxpool_3[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_4a (Conv2D)          (None, 25, 25, 512)  1180160     index_2_maxpool_3[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_4a (BatchNormal (None, 25, 25, 512)  2048        cnn_0_conv_4a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_4a (BatchNormal (None, 25, 25, 512)  2048        cnn_1_conv_4a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_4a (BatchNormal (None, 25, 25, 512)  2048        cnn_2_conv_4a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_4b (Conv2D)          (None, 25, 25, 512)  2359808     cnn_0_batchnorm_4a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_4b (Conv2D)          (None, 25, 25, 512)  2359808     cnn_1_batchnorm_4a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_4b (Conv2D)          (None, 25, 25, 512)  2359808     cnn_2_batchnorm_4a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_4b (BatchNormal (None, 25, 25, 512)  2048        cnn_0_conv_4b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_4b (BatchNormal (None, 25, 25, 512)  2048        cnn_1_conv_4b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_4b (BatchNormal (None, 25, 25, 512)  2048        cnn_2_conv_4b[0][0]
# __________________________________________________________________________________________________
# cnn_0_maxpool_4 (MaxPooling2D)  (None, 12, 12, 512)  0           cnn_0_batchnorm_4b[0][0]
# __________________________________________________________________________________________________
# cnn_1_maxpool_4 (MaxPooling2D)  (None, 12, 12, 512)  0           cnn_1_batchnorm_4b[0][0]
# __________________________________________________________________________________________________
# cnn_2_maxpool_4 (MaxPooling2D)  (None, 12, 12, 512)  0           cnn_2_batchnorm_4b[0][0]
# __________________________________________________________________________________________________
# cnn_0_flatten (Flatten)         (None, 73728)        0           cnn_0_maxpool_4[0][0]
# __________________________________________________________________________________________________
# cnn_1_flatten (Flatten)         (None, 73728)        0           cnn_1_maxpool_4[0][0]
# __________________________________________________________________________________________________
# cnn_2_flatten (Flatten)         (None, 73728)        0           cnn_2_maxpool_4[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_1 (Dense)            (None, 64)           4718656     cnn_0_flatten[0][0]
# __________________________________________________________________________________________________
# cnn_1_relu_1 (Dense)            (None, 64)           4718656     cnn_1_flatten[0][0]
# __________________________________________________________________________________________________
# cnn_2_relu_1 (Dense)            (None, 64)           4718656     cnn_2_flatten[0][0]
# __________________________________________________________________________________________________
# cnn_0_drop_1 (Dropout)          (None, 64)           0           cnn_0_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_drop_1 (Dropout)          (None, 64)           0           cnn_1_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_drop_1 (Dropout)          (None, 64)           0           cnn_2_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_2 (Dense)            (None, 32)           2080        cnn_0_drop_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_relu_2 (Dense)            (None, 32)           2080        cnn_1_drop_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_relu_2 (Dense)            (None, 32)           2080        cnn_2_drop_1[0][0]
# __________________________________________________________________________________________________
# cnn_0_drop_2 (Dropout)          (None, 32)           0           cnn_0_relu_2[0][0]
# __________________________________________________________________________________________________
# cnn_1_drop_2 (Dropout)          (None, 32)           0           cnn_1_relu_2[0][0]
# __________________________________________________________________________________________________
# cnn_2_drop_2 (Dropout)          (None, 32)           0           cnn_2_relu_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_3 (Dense)            (None, 16)           528         cnn_0_drop_2[0][0]
# __________________________________________________________________________________________________
# gsod_input_0 (InputLayer)       (None, 50)           0
# __________________________________________________________________________________________________
# adj_input_0 (InputLayer)        (None, 8)            0
# __________________________________________________________________________________________________
# cnn_1_relu_3 (Dense)            (None, 16)           528         cnn_1_drop_2[0][0]
# __________________________________________________________________________________________________
# gsod_input_1 (InputLayer)       (None, 50)           0
# __________________________________________________________________________________________________
# adj_input_1 (InputLayer)        (None, 8)            0
# __________________________________________________________________________________________________
# cnn_2_relu_3 (Dense)            (None, 16)           528         cnn_2_drop_2[0][0]
# __________________________________________________________________________________________________
# gsod_input_2 (InputLayer)       (None, 10)           0
# __________________________________________________________________________________________________
# adj_input_2 (InputLayer)        (None, 8)            0
# __________________________________________________________________________________________________
# cnn_0_drop_3 (Dropout)          (None, 16)           0           cnn_0_relu_3[0][0]
# __________________________________________________________________________________________________
# gsod_0_relu_1 (Dense)           (None, 8)            408         gsod_input_0[0][0]
# __________________________________________________________________________________________________
# adj_0_relu_1 (Dense)            (None, 8)            72          adj_input_0[0][0]
# __________________________________________________________________________________________________
# cnn_1_drop_3 (Dropout)          (None, 16)           0           cnn_1_relu_3[0][0]
# __________________________________________________________________________________________________
# gsod_1_relu_1 (Dense)           (None, 8)            408         gsod_input_1[0][0]
# __________________________________________________________________________________________________
# adj_1_relu_1 (Dense)            (None, 8)            72          adj_input_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_drop_3 (Dropout)          (None, 16)           0           cnn_2_relu_3[0][0]
# __________________________________________________________________________________________________
# gsod_2_relu_1 (Dense)           (None, 8)            88          gsod_input_2[0][0]
# __________________________________________________________________________________________________
# adj_2_relu_1 (Dense)            (None, 8)            72          adj_input_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_4 (Dense)            (None, 8)            136         cnn_0_drop_3[0][0]
# __________________________________________________________________________________________________
# gsod_0_relu_2 (Dense)           (None, 4)            36          gsod_0_relu_1[0][0]
# __________________________________________________________________________________________________
# adj_0_relu_2 (Dense)            (None, 4)            36          adj_0_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_relu_4 (Dense)            (None, 8)            136         cnn_1_drop_3[0][0]
# __________________________________________________________________________________________________
# gsod_1_relu_2 (Dense)           (None, 4)            36          gsod_1_relu_1[0][0]
# __________________________________________________________________________________________________
# adj_1_relu_2 (Dense)            (None, 4)            36          adj_1_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_relu_4 (Dense)            (None, 8)            136         cnn_2_drop_3[0][0]
# __________________________________________________________________________________________________
# gsod_2_relu_2 (Dense)           (None, 4)            36          gsod_2_relu_1[0][0]
# __________________________________________________________________________________________________
# adj_2_relu_2 (Dense)            (None, 4)            36          adj_2_relu_1[0][0]
# __________________________________________________________________________________________________
# mixed_0 (Concatenate)           (None, 16)           0           cnn_0_relu_4[0][0]
#                                                                  gsod_0_relu_2[0][0]
#                                                                  adj_0_relu_2[0][0]
# __________________________________________________________________________________________________
# mixed_1 (Concatenate)           (None, 16)           0           cnn_1_relu_4[0][0]
#                                                                  gsod_1_relu_2[0][0]
#                                                                  adj_1_relu_2[0][0]
# __________________________________________________________________________________________________
# mixed_2 (Concatenate)           (None, 16)           0           cnn_2_relu_4[0][0]
#                                                                  gsod_2_relu_2[0][0]
#                                                                  adj_2_relu_2[0][0]
# __________________________________________________________________________________________________
# concat_mixed (Concatenate)      (None, 48)           0           mixed_0[0][0]
#                                                                  mixed_1[0][0]
#                                                                  mixed_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 3, 16)        0           concat_mixed[0][0]
# __________________________________________________________________________________________________
# lstm_1 (CuDNNLSTM)              (None, 3, 256)       280576      reshape[0][0]
# __________________________________________________________________________________________________
# lstm_drop_1 (Dropout)           (None, 3, 256)       0           lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (CuDNNLSTM)              (None, 256)          526336      lstm_drop_1[0][0]
# __________________________________________________________________________________________________
# lstm_drop_2 (Dropout)           (None, 256)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# fc_relu (Dense)                 (None, 10)           2570        lstm_drop_2[0][0]
# __________________________________________________________________________________________________
# fc_sigmoid (Dense)              (None, 1)            11          fc_relu[0][0]
# ==================================================================================================
# Total params: 29,073,205
# Trainable params: 29,061,685
# Non-trainable params: 11,520
# __________________________________________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("fc...)`

# %%
def custom_loss(y_true, y_pred):
  crossentropy_loss = K.binary_crossentropy(y_true, y_pred)
  weight  = (y_true*9)+1
  return crossentropy_loss*(weight)

# %%
random_everything(seed=42)
#model = Model(inputs=[img_0, img_1, img_2, num_0, num_1, num_2, adj_0, adj_1, adj_2], output=dense)

model.compile(optimizer = Adam(lr=1e-4, decay=1e-6), 
              loss=custom_loss,
              metrics=['acc', recall_m, precision_m, f1_m, f2_m])

ckpt = ModelCheckpoint(f"/content/gdrive/My Drive/CNN_LSTM_{I}_adj_watermask_5day.hdf5", monitor = "val_loss", save_best_only = True, mode = "min", save_weights_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

history = model.fit([x_trn_0, x_trn_1, x_trn_2, num_trn_0, num_trn_1, num_trn_2, adj_trn_0, adj_trn_1, adj_trn_2], y_trn,
                        validation_data=([x_val_0, x_val_1, x_val_2, num_val_0, num_val_1, num_val_2, adj_val_0, adj_val_1, adj_val_2], y_val),
                        batch_size=24, epochs=300,
                        callbacks=[es, ckpt, 
                                   keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7)
                                   ]
                        )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 2120 samples, validate on 530 samples
# Epoch 1/300
# 2120/2120 [==============================] - 72s 34ms/step - loss: 0.9617 - acc: 0.9137 - recall_m: 0.0264 - precision_m: 0.0047 - f1_m: 0.0080 - f2_m: 0.0136 - val_loss: 1.1759 - val_acc: 0.9245 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_f1_m: 0.0000e+00 - val_f2_m: 0.0000e+00
# Epoch 2/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8920 - acc: 0.9467 - recall_m: 0.0566 - precision_m: 0.0906 - f1_m: 0.0675 - f2_m: 0.0602 - val_loss: 1.0658 - val_acc: 0.9189 - val_recall_m: 0.0480 - val_precision_m: 0.1019 - val_f1_m: 0.0624 - val_f2_m: 0.0526
# Epoch 3/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8305 - acc: 0.8976 - recall_m: 0.2604 - precision_m: 0.1802 - f1_m: 0.1920 - f2_m: 0.2208 - val_loss: 1.2718 - val_acc: 0.9245 - val_recall_m: 0.0668 - val_precision_m: 0.1358 - val_f1_m: 0.0886 - val_f2_m: 0.0740
# Epoch 4/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8439 - acc: 0.8910 - recall_m: 0.1943 - precision_m: 0.1517 - f1_m: 0.1555 - f2_m: 0.1714 - val_loss: 1.0323 - val_acc: 0.8981 - val_recall_m: 0.1423 - val_precision_m: 0.1370 - val_f1_m: 0.1230 - val_f2_m: 0.1299
# Epoch 5/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8128 - acc: 0.8500 - recall_m: 0.3019 - precision_m: 0.1570 - f1_m: 0.1867 - f2_m: 0.2314 - val_loss: 0.9572 - val_acc: 0.7491 - val_recall_m: 0.3752 - val_precision_m: 0.1216 - val_f1_m: 0.1761 - val_f2_m: 0.2515
# Epoch 6/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7327 - acc: 0.8538 - recall_m: 0.4377 - precision_m: 0.2089 - f1_m: 0.2586 - f2_m: 0.3309 - val_loss: 1.0548 - val_acc: 0.8566 - val_recall_m: 0.2744 - val_precision_m: 0.1636 - val_f1_m: 0.1688 - val_f2_m: 0.2117
# Epoch 7/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7450 - acc: 0.8476 - recall_m: 0.3868 - precision_m: 0.1745 - f1_m: 0.2239 - f2_m: 0.2873 - val_loss: 0.8980 - val_acc: 0.8340 - val_recall_m: 0.4296 - val_precision_m: 0.1917 - val_f1_m: 0.2548 - val_f2_m: 0.3312
# Epoch 8/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7125 - acc: 0.8264 - recall_m: 0.4370 - precision_m: 0.1987 - f1_m: 0.2455 - f2_m: 0.3160 - val_loss: 0.8480 - val_acc: 0.7887 - val_recall_m: 0.3784 - val_precision_m: 0.1503 - val_f1_m: 0.2085 - val_f2_m: 0.2797
# Epoch 9/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6657 - acc: 0.8439 - recall_m: 0.4547 - precision_m: 0.2138 - f1_m: 0.2662 - f2_m: 0.3399 - val_loss: 0.7596 - val_acc: 0.8755 - val_recall_m: 0.3784 - val_precision_m: 0.2817 - val_f1_m: 0.3076 - val_f2_m: 0.3408
# Epoch 10/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7088 - acc: 0.8585 - recall_m: 0.3962 - precision_m: 0.1999 - f1_m: 0.2459 - f2_m: 0.3062 - val_loss: 0.8924 - val_acc: 0.8660 - val_recall_m: 0.2938 - val_precision_m: 0.1964 - val_f1_m: 0.2173 - val_f2_m: 0.2514
# Epoch 11/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6349 - acc: 0.8665 - recall_m: 0.4481 - precision_m: 0.2232 - f1_m: 0.2740 - f2_m: 0.3442 - val_loss: 0.7766 - val_acc: 0.8811 - val_recall_m: 0.3542 - val_precision_m: 0.2506 - val_f1_m: 0.2813 - val_f2_m: 0.3159
# Epoch 12/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6744 - acc: 0.8623 - recall_m: 0.5179 - precision_m: 0.2357 - f1_m: 0.2933 - f2_m: 0.3786 - val_loss: 0.8146 - val_acc: 0.8396 - val_recall_m: 0.4092 - val_precision_m: 0.1911 - val_f1_m: 0.2443 - val_f2_m: 0.3136
# Epoch 13/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6428 - acc: 0.8736 - recall_m: 0.4974 - precision_m: 0.2709 - f1_m: 0.3275 - f2_m: 0.3996 - val_loss: 1.0183 - val_acc: 0.9000 - val_recall_m: 0.3213 - val_precision_m: 0.2925 - val_f1_m: 0.2801 - val_f2_m: 0.2971
# Epoch 14/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5778 - acc: 0.8925 - recall_m: 0.5170 - precision_m: 0.3153 - f1_m: 0.3619 - f2_m: 0.4267 - val_loss: 0.7817 - val_acc: 0.9057 - val_recall_m: 0.4194 - val_precision_m: 0.3181 - val_f1_m: 0.3456 - val_f2_m: 0.3804
# Epoch 15/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5420 - acc: 0.8783 - recall_m: 0.5028 - precision_m: 0.2695 - f1_m: 0.3288 - f2_m: 0.4020 - val_loss: 0.6163 - val_acc: 0.9113 - val_recall_m: 0.4739 - val_precision_m: 0.3166 - val_f1_m: 0.3604 - val_f2_m: 0.4129
# Epoch 16/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5328 - acc: 0.8934 - recall_m: 0.5245 - precision_m: 0.2927 - f1_m: 0.3489 - f2_m: 0.4225 - val_loss: 0.7367 - val_acc: 0.9151 - val_recall_m: 0.4005 - val_precision_m: 0.2909 - val_f1_m: 0.3200 - val_f2_m: 0.3577
# Epoch 17/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4473 - acc: 0.9005 - recall_m: 0.6109 - precision_m: 0.3394 - f1_m: 0.4116 - f2_m: 0.4976 - val_loss: 0.8512 - val_acc: 0.8642 - val_recall_m: 0.3795 - val_precision_m: 0.1775 - val_f1_m: 0.2324 - val_f2_m: 0.2957
# Epoch 18/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5022 - acc: 0.8906 - recall_m: 0.6104 - precision_m: 0.2987 - f1_m: 0.3760 - f2_m: 0.4742 - val_loss: 0.6467 - val_acc: 0.8660 - val_recall_m: 0.4539 - val_precision_m: 0.2539 - val_f1_m: 0.2992 - val_f2_m: 0.3661
# Epoch 19/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4349 - acc: 0.8962 - recall_m: 0.5764 - precision_m: 0.3096 - f1_m: 0.3808 - f2_m: 0.4649 - val_loss: 0.5559 - val_acc: 0.9000 - val_recall_m: 0.5003 - val_precision_m: 0.2917 - val_f1_m: 0.3494 - val_f2_m: 0.4168
# Epoch 20/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4584 - acc: 0.8920 - recall_m: 0.5355 - precision_m: 0.2818 - f1_m: 0.3485 - f2_m: 0.4278 - val_loss: 0.6563 - val_acc: 0.8943 - val_recall_m: 0.4663 - val_precision_m: 0.2881 - val_f1_m: 0.3393 - val_f2_m: 0.3986
# Epoch 21/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4742 - acc: 0.8981 - recall_m: 0.5868 - precision_m: 0.3216 - f1_m: 0.3945 - f2_m: 0.4789 - val_loss: 0.5921 - val_acc: 0.8434 - val_recall_m: 0.5051 - val_precision_m: 0.2601 - val_f1_m: 0.3168 - val_f2_m: 0.3940
# Epoch 22/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4357 - acc: 0.9061 - recall_m: 0.5943 - precision_m: 0.3632 - f1_m: 0.4208 - f2_m: 0.4950 - val_loss: 0.4644 - val_acc: 0.8849 - val_recall_m: 0.5278 - val_precision_m: 0.3140 - val_f1_m: 0.3680 - val_f2_m: 0.4375
# Epoch 23/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4200 - acc: 0.9184 - recall_m: 0.6292 - precision_m: 0.3660 - f1_m: 0.4364 - f2_m: 0.5208 - val_loss: 0.5656 - val_acc: 0.8774 - val_recall_m: 0.5267 - val_precision_m: 0.2537 - val_f1_m: 0.3306 - val_f2_m: 0.4187
# Epoch 24/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3967 - acc: 0.9052 - recall_m: 0.5906 - precision_m: 0.3591 - f1_m: 0.4226 - f2_m: 0.4973 - val_loss: 0.6037 - val_acc: 0.8925 - val_recall_m: 0.4776 - val_precision_m: 0.2805 - val_f1_m: 0.3297 - val_f2_m: 0.3958
# Epoch 25/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4684 - acc: 0.9104 - recall_m: 0.5702 - precision_m: 0.3290 - f1_m: 0.3952 - f2_m: 0.4722 - val_loss: 0.6785 - val_acc: 0.8792 - val_recall_m: 0.4938 - val_precision_m: 0.2902 - val_f1_m: 0.3454 - val_f2_m: 0.4112
# Epoch 26/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3808 - acc: 0.9217 - recall_m: 0.6057 - precision_m: 0.3496 - f1_m: 0.4194 - f2_m: 0.5004 - val_loss: 0.4543 - val_acc: 0.8698 - val_recall_m: 0.5644 - val_precision_m: 0.2571 - val_f1_m: 0.3418 - val_f2_m: 0.4399
# Epoch 27/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3904 - acc: 0.9170 - recall_m: 0.6113 - precision_m: 0.3711 - f1_m: 0.4268 - f2_m: 0.5035 - val_loss: 0.5574 - val_acc: 0.8302 - val_recall_m: 0.6011 - val_precision_m: 0.2441 - val_f1_m: 0.3320 - val_f2_m: 0.4417
# Epoch 28/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3784 - acc: 0.8986 - recall_m: 0.6991 - precision_m: 0.3355 - f1_m: 0.4284 - f2_m: 0.5421 - val_loss: 0.4425 - val_acc: 0.9094 - val_recall_m: 0.5644 - val_precision_m: 0.3433 - val_f1_m: 0.4080 - val_f2_m: 0.4794
# Epoch 29/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3299 - acc: 0.9259 - recall_m: 0.5783 - precision_m: 0.3634 - f1_m: 0.4240 - f2_m: 0.4950 - val_loss: 0.5005 - val_acc: 0.8189 - val_recall_m: 0.6097 - val_precision_m: 0.2219 - val_f1_m: 0.3199 - val_f2_m: 0.4426
# Epoch 30/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3795 - acc: 0.9094 - recall_m: 0.6783 - precision_m: 0.3553 - f1_m: 0.4395 - f2_m: 0.5422 - val_loss: 0.5909 - val_acc: 0.9226 - val_recall_m: 0.4776 - val_precision_m: 0.3709 - val_f1_m: 0.3925 - val_f2_m: 0.4306
# Epoch 31/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3403 - acc: 0.9189 - recall_m: 0.6285 - precision_m: 0.3866 - f1_m: 0.4522 - f2_m: 0.5303 - val_loss: 0.7344 - val_acc: 0.8585 - val_recall_m: 0.4992 - val_precision_m: 0.2164 - val_f1_m: 0.2864 - val_f2_m: 0.3746
# Epoch 32/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3844 - acc: 0.9066 - recall_m: 0.6509 - precision_m: 0.3681 - f1_m: 0.4345 - f2_m: 0.5245 - val_loss: 0.4495 - val_acc: 0.9038 - val_recall_m: 0.5013 - val_precision_m: 0.3141 - val_f1_m: 0.3724 - val_f2_m: 0.4336
# Epoch 33/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3269 - acc: 0.9335 - recall_m: 0.6274 - precision_m: 0.4209 - f1_m: 0.4786 - f2_m: 0.5460 - val_loss: 0.4576 - val_acc: 0.9226 - val_recall_m: 0.4825 - val_precision_m: 0.3657 - val_f1_m: 0.3909 - val_f2_m: 0.4300
# Epoch 34/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3173 - acc: 0.9179 - recall_m: 0.6472 - precision_m: 0.3713 - f1_m: 0.4500 - f2_m: 0.5382 - val_loss: 0.3692 - val_acc: 0.9132 - val_recall_m: 0.5671 - val_precision_m: 0.3863 - val_f1_m: 0.4348 - val_f2_m: 0.4943
# Epoch 35/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3136 - acc: 0.9264 - recall_m: 0.6364 - precision_m: 0.4177 - f1_m: 0.4784 - f2_m: 0.5495 - val_loss: 0.3947 - val_acc: 0.9189 - val_recall_m: 0.5606 - val_precision_m: 0.3943 - val_f1_m: 0.4371 - val_f2_m: 0.4915
# Epoch 36/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3004 - acc: 0.9382 - recall_m: 0.6283 - precision_m: 0.4426 - f1_m: 0.4981 - f2_m: 0.5576 - val_loss: 0.3246 - val_acc: 0.9189 - val_recall_m: 0.5898 - val_precision_m: 0.4105 - val_f1_m: 0.4570 - val_f2_m: 0.5151
# Epoch 37/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2690 - acc: 0.9316 - recall_m: 0.7264 - precision_m: 0.4155 - f1_m: 0.5062 - f2_m: 0.6061 - val_loss: 0.3325 - val_acc: 0.9094 - val_recall_m: 0.5482 - val_precision_m: 0.3328 - val_f1_m: 0.3942 - val_f2_m: 0.4630
# Epoch 38/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2450 - acc: 0.9410 - recall_m: 0.6132 - precision_m: 0.4287 - f1_m: 0.4783 - f2_m: 0.5404 - val_loss: 0.3315 - val_acc: 0.9038 - val_recall_m: 0.5871 - val_precision_m: 0.3604 - val_f1_m: 0.4287 - val_f2_m: 0.5016
# Epoch 39/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2550 - acc: 0.9321 - recall_m: 0.6274 - precision_m: 0.3825 - f1_m: 0.4523 - f2_m: 0.5307 - val_loss: 0.2870 - val_acc: 0.9132 - val_recall_m: 0.5520 - val_precision_m: 0.3294 - val_f1_m: 0.3986 - val_f2_m: 0.4709
# Epoch 40/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2817 - acc: 0.9335 - recall_m: 0.6868 - precision_m: 0.4225 - f1_m: 0.4981 - f2_m: 0.5829 - val_loss: 0.3528 - val_acc: 0.9208 - val_recall_m: 0.5660 - val_precision_m: 0.3686 - val_f1_m: 0.4219 - val_f2_m: 0.4856
# Epoch 41/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2979 - acc: 0.9307 - recall_m: 0.6317 - precision_m: 0.3915 - f1_m: 0.4540 - f2_m: 0.5316 - val_loss: 0.3219 - val_acc: 0.9302 - val_recall_m: 0.5305 - val_precision_m: 0.3766 - val_f1_m: 0.4182 - val_f2_m: 0.4693
# Epoch 42/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.2473 - acc: 0.9387 - recall_m: 0.7113 - precision_m: 0.4391 - f1_m: 0.5208 - f2_m: 0.6086 - val_loss: 0.3185 - val_acc: 0.9170 - val_recall_m: 0.5596 - val_precision_m: 0.3392 - val_f1_m: 0.4022 - val_f2_m: 0.4748
# Epoch 43/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.2347 - acc: 0.9396 - recall_m: 0.7179 - precision_m: 0.4300 - f1_m: 0.5187 - f2_m: 0.6126 - val_loss: 0.3384 - val_acc: 0.8887 - val_recall_m: 0.5747 - val_precision_m: 0.2740 - val_f1_m: 0.3622 - val_f2_m: 0.4595
# Epoch 44/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.2226 - acc: 0.9443 - recall_m: 0.6558 - precision_m: 0.4564 - f1_m: 0.5125 - f2_m: 0.5787 - val_loss: 0.2680 - val_acc: 0.9283 - val_recall_m: 0.6113 - val_precision_m: 0.4200 - val_f1_m: 0.4721 - val_f2_m: 0.5355
# Epoch 45/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2300 - acc: 0.9354 - recall_m: 0.6962 - precision_m: 0.4251 - f1_m: 0.5069 - f2_m: 0.5950 - val_loss: 0.2367 - val_acc: 0.9283 - val_recall_m: 0.6313 - val_precision_m: 0.4078 - val_f1_m: 0.4765 - val_f2_m: 0.5492
# Epoch 46/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2720 - acc: 0.9453 - recall_m: 0.6392 - precision_m: 0.4415 - f1_m: 0.5016 - f2_m: 0.5659 - val_loss: 0.3312 - val_acc: 0.9038 - val_recall_m: 0.5633 - val_precision_m: 0.3176 - val_f1_m: 0.3912 - val_f2_m: 0.4707
# Epoch 47/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2830 - acc: 0.9340 - recall_m: 0.6555 - precision_m: 0.4345 - f1_m: 0.4951 - f2_m: 0.5669 - val_loss: 0.2647 - val_acc: 0.9264 - val_recall_m: 0.5596 - val_precision_m: 0.3644 - val_f1_m: 0.4150 - val_f2_m: 0.4791
# Epoch 48/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2765 - acc: 0.9377 - recall_m: 0.6038 - precision_m: 0.4192 - f1_m: 0.4760 - f2_m: 0.5360 - val_loss: 0.2785 - val_acc: 0.9283 - val_recall_m: 0.5547 - val_precision_m: 0.3740 - val_f1_m: 0.4242 - val_f2_m: 0.4838
# Epoch 49/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2599 - acc: 0.9316 - recall_m: 0.6925 - precision_m: 0.3894 - f1_m: 0.4761 - f2_m: 0.5743 - val_loss: 0.2948 - val_acc: 0.9264 - val_recall_m: 0.5434 - val_precision_m: 0.3663 - val_f1_m: 0.4183 - val_f2_m: 0.4779
# Epoch 50/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2233 - acc: 0.9420 - recall_m: 0.6519 - precision_m: 0.4579 - f1_m: 0.5181 - f2_m: 0.5818 - val_loss: 0.2874 - val_acc: 0.9132 - val_recall_m: 0.5660 - val_precision_m: 0.3341 - val_f1_m: 0.4010 - val_f2_m: 0.4775
# Epoch 51/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2111 - acc: 0.9476 - recall_m: 0.6792 - precision_m: 0.4755 - f1_m: 0.5403 - f2_m: 0.6067 - val_loss: 0.2970 - val_acc: 0.9283 - val_recall_m: 0.5660 - val_precision_m: 0.3707 - val_f1_m: 0.4241 - val_f2_m: 0.4889
# Epoch 52/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2534 - acc: 0.9377 - recall_m: 0.6958 - precision_m: 0.4577 - f1_m: 0.5267 - f2_m: 0.6044 - val_loss: 0.2789 - val_acc: 0.9208 - val_recall_m: 0.5811 - val_precision_m: 0.3512 - val_f1_m: 0.4228 - val_f2_m: 0.4975
# Epoch 53/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.2116 - acc: 0.9481 - recall_m: 0.7057 - precision_m: 0.4562 - f1_m: 0.5296 - f2_m: 0.6100 - val_loss: 0.2346 - val_acc: 0.9415 - val_recall_m: 0.5811 - val_precision_m: 0.3843 - val_f1_m: 0.4504 - val_f2_m: 0.5153
# Epoch 54/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2236 - acc: 0.9486 - recall_m: 0.6585 - precision_m: 0.4575 - f1_m: 0.5147 - f2_m: 0.5814 - val_loss: 0.2512 - val_acc: 0.9340 - val_recall_m: 0.5321 - val_precision_m: 0.3790 - val_f1_m: 0.4234 - val_f2_m: 0.4750
# Epoch 55/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.2177 - acc: 0.9443 - recall_m: 0.6943 - precision_m: 0.4774 - f1_m: 0.5439 - f2_m: 0.6143 - val_loss: 0.2416 - val_acc: 0.9453 - val_recall_m: 0.6151 - val_precision_m: 0.4449 - val_f1_m: 0.4989 - val_f2_m: 0.5546
# Epoch 56/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2136 - acc: 0.9495 - recall_m: 0.7547 - precision_m: 0.5130 - f1_m: 0.5787 - f2_m: 0.6585 - val_loss: 0.2212 - val_acc: 0.9283 - val_recall_m: 0.5925 - val_precision_m: 0.3405 - val_f1_m: 0.4220 - val_f2_m: 0.5048
# Epoch 57/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2490 - acc: 0.9425 - recall_m: 0.7028 - precision_m: 0.4392 - f1_m: 0.5136 - f2_m: 0.5991 - val_loss: 0.2513 - val_acc: 0.9396 - val_recall_m: 0.5811 - val_precision_m: 0.3862 - val_f1_m: 0.4464 - val_f2_m: 0.5102
# Epoch 58/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2187 - acc: 0.9443 - recall_m: 0.6802 - precision_m: 0.4532 - f1_m: 0.5215 - f2_m: 0.5953 - val_loss: 0.2730 - val_acc: 0.9264 - val_recall_m: 0.5660 - val_precision_m: 0.3387 - val_f1_m: 0.4046 - val_f2_m: 0.4800
# Epoch 59/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2004 - acc: 0.9519 - recall_m: 0.6370 - precision_m: 0.4572 - f1_m: 0.5146 - f2_m: 0.5741 - val_loss: 0.2451 - val_acc: 0.9358 - val_recall_m: 0.5925 - val_precision_m: 0.3420 - val_f1_m: 0.4257 - val_f2_m: 0.5083
# Epoch 60/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.2020 - acc: 0.9542 - recall_m: 0.6887 - precision_m: 0.4917 - f1_m: 0.5470 - f2_m: 0.6134 - val_loss: 0.2102 - val_acc: 0.9472 - val_recall_m: 0.5925 - val_precision_m: 0.3830 - val_f1_m: 0.4529 - val_f2_m: 0.5220
# Epoch 61/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1648 - acc: 0.9561 - recall_m: 0.6849 - precision_m: 0.4874 - f1_m: 0.5503 - f2_m: 0.6159 - val_loss: 0.2179 - val_acc: 0.9528 - val_recall_m: 0.5585 - val_precision_m: 0.3925 - val_f1_m: 0.4486 - val_f2_m: 0.5034
# Epoch 62/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1496 - acc: 0.9604 - recall_m: 0.7670 - precision_m: 0.5174 - f1_m: 0.5922 - f2_m: 0.6735 - val_loss: 0.2419 - val_acc: 0.9491 - val_recall_m: 0.5434 - val_precision_m: 0.4015 - val_f1_m: 0.4438 - val_f2_m: 0.4918
# Epoch 63/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1937 - acc: 0.9575 - recall_m: 0.7208 - precision_m: 0.5121 - f1_m: 0.5726 - f2_m: 0.6411 - val_loss: 0.2658 - val_acc: 0.9509 - val_recall_m: 0.5434 - val_precision_m: 0.3998 - val_f1_m: 0.4433 - val_f2_m: 0.4916
# Epoch 64/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1703 - acc: 0.9613 - recall_m: 0.7387 - precision_m: 0.5596 - f1_m: 0.6151 - f2_m: 0.6738 - val_loss: 0.2210 - val_acc: 0.9509 - val_recall_m: 0.5434 - val_precision_m: 0.4029 - val_f1_m: 0.4457 - val_f2_m: 0.4932
# Epoch 65/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2092 - acc: 0.9519 - recall_m: 0.6311 - precision_m: 0.4740 - f1_m: 0.5156 - f2_m: 0.5679 - val_loss: 0.2001 - val_acc: 0.9509 - val_recall_m: 0.6151 - val_precision_m: 0.4483 - val_f1_m: 0.5034 - val_f2_m: 0.5582
# Epoch 66/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1640 - acc: 0.9571 - recall_m: 0.7377 - precision_m: 0.5109 - f1_m: 0.5803 - f2_m: 0.6547 - val_loss: 0.2040 - val_acc: 0.9491 - val_recall_m: 0.6151 - val_precision_m: 0.4426 - val_f1_m: 0.4991 - val_f2_m: 0.5557
# Epoch 67/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2088 - acc: 0.9585 - recall_m: 0.6868 - precision_m: 0.5117 - f1_m: 0.5649 - f2_m: 0.6236 - val_loss: 0.2036 - val_acc: 0.9547 - val_recall_m: 0.6151 - val_precision_m: 0.4561 - val_f1_m: 0.5099 - val_f2_m: 0.5620
# Epoch 68/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1806 - acc: 0.9604 - recall_m: 0.7585 - precision_m: 0.5366 - f1_m: 0.6051 - f2_m: 0.6774 - val_loss: 0.2007 - val_acc: 0.9509 - val_recall_m: 0.5698 - val_precision_m: 0.4023 - val_f1_m: 0.4573 - val_f2_m: 0.5124
# Epoch 69/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1683 - acc: 0.9575 - recall_m: 0.7057 - precision_m: 0.5245 - f1_m: 0.5804 - f2_m: 0.6396 - val_loss: 0.2789 - val_acc: 0.9509 - val_recall_m: 0.5434 - val_precision_m: 0.3998 - val_f1_m: 0.4449 - val_f2_m: 0.4933
# Epoch 70/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2112 - acc: 0.9500 - recall_m: 0.6609 - precision_m: 0.4585 - f1_m: 0.5182 - f2_m: 0.5852 - val_loss: 0.3000 - val_acc: 0.9415 - val_recall_m: 0.6151 - val_precision_m: 0.4209 - val_f1_m: 0.4859 - val_f2_m: 0.5495
# Epoch 71/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1752 - acc: 0.9528 - recall_m: 0.6972 - precision_m: 0.4945 - f1_m: 0.5544 - f2_m: 0.6202 - val_loss: 0.2168 - val_acc: 0.9528 - val_recall_m: 0.6151 - val_precision_m: 0.4457 - val_f1_m: 0.5038 - val_f2_m: 0.5594
# Epoch 72/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1781 - acc: 0.9566 - recall_m: 0.6840 - precision_m: 0.4972 - f1_m: 0.5542 - f2_m: 0.6153 - val_loss: 0.2264 - val_acc: 0.9509 - val_recall_m: 0.6151 - val_precision_m: 0.4411 - val_f1_m: 0.5000 - val_f2_m: 0.5572
# Epoch 73/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1827 - acc: 0.9571 - recall_m: 0.7066 - precision_m: 0.5304 - f1_m: 0.5844 - f2_m: 0.6429 - val_loss: 0.2563 - val_acc: 0.9547 - val_recall_m: 0.5698 - val_precision_m: 0.4168 - val_f1_m: 0.4682 - val_f2_m: 0.5188
# Epoch 74/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2076 - acc: 0.9561 - recall_m: 0.6217 - precision_m: 0.5147 - f1_m: 0.5368 - f2_m: 0.5746 - val_loss: 0.2124 - val_acc: 0.9453 - val_recall_m: 0.6151 - val_precision_m: 0.4424 - val_f1_m: 0.4984 - val_f2_m: 0.5551
# Epoch 75/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1628 - acc: 0.9604 - recall_m: 0.6906 - precision_m: 0.5140 - f1_m: 0.5719 - f2_m: 0.6302 - val_loss: 0.2010 - val_acc: 0.9434 - val_recall_m: 0.6151 - val_precision_m: 0.4382 - val_f1_m: 0.4953 - val_f2_m: 0.5532
# Epoch 76/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1712 - acc: 0.9580 - recall_m: 0.6962 - precision_m: 0.5119 - f1_m: 0.5614 - f2_m: 0.6230 - val_loss: 0.1954 - val_acc: 0.9453 - val_recall_m: 0.6151 - val_precision_m: 0.4382 - val_f1_m: 0.4953 - val_f2_m: 0.5532
# Epoch 77/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1721 - acc: 0.9500 - recall_m: 0.6208 - precision_m: 0.4358 - f1_m: 0.4952 - f2_m: 0.5555 - val_loss: 0.1797 - val_acc: 0.9491 - val_recall_m: 0.6151 - val_precision_m: 0.4426 - val_f1_m: 0.4998 - val_f2_m: 0.5566
# Epoch 78/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1823 - acc: 0.9566 - recall_m: 0.6509 - precision_m: 0.4575 - f1_m: 0.5180 - f2_m: 0.5810 - val_loss: 0.1839 - val_acc: 0.9509 - val_recall_m: 0.6151 - val_precision_m: 0.4458 - val_f1_m: 0.5028 - val_f2_m: 0.5586
# Epoch 79/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1732 - acc: 0.9642 - recall_m: 0.6538 - precision_m: 0.5406 - f1_m: 0.5731 - f2_m: 0.6115 - val_loss: 0.1986 - val_acc: 0.9547 - val_recall_m: 0.6151 - val_precision_m: 0.4542 - val_f1_m: 0.5093 - val_f2_m: 0.5623
# Epoch 80/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1705 - acc: 0.9608 - recall_m: 0.6755 - precision_m: 0.5175 - f1_m: 0.5624 - f2_m: 0.6135 - val_loss: 0.2277 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4656 - val_f1_m: 0.5180 - val_f2_m: 0.5671
# Epoch 81/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1921 - acc: 0.9594 - recall_m: 0.6321 - precision_m: 0.4970 - f1_m: 0.5372 - f2_m: 0.5824 - val_loss: 0.2030 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4662 - val_f1_m: 0.5176 - val_f2_m: 0.5665
# Epoch 82/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1824 - acc: 0.9613 - recall_m: 0.6472 - precision_m: 0.5009 - f1_m: 0.5403 - f2_m: 0.5890 - val_loss: 0.2153 - val_acc: 0.9566 - val_recall_m: 0.6151 - val_precision_m: 0.4618 - val_f1_m: 0.5150 - val_f2_m: 0.5653
# Epoch 83/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1987 - acc: 0.9547 - recall_m: 0.6747 - precision_m: 0.4840 - f1_m: 0.5428 - f2_m: 0.6060 - val_loss: 0.1839 - val_acc: 0.9528 - val_recall_m: 0.6151 - val_precision_m: 0.4490 - val_f1_m: 0.5061 - val_f2_m: 0.5609
# Epoch 84/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1670 - acc: 0.9585 - recall_m: 0.6654 - precision_m: 0.4915 - f1_m: 0.5446 - f2_m: 0.6018 - val_loss: 0.1729 - val_acc: 0.9566 - val_recall_m: 0.6151 - val_precision_m: 0.4595 - val_f1_m: 0.5139 - val_f2_m: 0.5651
# Epoch 85/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1647 - acc: 0.9571 - recall_m: 0.7100 - precision_m: 0.5111 - f1_m: 0.5749 - f2_m: 0.6404 - val_loss: 0.1894 - val_acc: 0.9547 - val_recall_m: 0.6151 - val_precision_m: 0.4550 - val_f1_m: 0.5101 - val_f2_m: 0.5629
# Epoch 86/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1699 - acc: 0.9552 - recall_m: 0.6623 - precision_m: 0.4708 - f1_m: 0.5284 - f2_m: 0.5912 - val_loss: 0.1869 - val_acc: 0.9547 - val_recall_m: 0.6151 - val_precision_m: 0.4564 - val_f1_m: 0.5106 - val_f2_m: 0.5628
# Epoch 87/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1637 - acc: 0.9557 - recall_m: 0.6925 - precision_m: 0.5053 - f1_m: 0.5601 - f2_m: 0.6221 - val_loss: 0.1980 - val_acc: 0.9547 - val_recall_m: 0.6151 - val_precision_m: 0.4518 - val_f1_m: 0.5069 - val_f2_m: 0.5606
# Epoch 88/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1715 - acc: 0.9491 - recall_m: 0.6670 - precision_m: 0.4581 - f1_m: 0.5216 - f2_m: 0.5902 - val_loss: 0.1951 - val_acc: 0.9547 - val_recall_m: 0.6151 - val_precision_m: 0.4542 - val_f1_m: 0.5093 - val_f2_m: 0.5623
# Epoch 89/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1781 - acc: 0.9580 - recall_m: 0.7151 - precision_m: 0.5264 - f1_m: 0.5827 - f2_m: 0.6452 - val_loss: 0.1796 - val_acc: 0.9528 - val_recall_m: 0.6151 - val_precision_m: 0.4526 - val_f1_m: 0.5076 - val_f2_m: 0.5611
# Epoch 90/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1640 - acc: 0.9585 - recall_m: 0.6774 - precision_m: 0.4917 - f1_m: 0.5517 - f2_m: 0.6132 - val_loss: 0.1801 - val_acc: 0.9491 - val_recall_m: 0.6151 - val_precision_m: 0.4462 - val_f1_m: 0.5018 - val_f2_m: 0.5572
# Epoch 91/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1952 - acc: 0.9552 - recall_m: 0.6396 - precision_m: 0.4551 - f1_m: 0.5100 - f2_m: 0.5713 - val_loss: 0.1735 - val_acc: 0.9528 - val_recall_m: 0.6151 - val_precision_m: 0.4503 - val_f1_m: 0.5066 - val_f2_m: 0.5608
# Epoch 92/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1551 - acc: 0.9571 - recall_m: 0.6883 - precision_m: 0.5121 - f1_m: 0.5663 - f2_m: 0.6246 - val_loss: 0.1689 - val_acc: 0.9491 - val_recall_m: 0.6151 - val_precision_m: 0.4447 - val_f1_m: 0.5015 - val_f2_m: 0.5575
# Epoch 93/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1684 - acc: 0.9599 - recall_m: 0.7443 - precision_m: 0.5447 - f1_m: 0.5984 - f2_m: 0.6650 - val_loss: 0.1713 - val_acc: 0.9528 - val_recall_m: 0.6151 - val_precision_m: 0.4490 - val_f1_m: 0.5061 - val_f2_m: 0.5609
# Epoch 94/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1417 - acc: 0.9604 - recall_m: 0.7472 - precision_m: 0.5113 - f1_m: 0.5862 - f2_m: 0.6630 - val_loss: 0.1687 - val_acc: 0.9566 - val_recall_m: 0.6151 - val_precision_m: 0.4588 - val_f1_m: 0.5131 - val_f2_m: 0.5646
# Epoch 95/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1757 - acc: 0.9594 - recall_m: 0.7425 - precision_m: 0.5434 - f1_m: 0.6031 - f2_m: 0.6686 - val_loss: 0.1632 - val_acc: 0.9528 - val_recall_m: 0.6151 - val_precision_m: 0.4503 - val_f1_m: 0.5066 - val_f2_m: 0.5608
# Epoch 96/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1908 - acc: 0.9613 - recall_m: 0.6406 - precision_m: 0.4936 - f1_m: 0.5418 - f2_m: 0.5905 - val_loss: 0.1644 - val_acc: 0.9491 - val_recall_m: 0.6151 - val_precision_m: 0.4447 - val_f1_m: 0.5015 - val_f2_m: 0.5575
# Epoch 97/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1710 - acc: 0.9590 - recall_m: 0.6415 - precision_m: 0.4694 - f1_m: 0.5237 - f2_m: 0.5810 - val_loss: 0.1601 - val_acc: 0.9528 - val_recall_m: 0.6151 - val_precision_m: 0.4484 - val_f1_m: 0.5046 - val_f2_m: 0.5592
# Epoch 98/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1715 - acc: 0.9646 - recall_m: 0.6764 - precision_m: 0.5328 - f1_m: 0.5818 - f2_m: 0.6297 - val_loss: 0.1600 - val_acc: 0.9547 - val_recall_m: 0.6151 - val_precision_m: 0.4527 - val_f1_m: 0.5091 - val_f2_m: 0.5626
# Epoch 99/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1497 - acc: 0.9590 - recall_m: 0.6642 - precision_m: 0.4777 - f1_m: 0.5341 - f2_m: 0.5957 - val_loss: 0.1598 - val_acc: 0.9528 - val_recall_m: 0.6151 - val_precision_m: 0.4503 - val_f1_m: 0.5066 - val_f2_m: 0.5608
# Epoch 100/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1633 - acc: 0.9538 - recall_m: 0.6528 - precision_m: 0.4821 - f1_m: 0.5366 - f2_m: 0.5925 - val_loss: 0.1608 - val_acc: 0.9509 - val_recall_m: 0.6151 - val_precision_m: 0.4458 - val_f1_m: 0.5028 - val_f2_m: 0.5586
# Epoch 101/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1647 - acc: 0.9613 - recall_m: 0.6472 - precision_m: 0.5030 - f1_m: 0.5502 - f2_m: 0.5973 - val_loss: 0.1622 - val_acc: 0.9547 - val_recall_m: 0.6151 - val_precision_m: 0.4526 - val_f1_m: 0.5076 - val_f2_m: 0.5611
# Epoch 102/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1802 - acc: 0.9660 - recall_m: 0.6717 - precision_m: 0.5362 - f1_m: 0.5740 - f2_m: 0.6196 - val_loss: 0.1550 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4588 - val_f1_m: 0.5131 - val_f2_m: 0.5646
# Epoch 103/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2220 - acc: 0.9557 - recall_m: 0.6208 - precision_m: 0.4847 - f1_m: 0.5244 - f2_m: 0.5704 - val_loss: 0.1586 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 104/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1733 - acc: 0.9575 - recall_m: 0.6906 - precision_m: 0.5038 - f1_m: 0.5629 - f2_m: 0.6246 - val_loss: 0.1573 - val_acc: 0.9566 - val_recall_m: 0.6151 - val_precision_m: 0.4564 - val_f1_m: 0.5106 - val_f2_m: 0.5628
# Epoch 105/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1636 - acc: 0.9604 - recall_m: 0.6774 - precision_m: 0.5019 - f1_m: 0.5543 - f2_m: 0.6121 - val_loss: 0.1568 - val_acc: 0.9566 - val_recall_m: 0.6151 - val_precision_m: 0.4564 - val_f1_m: 0.5106 - val_f2_m: 0.5628
# Epoch 106/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1404 - acc: 0.9637 - recall_m: 0.7491 - precision_m: 0.5638 - f1_m: 0.6259 - f2_m: 0.6869 - val_loss: 0.1585 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4588 - val_f1_m: 0.5131 - val_f2_m: 0.5646
# Epoch 107/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1896 - acc: 0.9627 - recall_m: 0.7223 - precision_m: 0.5483 - f1_m: 0.6013 - f2_m: 0.6589 - val_loss: 0.1563 - val_acc: 0.9566 - val_recall_m: 0.6151 - val_precision_m: 0.4564 - val_f1_m: 0.5106 - val_f2_m: 0.5628
# Epoch 108/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1503 - acc: 0.9632 - recall_m: 0.7179 - precision_m: 0.5313 - f1_m: 0.5924 - f2_m: 0.6538 - val_loss: 0.1567 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4588 - val_f1_m: 0.5131 - val_f2_m: 0.5646
# Epoch 109/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1607 - acc: 0.9613 - recall_m: 0.7057 - precision_m: 0.5481 - f1_m: 0.5950 - f2_m: 0.6476 - val_loss: 0.1532 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 110/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1543 - acc: 0.9651 - recall_m: 0.6953 - precision_m: 0.5545 - f1_m: 0.5962 - f2_m: 0.6438 - val_loss: 0.1545 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4588 - val_f1_m: 0.5131 - val_f2_m: 0.5646
# Epoch 111/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1493 - acc: 0.9651 - recall_m: 0.7198 - precision_m: 0.5549 - f1_m: 0.6029 - f2_m: 0.6588 - val_loss: 0.1529 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4564 - val_f1_m: 0.5106 - val_f2_m: 0.5628
# Epoch 112/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1531 - acc: 0.9613 - recall_m: 0.7255 - precision_m: 0.5555 - f1_m: 0.6037 - f2_m: 0.6610 - val_loss: 0.1591 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 113/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1737 - acc: 0.9566 - recall_m: 0.6836 - precision_m: 0.5232 - f1_m: 0.5708 - f2_m: 0.6244 - val_loss: 0.1580 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4564 - val_f1_m: 0.5106 - val_f2_m: 0.5628
# Epoch 114/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1520 - acc: 0.9632 - recall_m: 0.6566 - precision_m: 0.5075 - f1_m: 0.5562 - f2_m: 0.6053 - val_loss: 0.1560 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4588 - val_f1_m: 0.5131 - val_f2_m: 0.5646
# Epoch 115/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1622 - acc: 0.9623 - recall_m: 0.6717 - precision_m: 0.4974 - f1_m: 0.5549 - f2_m: 0.6122 - val_loss: 0.1538 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4588 - val_f1_m: 0.5131 - val_f2_m: 0.5646
# Epoch 116/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1926 - acc: 0.9646 - recall_m: 0.6660 - precision_m: 0.5323 - f1_m: 0.5733 - f2_m: 0.6176 - val_loss: 0.1566 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4564 - val_f1_m: 0.5106 - val_f2_m: 0.5628
# Epoch 117/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1630 - acc: 0.9599 - recall_m: 0.7321 - precision_m: 0.5302 - f1_m: 0.5903 - f2_m: 0.6562 - val_loss: 0.1550 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4564 - val_f1_m: 0.5106 - val_f2_m: 0.5628
# Epoch 118/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1624 - acc: 0.9632 - recall_m: 0.6566 - precision_m: 0.5209 - f1_m: 0.5576 - f2_m: 0.6040 - val_loss: 0.1621 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 119/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1638 - acc: 0.9665 - recall_m: 0.6849 - precision_m: 0.5660 - f1_m: 0.6014 - f2_m: 0.6415 - val_loss: 0.1572 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 120/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1614 - acc: 0.9618 - recall_m: 0.7009 - precision_m: 0.5519 - f1_m: 0.5951 - f2_m: 0.6454 - val_loss: 0.1578 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4588 - val_f1_m: 0.5131 - val_f2_m: 0.5646
# Epoch 121/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1669 - acc: 0.9599 - recall_m: 0.6242 - precision_m: 0.5015 - f1_m: 0.5433 - f2_m: 0.5843 - val_loss: 0.1596 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 122/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1641 - acc: 0.9632 - recall_m: 0.6764 - precision_m: 0.5217 - f1_m: 0.5681 - f2_m: 0.6206 - val_loss: 0.1618 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 123/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1535 - acc: 0.9590 - recall_m: 0.7358 - precision_m: 0.5260 - f1_m: 0.5941 - f2_m: 0.6645 - val_loss: 0.1619 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 124/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1672 - acc: 0.9632 - recall_m: 0.6600 - precision_m: 0.5000 - f1_m: 0.5494 - f2_m: 0.6024 - val_loss: 0.1574 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 125/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1572 - acc: 0.9637 - recall_m: 0.7047 - precision_m: 0.5106 - f1_m: 0.5698 - f2_m: 0.6338 - val_loss: 0.1618 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 126/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1766 - acc: 0.9538 - recall_m: 0.7219 - precision_m: 0.5168 - f1_m: 0.5740 - f2_m: 0.6411 - val_loss: 0.1574 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 127/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1877 - acc: 0.9656 - recall_m: 0.7028 - precision_m: 0.5717 - f1_m: 0.6102 - f2_m: 0.6543 - val_loss: 0.1559 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 128/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1498 - acc: 0.9604 - recall_m: 0.7340 - precision_m: 0.5445 - f1_m: 0.6002 - f2_m: 0.6636 - val_loss: 0.1553 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 129/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1800 - acc: 0.9571 - recall_m: 0.6726 - precision_m: 0.5008 - f1_m: 0.5535 - f2_m: 0.6104 - val_loss: 0.1565 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 130/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1508 - acc: 0.9670 - recall_m: 0.6709 - precision_m: 0.5528 - f1_m: 0.5861 - f2_m: 0.6260 - val_loss: 0.1559 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 131/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1226 - acc: 0.9651 - recall_m: 0.7283 - precision_m: 0.5500 - f1_m: 0.6084 - f2_m: 0.6669 - val_loss: 0.1567 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 132/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1184 - acc: 0.9670 - recall_m: 0.6962 - precision_m: 0.5377 - f1_m: 0.5890 - f2_m: 0.6418 - val_loss: 0.1574 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 133/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1494 - acc: 0.9651 - recall_m: 0.7019 - precision_m: 0.5372 - f1_m: 0.5902 - f2_m: 0.6448 - val_loss: 0.1591 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4550 - val_f1_m: 0.5101 - val_f2_m: 0.5629
# Epoch 134/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1312 - acc: 0.9646 - recall_m: 0.7351 - precision_m: 0.5542 - f1_m: 0.6137 - f2_m: 0.6732 - val_loss: 0.1595 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 135/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1392 - acc: 0.9642 - recall_m: 0.6170 - precision_m: 0.5047 - f1_m: 0.5435 - f2_m: 0.5802 - val_loss: 0.1604 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 136/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1451 - acc: 0.9585 - recall_m: 0.6538 - precision_m: 0.4833 - f1_m: 0.5396 - f2_m: 0.5959 - val_loss: 0.1598 - val_acc: 0.9547 - val_recall_m: 0.6151 - val_precision_m: 0.4526 - val_f1_m: 0.5076 - val_f2_m: 0.5611
# Epoch 137/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1741 - acc: 0.9594 - recall_m: 0.7075 - precision_m: 0.5266 - f1_m: 0.5810 - f2_m: 0.6410 - val_loss: 0.1619 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 138/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1961 - acc: 0.9585 - recall_m: 0.7462 - precision_m: 0.5508 - f1_m: 0.6018 - f2_m: 0.6670 - val_loss: 0.1596 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 139/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1697 - acc: 0.9656 - recall_m: 0.7075 - precision_m: 0.5566 - f1_m: 0.6030 - f2_m: 0.6531 - val_loss: 0.1604 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 140/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1536 - acc: 0.9642 - recall_m: 0.7132 - precision_m: 0.5602 - f1_m: 0.6029 - f2_m: 0.6551 - val_loss: 0.1558 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 141/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1480 - acc: 0.9665 - recall_m: 0.7679 - precision_m: 0.5974 - f1_m: 0.6435 - f2_m: 0.7011 - val_loss: 0.1563 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 142/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1750 - acc: 0.9642 - recall_m: 0.6906 - precision_m: 0.5132 - f1_m: 0.5647 - f2_m: 0.6251 - val_loss: 0.1575 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 143/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1718 - acc: 0.9608 - recall_m: 0.6660 - precision_m: 0.5002 - f1_m: 0.5517 - f2_m: 0.6058 - val_loss: 0.1575 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 144/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1519 - acc: 0.9599 - recall_m: 0.6736 - precision_m: 0.4894 - f1_m: 0.5440 - f2_m: 0.6040 - val_loss: 0.1604 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 145/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1870 - acc: 0.9618 - recall_m: 0.6481 - precision_m: 0.5157 - f1_m: 0.5579 - f2_m: 0.6019 - val_loss: 0.1596 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4588 - val_f1_m: 0.5131 - val_f2_m: 0.5646
# Epoch 146/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1497 - acc: 0.9627 - recall_m: 0.6340 - precision_m: 0.5006 - f1_m: 0.5411 - f2_m: 0.5851 - val_loss: 0.1603 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 147/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1506 - acc: 0.9599 - recall_m: 0.7434 - precision_m: 0.5387 - f1_m: 0.6066 - f2_m: 0.6741 - val_loss: 0.1580 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4588 - val_f1_m: 0.5131 - val_f2_m: 0.5646
# Epoch 148/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1565 - acc: 0.9604 - recall_m: 0.6921 - precision_m: 0.5260 - f1_m: 0.5750 - f2_m: 0.6298 - val_loss: 0.1554 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4588 - val_f1_m: 0.5131 - val_f2_m: 0.5646
# Epoch 149/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1578 - acc: 0.9585 - recall_m: 0.6434 - precision_m: 0.4917 - f1_m: 0.5400 - f2_m: 0.5900 - val_loss: 0.1558 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 150/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1681 - acc: 0.9599 - recall_m: 0.6736 - precision_m: 0.5191 - f1_m: 0.5632 - f2_m: 0.6157 - val_loss: 0.1558 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 151/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2026 - acc: 0.9575 - recall_m: 0.6632 - precision_m: 0.5194 - f1_m: 0.5575 - f2_m: 0.6065 - val_loss: 0.1555 - val_acc: 0.9623 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 152/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1558 - acc: 0.9679 - recall_m: 0.7289 - precision_m: 0.5842 - f1_m: 0.6249 - f2_m: 0.6747 - val_loss: 0.1586 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 153/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1465 - acc: 0.9623 - recall_m: 0.7226 - precision_m: 0.5358 - f1_m: 0.5946 - f2_m: 0.6572 - val_loss: 0.1592 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 154/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1737 - acc: 0.9627 - recall_m: 0.7170 - precision_m: 0.5713 - f1_m: 0.6145 - f2_m: 0.6624 - val_loss: 0.1624 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 155/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1825 - acc: 0.9571 - recall_m: 0.6392 - precision_m: 0.4953 - f1_m: 0.5314 - f2_m: 0.5800 - val_loss: 0.1583 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 156/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1558 - acc: 0.9604 - recall_m: 0.6387 - precision_m: 0.4798 - f1_m: 0.5314 - f2_m: 0.5835 - val_loss: 0.1594 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 157/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1798 - acc: 0.9618 - recall_m: 0.6364 - precision_m: 0.4811 - f1_m: 0.5294 - f2_m: 0.5806 - val_loss: 0.1578 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4582 - val_f1_m: 0.5131 - val_f2_m: 0.5648
# Epoch 158/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1623 - acc: 0.9608 - recall_m: 0.6453 - precision_m: 0.4709 - f1_m: 0.5266 - f2_m: 0.5835 - val_loss: 0.1565 - val_acc: 0.9604 - val_recall_m: 0.6151 - val_precision_m: 0.4620 - val_f1_m: 0.5161 - val_f2_m: 0.5666
# Epoch 159/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1727 - acc: 0.9642 - recall_m: 0.6642 - precision_m: 0.4962 - f1_m: 0.5510 - f2_m: 0.6073 - val_loss: 0.1588 - val_acc: 0.9585 - val_recall_m: 0.6151 - val_precision_m: 0.4588 - val_f1_m: 0.5131 - val_f2_m: 0.5646
# Epoch 160/300
# 2120/2120 [==============================] - 54s 26ms/step - loss: 0.1681 - acc: 0.9627 - recall_m: 0.6764 - precision_m: 0.4955 - f1_m: 0.5521 - f2_m: 0.6118 - val_loss: 0.1592 - val_acc: 0.9547 - val_recall_m: 0.6151 - val_precision_m: 0.4526 - val_f1_m: 0.5076 - val_f2_m: 0.5611
# Epoch 161/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1421 - acc: 0.9670 - recall_m: 0.6708 - precision_m: 0.5485 - f1_m: 0.5879 - f2_m: 0.6288 - val_loss: 0.1618 - val_acc: 0.9566 - val_recall_m: 0.6151 - val_precision_m: 0.4564 - val_f1_m: 0.5106 - val_f2_m: 0.5628
# Epoch 00161: early stopping

# %%
def plot_history(history):
  plt.figure(figsize=(12,15))
  plt.subplot(3,2,1)
  name = 'loss'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,2)
  name = 'acc'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,3)
  name = 'recall_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,4)
  name = 'precision_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,5)
  name = 'f1_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,6)
  name = 'f2_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

plot_history(history)

# %%
from sklearn.metrics import recall_score, precision_score, f1_score, fbeta_score, cohen_kappa_score, roc_auc_score, accuracy_score

model.load_weights(f"/content/gdrive/My Drive/CNN_LSTM_{I}_adj_watermask_5day.hdf5")
preds = model.predict([x_val_0, x_val_1, x_val_2, num_val_0, num_val_1, num_val_2, adj_val_0, adj_val_1, adj_val_2])

print(recall_score(y_val, preds.round()))
print(fbeta_score(y_val, preds.round(), 2))
print(f1_score(y_val, preds.round()))
print(cohen_kappa_score(y_val, preds.round().flatten()))
print(roc_auc_score(y_val, preds.round()))
print(accuracy_score(y_val, preds.round()))
print(precision_score(y_val, preds.round()))
np.save(f'/content/gdrive/My Drive/preds_{I}', preds.flatten())
# Out:
# 0.975
# 0.8863636363636362
# 0.78
# 0.7580912863070539
# 0.9660714285714287
# 0.9584905660377359
# 0.65
