# %%
import os
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
from PIL import Image
import matplotlib
from sklearn.model_selection import StratifiedKFold
import keras
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, TensorBoard
from keras import optimizers
from keras.models import Model
from keras.layers import Input, Dropout, UpSampling2D, BatchNormalization, Activation, Dense, Lambda, TimeDistributed, Flatten
from keras.layers import LSTM, GRU, RNN, Reshape, CuDNNGRU, CuDNNLSTM
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, MaxPooling3D
from keras.layers.merge import concatenate
from keras.models import Sequential
from keras.layers.convolutional import Conv3D
from keras.layers.convolutional_recurrent import ConvLSTM2D
from keras import backend as K
from keras.losses import binary_crossentropy
from keras.optimizers import Adam
from keras.optimizers import Adam
from keras.callbacks import Callback
import tensorflow as tf
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import confusion_matrix
import tensorflow as tf
import gc
import torch
from torch.utils.data import Dataset, DataLoader
from keras import layers, models, applications
from keras.layers import concatenate
from matplotlib import pyplot as plt
import tensorflow as tf
from torch.utils.data import Dataset, DataLoader
from keras import layers, models, applications
import albumentations
from albumentations import (
    HorizontalFlip, VerticalFlip, IAAPerspective, ShiftScaleRotate, CLAHE, RandomRotate90, ToFloat,
    Transpose, ShiftScaleRotate, Blur, OpticalDistortion, GridDistortion, HueSaturationValue,
    IAAAdditiveGaussianNoise, GaussNoise, MotionBlur, MedianBlur, IAAPiecewiseAffine, 
    IAASharpen, IAAEmboss, RandomContrast, RandomBrightness, Flip, OneOf, Compose, RandomGamma, ElasticTransform, ChannelShuffle,RGBShift, Rotate
)

from keras.backend.tensorflow_backend import set_session
from keras.backend.tensorflow_backend import clear_session
from keras.backend.tensorflow_backend import get_session
import tensorflow
# Reset Keras Session
def reset_keras():
    sess = get_session()
    clear_session()
    sess.close()
    sess = get_session()
    try:
        del classifier # this is from global space - change this as you need
    except:
        pass

    print(gc.collect()) # if it's done something you should see a number being outputted

    # use the same config as you used to create the session
    config = tensorflow.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 1
    config.gpu_options.visible_device_list = "0"
    set_session(tensorflow.Session(config=config))

def random_everything(seed=42):
  os.environ['PYTHONHASHSEED'] = str(42)
  random.seed(42)
  np.random.seed(42)
  tf.set_random_seed(42)

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

def f2_m(y_true, y_pred, beta=2):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return (1+beta**2) * (precision*recall) / ((beta**2)*(precision)+recall+K.epsilon())

'''
a = []
while(1):
  a.append('1')
'''
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# "\na = []\nwhile(1):\n  a.append('1')\n"

# %%
from google.colab import drive
#drive.mount('/content/gdrive')
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
def generate_sector(imgs, labs, idx=0):
  assert idx <= 24
  alphabets = "ABCDEFGHIJKLMNOPQRSTUVW"
  name = alphabets[idx]
  row_idx = idx//5
  col_idx = idx%5
  return imgs[:108, row_idx*200:(row_idx+1)*200, col_idx*200:(col_idx+1)*200, :], labs[:, row_idx*200:(row_idx+1)*200, col_idx*200:(col_idx+1)*200, :]

def calculate_burnt_ratio(labs):
  ratio = np.zeros((labs.shape[0],))
  for i in range(len(labs)):
    ratio[i] = labs[i,:,:,:].mean()
  return ratio

def generate_sectos_combined(imgs, labs, indices=np.arange(20)):
  combined_imgs, combined_labs = generate_sector(imgs, labs, indices[0])
  for idx in range(1, len(indices)):
    sector_imgs, sector_labs = generate_sector(imgs, labs, idx)
    combined_imgs = np.concatenate([combined_imgs, sector_imgs], 0)
    combined_labs = np.concatenate([combined_labs, sector_labs], 0)
  combined_area = calculate_burnt_ratio(combined_labs)
  return combined_imgs, combined_area

def binarize(y, thres=0.05):
  return (y>thres).astype(int)

def dissect_data(imgs, labs, size=108):
  idx = np.array([i for i in range(len(imgs)) if i%size not in [size-2, size-1, size]])
  imgs_0 = imgs[idx, :,:,:]
  imgs_1 = imgs[idx+1, :,:,:]
  imgs_2 = imgs[idx+2, :,:,:]
  labs   = binarize(labs[idx+2])
  return imgs_0, imgs_1, imgs_2, labs

# %%
water_mask = np.load('/content/gdrive/My Drive/water_mask_based_on_ndvi_565.npy')
water_mask = np.expand_dims(water_mask, 2)

# %%
I = 3
trn_idx = [i for i in range(25) if i not in range(5*I, 5*I+5)]
val_idx = [i for i in range(25) if i in range(5*I, 5*I+5)]

imgs = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['imgs']
dnbr = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['dnbr']
labs = (dnbr>0.66).astype(int)
del dnbr
gc.collect()
### apply water mask
for i in range(len(labs)):
  labs[i,:][water_mask==1] = 0

x_trn, y_trn = generate_sectos_combined(imgs, labs, indices=trn_idx)
del imgs, labs
gc.collect()
## normalize
x_trn = x_trn.astype('float32')
x_trn = x_trn / x_trn.max()

x_trn_0, x_trn_1, x_trn_2, y_trn = dissect_data(x_trn, y_trn)
del x_trn
gc.collect()
# Out:
# 0

# %%
imgs = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['imgs']
dnbr = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['dnbr']
labs = (dnbr>0.66).astype(int)
del dnbr
gc.collect()
### apply water mask
for i in range(len(labs)):
  labs[i,:][water_mask==1] = 0

x_val, y_val = generate_sectos_combined(imgs, labs, indices=val_idx)
del imgs, labs
gc.collect()
## normalize
x_val = x_val.astype('float32')
x_val = x_val / x_val.max()

x_val_0, x_val_1, x_val_2, y_val = dissect_data(x_val, y_val)
del x_val
gc.collect()

del water_mask
gc.collect()
# Out:
# 0

# %%
gsod = pd.read_csv('/content/gdrive/My Drive/flinders_chase_clean_5day.csv').values
gsod = np.array(gsod, dtype='float')
## normalize
gsod = gsod/gsod.max(axis=0)

num_trn_0, num_trn_1, num_trn_2 = gsod[:-2,:], gsod[1:-1,:], gsod[2:,:10]
num_val_0, num_val_1, num_val_2 = gsod[:-2,:], gsod[1:-1,:], gsod[2:,:10]
for i in range(len(trn_idx)-1):
  num_trn_0 = np.concatenate([num_trn_0, gsod[:-2,:]])
  num_trn_1 = np.concatenate([num_trn_1, gsod[1:-1,:]])
  ### the last series should only have day_0 data!
  num_trn_2 = np.concatenate([num_trn_2, gsod[2:,:10]])
for i in range(len(val_idx)-1):
  num_val_0 = np.concatenate([num_val_0, gsod[:-2,:]])
  num_val_1 = np.concatenate([num_val_1, gsod[1:-1,:]])
  ### the last series should only have day_0 data!
  num_val_2 = np.concatenate([num_val_2, gsod[2:,:10]])

# %%
trn_adjacency = pd.read_csv('/content/gdrive/My Drive/trn_adjacency.csv')
val_adjacency = pd.read_csv('/content/gdrive/My Drive/val_adjacency.csv')
sub_columns = [i for i in trn_adjacency.columns if i.startswith(f"f_{I}")]
trn_adjacency = trn_adjacency[sub_columns]
val_adjacency = val_adjacency[sub_columns]

## normalize
MAX = pd.concat([trn_adjacency, val_adjacency], 0).max()
trn_adjacency = trn_adjacency/MAX
val_adjacency = val_adjacency/MAX

s = 0
adj_trn_0 = trn_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 1
adj_trn_1 = trn_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 2
adj_trn_2 = trn_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]

s = 0
adj_val_0 = val_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 1
adj_val_1 = val_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 2
adj_val_2 = val_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]

# %%
def ConvBlock(inputs, suffix=0, prefix="cnn"):
    """no final linear dense layer!"""
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_1a")(inputs)
    conv1 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_1a")(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_1b")(conv1)
    conv1 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_1b")(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2), name=f"{prefix}_{suffix}_maxpool_1")(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_2a")(pool1)
    conv2 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_2a")(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_2b")(conv2)
    conv2 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_2b")(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2), name=f"index_{suffix}_maxpool_2")(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_3a")(pool2)
    conv3 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_3a")(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_3b")(conv3)
    conv3 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_3b")(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2), name=f"index_{suffix}_maxpool_3")(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_4a")(pool3)
    conv4 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_4a")(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_4b")(conv4)
    conv4 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_4b")(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2), name=f"{prefix}_{suffix}_maxpool_4")(conv4)    
    
    flatten= Flatten(name=f"{prefix}_{suffix}_flatten")(pool4)
    dense1 = Dense(64, activation="relu", name=f"{prefix}_{suffix}_relu_1")(flatten)
    drop1  = Dropout(0.4, name=f"{prefix}_{suffix}_drop_1")(dense1)
    dense2 = Dense(32, activation="relu", name=f"{prefix}_{suffix}_relu_2")(drop1)
    drop2  = Dropout(0.3, name=f"{prefix}_{suffix}_drop_2")(dense2)
    dense3 = Dense(16, activation="relu", name=f"{prefix}_{suffix}_relu_3")(drop2)
    drop3  = Dropout(0.2, name=f"{prefix}_{suffix}_drop_3")(dense3)
    dense4 = Dense(8, activation="relu",  name=f"{prefix}_{suffix}_relu_4")(drop3)
    #dense4 = Dense(1, activation="linear", name=f"{prefix}_{suffix}_linear")(drop3)
    return dense4

def MLP(inputs, suffix=0, prefix='mlp'):
    dense = Dense(8, activation='relu', name=f"{prefix}_{suffix}_relu_1")(inputs)
    dense = Dense(4, activation='relu', name=f"{prefix}_{suffix}_relu_2")(dense)
    #dense = Dense(1, activation='linear', name=f"{prefix}_{suffix}_linear")(dense)
    return dense

# %%
n_channels = 14
sector_dim = 200

img_0 = Input((sector_dim,sector_dim,n_channels), name="cnn_input_0")
img_1 = Input((sector_dim,sector_dim,n_channels), name="cnn_input_1")
img_2 = Input((sector_dim,sector_dim,n_channels), name="cnn_input_2")

num_0 = Input((50,), name="gsod_input_0")
num_1 = Input((50,), name="gsod_input_1")
num_2 = Input((10,), name="gsod_input_2")

adj_0 = Input((8,), name="adj_input_0")
adj_1 = Input((8,), name="adj_input_1")
adj_2 = Input((8,), name="adj_input_2")

cnn_0 = ConvBlock(img_0, suffix=0)
cnn_1 = ConvBlock(img_1, suffix=1)
cnn_2 = ConvBlock(img_2, suffix=2)

num_0_m = MLP(num_0, suffix=0, prefix="gsod")
num_1_m = MLP(num_1, suffix=1, prefix="gsod")
num_2_m = MLP(num_2, suffix=2, prefix="gsod")

adj_0_m = MLP(adj_0, suffix=0, prefix="adj")
adj_1_m = MLP(adj_1, suffix=1, prefix="adj")
adj_2_m = MLP(adj_2, suffix=2, prefix="adj")

mixed_0 = concatenate([cnn_0, num_0_m, adj_0_m], name='mixed_0')
mixed_1 = concatenate([cnn_1, num_1_m, adj_0_m], name='mixed_1')
mixed_2 = concatenate([cnn_2, num_2_m, adj_0_m], name='mixed_2')

concat   = concatenate([mixed_0, mixed_1, mixed_2], name="concat_mixed")
reshape    = Reshape((3, -1), name="reshape")(concat)
lstm       = CuDNNLSTM(256, name='lstm_1', return_sequences=True)(reshape)
lstm       = Dropout(0.4, name='lstm_drop_1')(lstm)
lstm       = CuDNNLSTM(256, name='lstm_2')(lstm)
lstm       = Dropout(0.4, name='lstm_drop_2')(lstm)
dense      = Dense(10, activation="relu", name="fc_relu")(lstm)
dense      = Dense(1, activation="sigmoid", name="fc_sigmoid")(dense)

model = Model(inputs=[img_0, img_1, img_2, num_0, num_1, num_2, adj_0, adj_1, adj_2], output=dense)
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# cnn_input_0 (InputLayer)        (None, 200, 200, 14) 0
# __________________________________________________________________________________________________
# cnn_input_1 (InputLayer)        (None, 200, 200, 14) 0
# __________________________________________________________________________________________________
# cnn_input_2 (InputLayer)        (None, 200, 200, 14) 0
# __________________________________________________________________________________________________
# cnn_0_conv_1a (Conv2D)          (None, 200, 200, 64) 8128        cnn_input_0[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_1a (Conv2D)          (None, 200, 200, 64) 8128        cnn_input_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_1a (Conv2D)          (None, 200, 200, 64) 8128        cnn_input_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_1a (BatchNormal (None, 200, 200, 64) 256         cnn_0_conv_1a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_1a (BatchNormal (None, 200, 200, 64) 256         cnn_1_conv_1a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_1a (BatchNormal (None, 200, 200, 64) 256         cnn_2_conv_1a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_1b (Conv2D)          (None, 200, 200, 64) 36928       cnn_0_batchnorm_1a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_1b (Conv2D)          (None, 200, 200, 64) 36928       cnn_1_batchnorm_1a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_1b (Conv2D)          (None, 200, 200, 64) 36928       cnn_2_batchnorm_1a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_1b (BatchNormal (None, 200, 200, 64) 256         cnn_0_conv_1b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_1b (BatchNormal (None, 200, 200, 64) 256         cnn_1_conv_1b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_1b (BatchNormal (None, 200, 200, 64) 256         cnn_2_conv_1b[0][0]
# __________________________________________________________________________________________________
# cnn_0_maxpool_1 (MaxPooling2D)  (None, 100, 100, 64) 0           cnn_0_batchnorm_1b[0][0]
# __________________________________________________________________________________________________
# cnn_1_maxpool_1 (MaxPooling2D)  (None, 100, 100, 64) 0           cnn_1_batchnorm_1b[0][0]
# __________________________________________________________________________________________________
# cnn_2_maxpool_1 (MaxPooling2D)  (None, 100, 100, 64) 0           cnn_2_batchnorm_1b[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_2a (Conv2D)          (None, 100, 100, 128 73856       cnn_0_maxpool_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_2a (Conv2D)          (None, 100, 100, 128 73856       cnn_1_maxpool_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_2a (Conv2D)          (None, 100, 100, 128 73856       cnn_2_maxpool_1[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_2a (BatchNormal (None, 100, 100, 128 512         cnn_0_conv_2a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_2a (BatchNormal (None, 100, 100, 128 512         cnn_1_conv_2a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_2a (BatchNormal (None, 100, 100, 128 512         cnn_2_conv_2a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_2b (Conv2D)          (None, 100, 100, 128 147584      cnn_0_batchnorm_2a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_2b (Conv2D)          (None, 100, 100, 128 147584      cnn_1_batchnorm_2a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_2b (Conv2D)          (None, 100, 100, 128 147584      cnn_2_batchnorm_2a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_2b (BatchNormal (None, 100, 100, 128 512         cnn_0_conv_2b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_2b (BatchNormal (None, 100, 100, 128 512         cnn_1_conv_2b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_2b (BatchNormal (None, 100, 100, 128 512         cnn_2_conv_2b[0][0]
# __________________________________________________________________________________________________
# index_0_maxpool_2 (MaxPooling2D (None, 50, 50, 128)  0           cnn_0_batchnorm_2b[0][0]
# __________________________________________________________________________________________________
# index_1_maxpool_2 (MaxPooling2D (None, 50, 50, 128)  0           cnn_1_batchnorm_2b[0][0]
# __________________________________________________________________________________________________
# index_2_maxpool_2 (MaxPooling2D (None, 50, 50, 128)  0           cnn_2_batchnorm_2b[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_3a (Conv2D)          (None, 50, 50, 256)  295168      index_0_maxpool_2[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_3a (Conv2D)          (None, 50, 50, 256)  295168      index_1_maxpool_2[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_3a (Conv2D)          (None, 50, 50, 256)  295168      index_2_maxpool_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_3a (BatchNormal (None, 50, 50, 256)  1024        cnn_0_conv_3a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_3a (BatchNormal (None, 50, 50, 256)  1024        cnn_1_conv_3a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_3a (BatchNormal (None, 50, 50, 256)  1024        cnn_2_conv_3a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_3b (Conv2D)          (None, 50, 50, 256)  590080      cnn_0_batchnorm_3a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_3b (Conv2D)          (None, 50, 50, 256)  590080      cnn_1_batchnorm_3a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_3b (Conv2D)          (None, 50, 50, 256)  590080      cnn_2_batchnorm_3a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_3b (BatchNormal (None, 50, 50, 256)  1024        cnn_0_conv_3b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_3b (BatchNormal (None, 50, 50, 256)  1024        cnn_1_conv_3b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_3b (BatchNormal (None, 50, 50, 256)  1024        cnn_2_conv_3b[0][0]
# __________________________________________________________________________________________________
# index_0_maxpool_3 (MaxPooling2D (None, 25, 25, 256)  0           cnn_0_batchnorm_3b[0][0]
# __________________________________________________________________________________________________
# index_1_maxpool_3 (MaxPooling2D (None, 25, 25, 256)  0           cnn_1_batchnorm_3b[0][0]
# __________________________________________________________________________________________________
# index_2_maxpool_3 (MaxPooling2D (None, 25, 25, 256)  0           cnn_2_batchnorm_3b[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_4a (Conv2D)          (None, 25, 25, 512)  1180160     index_0_maxpool_3[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_4a (Conv2D)          (None, 25, 25, 512)  1180160     index_1_maxpool_3[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_4a (Conv2D)          (None, 25, 25, 512)  1180160     index_2_maxpool_3[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_4a (BatchNormal (None, 25, 25, 512)  2048        cnn_0_conv_4a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_4a (BatchNormal (None, 25, 25, 512)  2048        cnn_1_conv_4a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_4a (BatchNormal (None, 25, 25, 512)  2048        cnn_2_conv_4a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_4b (Conv2D)          (None, 25, 25, 512)  2359808     cnn_0_batchnorm_4a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_4b (Conv2D)          (None, 25, 25, 512)  2359808     cnn_1_batchnorm_4a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_4b (Conv2D)          (None, 25, 25, 512)  2359808     cnn_2_batchnorm_4a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_4b (BatchNormal (None, 25, 25, 512)  2048        cnn_0_conv_4b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_4b (BatchNormal (None, 25, 25, 512)  2048        cnn_1_conv_4b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_4b (BatchNormal (None, 25, 25, 512)  2048        cnn_2_conv_4b[0][0]
# __________________________________________________________________________________________________
# cnn_0_maxpool_4 (MaxPooling2D)  (None, 12, 12, 512)  0           cnn_0_batchnorm_4b[0][0]
# __________________________________________________________________________________________________
# cnn_1_maxpool_4 (MaxPooling2D)  (None, 12, 12, 512)  0           cnn_1_batchnorm_4b[0][0]
# __________________________________________________________________________________________________
# cnn_2_maxpool_4 (MaxPooling2D)  (None, 12, 12, 512)  0           cnn_2_batchnorm_4b[0][0]
# __________________________________________________________________________________________________
# cnn_0_flatten (Flatten)         (None, 73728)        0           cnn_0_maxpool_4[0][0]
# __________________________________________________________________________________________________
# cnn_1_flatten (Flatten)         (None, 73728)        0           cnn_1_maxpool_4[0][0]
# __________________________________________________________________________________________________
# cnn_2_flatten (Flatten)         (None, 73728)        0           cnn_2_maxpool_4[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_1 (Dense)            (None, 64)           4718656     cnn_0_flatten[0][0]
# __________________________________________________________________________________________________
# cnn_1_relu_1 (Dense)            (None, 64)           4718656     cnn_1_flatten[0][0]
# __________________________________________________________________________________________________
# cnn_2_relu_1 (Dense)            (None, 64)           4718656     cnn_2_flatten[0][0]
# __________________________________________________________________________________________________
# cnn_0_drop_1 (Dropout)          (None, 64)           0           cnn_0_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_drop_1 (Dropout)          (None, 64)           0           cnn_1_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_drop_1 (Dropout)          (None, 64)           0           cnn_2_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_2 (Dense)            (None, 32)           2080        cnn_0_drop_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_relu_2 (Dense)            (None, 32)           2080        cnn_1_drop_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_relu_2 (Dense)            (None, 32)           2080        cnn_2_drop_1[0][0]
# __________________________________________________________________________________________________
# cnn_0_drop_2 (Dropout)          (None, 32)           0           cnn_0_relu_2[0][0]
# __________________________________________________________________________________________________
# cnn_1_drop_2 (Dropout)          (None, 32)           0           cnn_1_relu_2[0][0]
# __________________________________________________________________________________________________
# cnn_2_drop_2 (Dropout)          (None, 32)           0           cnn_2_relu_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_3 (Dense)            (None, 16)           528         cnn_0_drop_2[0][0]
# __________________________________________________________________________________________________
# gsod_input_0 (InputLayer)       (None, 50)           0
# __________________________________________________________________________________________________
# adj_input_0 (InputLayer)        (None, 8)            0
# __________________________________________________________________________________________________
# cnn_1_relu_3 (Dense)            (None, 16)           528         cnn_1_drop_2[0][0]
# __________________________________________________________________________________________________
# gsod_input_1 (InputLayer)       (None, 50)           0
# __________________________________________________________________________________________________
# cnn_2_relu_3 (Dense)            (None, 16)           528         cnn_2_drop_2[0][0]
# __________________________________________________________________________________________________
# gsod_input_2 (InputLayer)       (None, 10)           0
# __________________________________________________________________________________________________
# cnn_0_drop_3 (Dropout)          (None, 16)           0           cnn_0_relu_3[0][0]
# __________________________________________________________________________________________________
# gsod_0_relu_1 (Dense)           (None, 8)            408         gsod_input_0[0][0]
# __________________________________________________________________________________________________
# adj_0_relu_1 (Dense)            (None, 8)            72          adj_input_0[0][0]
# __________________________________________________________________________________________________
# cnn_1_drop_3 (Dropout)          (None, 16)           0           cnn_1_relu_3[0][0]
# __________________________________________________________________________________________________
# gsod_1_relu_1 (Dense)           (None, 8)            408         gsod_input_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_drop_3 (Dropout)          (None, 16)           0           cnn_2_relu_3[0][0]
# __________________________________________________________________________________________________
# gsod_2_relu_1 (Dense)           (None, 8)            88          gsod_input_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_4 (Dense)            (None, 8)            136         cnn_0_drop_3[0][0]
# __________________________________________________________________________________________________
# gsod_0_relu_2 (Dense)           (None, 4)            36          gsod_0_relu_1[0][0]
# __________________________________________________________________________________________________
# adj_0_relu_2 (Dense)            (None, 4)            36          adj_0_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_relu_4 (Dense)            (None, 8)            136         cnn_1_drop_3[0][0]
# __________________________________________________________________________________________________
# gsod_1_relu_2 (Dense)           (None, 4)            36          gsod_1_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_relu_4 (Dense)            (None, 8)            136         cnn_2_drop_3[0][0]
# __________________________________________________________________________________________________
# gsod_2_relu_2 (Dense)           (None, 4)            36          gsod_2_relu_1[0][0]
# __________________________________________________________________________________________________
# mixed_0 (Concatenate)           (None, 16)           0           cnn_0_relu_4[0][0]
#                                                                  gsod_0_relu_2[0][0]
#                                                                  adj_0_relu_2[0][0]
# __________________________________________________________________________________________________
# mixed_1 (Concatenate)           (None, 16)           0           cnn_1_relu_4[0][0]
#                                                                  gsod_1_relu_2[0][0]
#                                                                  adj_0_relu_2[0][0]
# __________________________________________________________________________________________________
# mixed_2 (Concatenate)           (None, 16)           0           cnn_2_relu_4[0][0]
#                                                                  gsod_2_relu_2[0][0]
#                                                                  adj_0_relu_2[0][0]
# __________________________________________________________________________________________________
# concat_mixed (Concatenate)      (None, 48)           0           mixed_0[0][0]
#                                                                  mixed_1[0][0]
#                                                                  mixed_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 3, 16)        0           concat_mixed[0][0]
# __________________________________________________________________________________________________
# lstm_1 (CuDNNLSTM)              (None, 3, 256)       280576      reshape[0][0]
# __________________________________________________________________________________________________
# lstm_drop_1 (Dropout)           (None, 3, 256)       0           lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (CuDNNLSTM)              (None, 256)          526336      lstm_drop_1[0][0]
# __________________________________________________________________________________________________
# lstm_drop_2 (Dropout)           (None, 256)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# fc_relu (Dense)                 (None, 10)           2570        lstm_drop_2[0][0]
# __________________________________________________________________________________________________
# fc_sigmoid (Dense)              (None, 1)            11          fc_relu[0][0]
# ==================================================================================================
# Total params: 29,072,989
# Trainable params: 29,061,469
# Non-trainable params: 11,520
# __________________________________________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("fc...)`

# %%
def custom_loss(y_true, y_pred):
  crossentropy_loss = K.binary_crossentropy(y_true, y_pred)
  weight  = (y_true*9)+1
  return crossentropy_loss*(weight)

# %%
from sklearn.metrics import recall_score, precision_score, f1_score, fbeta_score, cohen_kappa_score, roc_auc_score, accuracy_score
'''
model.compile(optimizer = Adam(lr=1e-4, decay=1e-6), 
              loss=custom_loss,
              metrics=['acc', recall_m, precision_m, f1_m, f2_m])
model.load_weights(f"/content/gdrive/My Drive/CNN_LSTM_{I}_adj_watermask_5day.hdf5")
preds = model.predict([x_val_0, x_val_1, x_val_2, num_val_0, num_val_1, num_val_2, adj_val_0, adj_val_1, adj_val_2])

print(recall_score(y_val, preds.round()))
print(precision_score(y_val, preds.round()))
print(f1_score(y_val, preds.round()))
print(fbeta_score(y_val, preds.round(), 2))
print(cohen_kappa_score(y_val, preds.round().flatten()))
print(roc_auc_score(y_val, preds.round()))
print(accuracy_score(y_val, preds.round()))
'''

# %%
random_everything(seed=42)
#model = Model(inputs=[img_0, img_1, img_2, num_0, num_1, num_2, adj_0, adj_1, adj_2], output=dense)

model.compile(optimizer = Adam(lr=1e-4, decay=1e-6), 
              loss=custom_loss,
              metrics=['acc', recall_m, precision_m, f1_m, f2_m])

ckpt = ModelCheckpoint(f"/content/gdrive/My Drive/CNN_LSTM_{I}_adj_watermask_5day.hdf5", monitor = "val_loss", save_best_only = True, mode = "min", save_weights_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

history = model.fit([x_trn_0, x_trn_1, x_trn_2, num_trn_0, num_trn_1, num_trn_2, adj_trn_0, adj_trn_1, adj_trn_2], y_trn,
                        validation_data=([x_val_0, x_val_1, x_val_2, num_val_0, num_val_1, num_val_2, adj_val_0, adj_val_1, adj_val_2], y_val),
                        batch_size=24, epochs=300,
                        callbacks=[es, ckpt, 
                                   keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7)
                                   ]
                        )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 2120 samples, validate on 530 samples
# Epoch 1/300
# 2120/2120 [==============================] - 71s 34ms/step - loss: 0.9554 - acc: 0.9175 - recall_m: 0.0174 - precision_m: 0.0161 - f1_m: 0.0109 - f2_m: 0.0129 - val_loss: 1.1489 - val_acc: 0.9264 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_f1_m: 0.0000e+00 - val_f2_m: 0.0000e+00
# Epoch 2/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.9104 - acc: 0.9453 - recall_m: 0.0160 - precision_m: 0.0453 - f1_m: 0.0234 - f2_m: 0.0183 - val_loss: 1.0769 - val_acc: 0.8189 - val_recall_m: 0.2054 - val_precision_m: 0.0981 - val_f1_m: 0.1179 - val_f2_m: 0.1495
# Epoch 3/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8523 - acc: 0.9127 - recall_m: 0.1925 - precision_m: 0.1485 - f1_m: 0.1521 - f2_m: 0.1686 - val_loss: 1.0712 - val_acc: 0.8925 - val_recall_m: 0.2631 - val_precision_m: 0.2596 - val_f1_m: 0.2168 - val_f2_m: 0.2326
# Epoch 4/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8020 - acc: 0.8670 - recall_m: 0.3528 - precision_m: 0.2145 - f1_m: 0.2438 - f2_m: 0.2882 - val_loss: 1.0689 - val_acc: 0.9208 - val_recall_m: 0.1698 - val_precision_m: 0.2698 - val_f1_m: 0.2005 - val_f2_m: 0.1788
# Epoch 5/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7397 - acc: 0.8717 - recall_m: 0.3821 - precision_m: 0.1991 - f1_m: 0.2413 - f2_m: 0.3006 - val_loss: 1.0482 - val_acc: 0.8547 - val_recall_m: 0.3553 - val_precision_m: 0.2043 - val_f1_m: 0.2424 - val_f2_m: 0.2894
# Epoch 6/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7312 - acc: 0.8278 - recall_m: 0.5123 - precision_m: 0.1916 - f1_m: 0.2569 - f2_m: 0.3520 - val_loss: 0.9120 - val_acc: 0.9019 - val_recall_m: 0.3278 - val_precision_m: 0.3016 - val_f1_m: 0.2906 - val_f2_m: 0.3065
# Epoch 7/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7208 - acc: 0.8585 - recall_m: 0.3925 - precision_m: 0.2108 - f1_m: 0.2526 - f2_m: 0.3100 - val_loss: 0.8816 - val_acc: 0.8321 - val_recall_m: 0.4070 - val_precision_m: 0.2342 - val_f1_m: 0.2578 - val_f2_m: 0.3154
# Epoch 8/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6609 - acc: 0.8410 - recall_m: 0.4253 - precision_m: 0.1944 - f1_m: 0.2514 - f2_m: 0.3238 - val_loss: 0.6158 - val_acc: 0.8189 - val_recall_m: 0.5833 - val_precision_m: 0.2420 - val_f1_m: 0.3284 - val_f2_m: 0.4338
# Epoch 9/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6120 - acc: 0.8618 - recall_m: 0.5349 - precision_m: 0.2596 - f1_m: 0.3236 - f2_m: 0.4085 - val_loss: 0.6853 - val_acc: 0.8642 - val_recall_m: 0.5062 - val_precision_m: 0.3092 - val_f1_m: 0.3553 - val_f2_m: 0.4197
# Epoch 10/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5862 - acc: 0.8854 - recall_m: 0.4915 - precision_m: 0.2655 - f1_m: 0.3199 - f2_m: 0.3925 - val_loss: 0.9170 - val_acc: 0.8509 - val_recall_m: 0.4647 - val_precision_m: 0.2862 - val_f1_m: 0.3251 - val_f2_m: 0.3816
# Epoch 11/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6330 - acc: 0.8552 - recall_m: 0.4698 - precision_m: 0.2248 - f1_m: 0.2826 - f2_m: 0.3592 - val_loss: 0.7535 - val_acc: 0.8170 - val_recall_m: 0.5364 - val_precision_m: 0.2394 - val_f1_m: 0.3138 - val_f2_m: 0.4029
# Epoch 12/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6177 - acc: 0.8807 - recall_m: 0.4500 - precision_m: 0.2353 - f1_m: 0.2869 - f2_m: 0.3549 - val_loss: 0.8280 - val_acc: 0.6623 - val_recall_m: 0.5898 - val_precision_m: 0.1462 - val_f1_m: 0.2263 - val_f2_m: 0.3483
# Epoch 13/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5099 - acc: 0.8873 - recall_m: 0.6238 - precision_m: 0.3066 - f1_m: 0.3864 - f2_m: 0.4864 - val_loss: 0.7183 - val_acc: 0.8547 - val_recall_m: 0.5466 - val_precision_m: 0.2652 - val_f1_m: 0.3371 - val_f2_m: 0.4230
# Epoch 14/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5149 - acc: 0.8934 - recall_m: 0.5575 - precision_m: 0.2977 - f1_m: 0.3629 - f2_m: 0.4462 - val_loss: 0.5834 - val_acc: 0.8830 - val_recall_m: 0.5181 - val_precision_m: 0.2827 - val_f1_m: 0.3469 - val_f2_m: 0.4206
# Epoch 15/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5345 - acc: 0.8896 - recall_m: 0.5160 - precision_m: 0.2985 - f1_m: 0.3580 - f2_m: 0.4274 - val_loss: 0.7205 - val_acc: 0.6906 - val_recall_m: 0.6226 - val_precision_m: 0.1537 - val_f1_m: 0.2408 - val_f2_m: 0.3727
# Epoch 16/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4833 - acc: 0.8863 - recall_m: 0.6019 - precision_m: 0.3092 - f1_m: 0.3828 - f2_m: 0.4746 - val_loss: 0.5194 - val_acc: 0.8358 - val_recall_m: 0.5445 - val_precision_m: 0.2364 - val_f1_m: 0.3233 - val_f2_m: 0.4225
# Epoch 17/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4773 - acc: 0.8821 - recall_m: 0.6132 - precision_m: 0.3134 - f1_m: 0.3897 - f2_m: 0.4825 - val_loss: 0.5006 - val_acc: 0.8755 - val_recall_m: 0.5229 - val_precision_m: 0.2662 - val_f1_m: 0.3424 - val_f2_m: 0.4261
# Epoch 18/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4226 - acc: 0.9113 - recall_m: 0.6132 - precision_m: 0.3555 - f1_m: 0.4148 - f2_m: 0.4976 - val_loss: 0.4873 - val_acc: 0.8566 - val_recall_m: 0.5660 - val_precision_m: 0.2437 - val_f1_m: 0.3320 - val_f2_m: 0.4355
# Epoch 19/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4427 - acc: 0.9108 - recall_m: 0.5525 - precision_m: 0.3581 - f1_m: 0.4050 - f2_m: 0.4682 - val_loss: 0.3848 - val_acc: 0.9226 - val_recall_m: 0.5606 - val_precision_m: 0.3705 - val_f1_m: 0.4363 - val_f2_m: 0.4988
# Epoch 20/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5037 - acc: 0.8910 - recall_m: 0.5283 - precision_m: 0.3165 - f1_m: 0.3689 - f2_m: 0.4349 - val_loss: 0.4615 - val_acc: 0.8943 - val_recall_m: 0.5202 - val_precision_m: 0.2605 - val_f1_m: 0.3336 - val_f2_m: 0.4171
# Epoch 21/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4128 - acc: 0.9179 - recall_m: 0.5972 - precision_m: 0.3717 - f1_m: 0.4364 - f2_m: 0.5102 - val_loss: 0.5245 - val_acc: 0.8868 - val_recall_m: 0.5380 - val_precision_m: 0.2641 - val_f1_m: 0.3346 - val_f2_m: 0.4220
# Epoch 22/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5062 - acc: 0.8995 - recall_m: 0.5519 - precision_m: 0.3223 - f1_m: 0.3775 - f2_m: 0.4503 - val_loss: 0.4868 - val_acc: 0.9132 - val_recall_m: 0.5871 - val_precision_m: 0.3219 - val_f1_m: 0.4040 - val_f2_m: 0.4910
# Epoch 23/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4331 - acc: 0.9104 - recall_m: 0.6160 - precision_m: 0.3526 - f1_m: 0.4207 - f2_m: 0.5042 - val_loss: 0.5255 - val_acc: 0.8774 - val_recall_m: 0.5380 - val_precision_m: 0.2471 - val_f1_m: 0.3261 - val_f2_m: 0.4185
# Epoch 24/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3921 - acc: 0.9142 - recall_m: 0.5387 - precision_m: 0.3543 - f1_m: 0.3993 - f2_m: 0.4596 - val_loss: 0.4590 - val_acc: 0.9132 - val_recall_m: 0.5353 - val_precision_m: 0.3104 - val_f1_m: 0.3822 - val_f2_m: 0.4555
# Epoch 25/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3903 - acc: 0.9137 - recall_m: 0.6200 - precision_m: 0.3592 - f1_m: 0.4303 - f2_m: 0.5154 - val_loss: 0.4703 - val_acc: 0.9057 - val_recall_m: 0.5466 - val_precision_m: 0.3105 - val_f1_m: 0.3770 - val_f2_m: 0.4531
# Epoch 26/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3643 - acc: 0.9259 - recall_m: 0.6123 - precision_m: 0.4051 - f1_m: 0.4582 - f2_m: 0.5257 - val_loss: 0.3830 - val_acc: 0.9132 - val_recall_m: 0.5569 - val_precision_m: 0.3257 - val_f1_m: 0.3918 - val_f2_m: 0.4673
# Epoch 27/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3893 - acc: 0.9193 - recall_m: 0.6279 - precision_m: 0.3743 - f1_m: 0.4497 - f2_m: 0.5310 - val_loss: 0.3969 - val_acc: 0.9000 - val_recall_m: 0.5682 - val_precision_m: 0.3124 - val_f1_m: 0.3914 - val_f2_m: 0.4742
# Epoch 28/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3337 - acc: 0.9255 - recall_m: 0.6896 - precision_m: 0.4153 - f1_m: 0.4922 - f2_m: 0.5821 - val_loss: 0.4156 - val_acc: 0.8774 - val_recall_m: 0.5747 - val_precision_m: 0.2672 - val_f1_m: 0.3528 - val_f2_m: 0.4498
# Epoch 29/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3140 - acc: 0.9420 - recall_m: 0.5981 - precision_m: 0.4192 - f1_m: 0.4681 - f2_m: 0.5275 - val_loss: 0.3358 - val_acc: 0.9038 - val_recall_m: 0.5682 - val_precision_m: 0.2993 - val_f1_m: 0.3787 - val_f2_m: 0.4652
# Epoch 30/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3207 - acc: 0.9274 - recall_m: 0.6811 - precision_m: 0.3958 - f1_m: 0.4735 - f2_m: 0.5664 - val_loss: 0.4265 - val_acc: 0.9453 - val_recall_m: 0.5164 - val_precision_m: 0.4364 - val_f1_m: 0.4545 - val_f2_m: 0.4831
# Epoch 31/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3988 - acc: 0.9325 - recall_m: 0.5375 - precision_m: 0.3564 - f1_m: 0.4047 - f2_m: 0.4648 - val_loss: 0.3979 - val_acc: 0.8811 - val_recall_m: 0.5682 - val_precision_m: 0.3016 - val_f1_m: 0.3804 - val_f2_m: 0.4653
# Epoch 32/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3497 - acc: 0.9297 - recall_m: 0.6726 - precision_m: 0.4174 - f1_m: 0.4885 - f2_m: 0.5709 - val_loss: 0.3014 - val_acc: 0.9245 - val_recall_m: 0.6049 - val_precision_m: 0.3815 - val_f1_m: 0.4518 - val_f2_m: 0.5238
# Epoch 33/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2885 - acc: 0.9335 - recall_m: 0.6440 - precision_m: 0.4034 - f1_m: 0.4621 - f2_m: 0.5405 - val_loss: 0.3930 - val_acc: 0.9132 - val_recall_m: 0.5682 - val_precision_m: 0.3549 - val_f1_m: 0.4243 - val_f2_m: 0.4938
# Epoch 34/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3526 - acc: 0.9292 - recall_m: 0.6543 - precision_m: 0.3849 - f1_m: 0.4598 - f2_m: 0.5471 - val_loss: 0.3939 - val_acc: 0.9151 - val_recall_m: 0.5240 - val_precision_m: 0.3150 - val_f1_m: 0.3772 - val_f2_m: 0.4453
# Epoch 35/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3137 - acc: 0.9325 - recall_m: 0.6368 - precision_m: 0.4213 - f1_m: 0.4789 - f2_m: 0.5493 - val_loss: 0.2677 - val_acc: 0.9189 - val_recall_m: 0.6377 - val_precision_m: 0.3661 - val_f1_m: 0.4444 - val_f2_m: 0.5318
# Epoch 36/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2957 - acc: 0.9396 - recall_m: 0.6377 - precision_m: 0.4500 - f1_m: 0.4957 - f2_m: 0.5580 - val_loss: 0.3260 - val_acc: 0.9358 - val_recall_m: 0.5795 - val_precision_m: 0.3766 - val_f1_m: 0.4415 - val_f2_m: 0.5075
# Epoch 37/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3000 - acc: 0.9358 - recall_m: 0.7028 - precision_m: 0.4360 - f1_m: 0.5111 - f2_m: 0.5976 - val_loss: 0.2787 - val_acc: 0.9472 - val_recall_m: 0.5946 - val_precision_m: 0.4567 - val_f1_m: 0.5005 - val_f2_m: 0.5467
# Epoch 38/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2972 - acc: 0.9476 - recall_m: 0.6223 - precision_m: 0.4613 - f1_m: 0.5088 - f2_m: 0.5629 - val_loss: 0.2210 - val_acc: 0.9377 - val_recall_m: 0.6377 - val_precision_m: 0.3914 - val_f1_m: 0.4726 - val_f2_m: 0.5530
# Epoch 39/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2947 - acc: 0.9321 - recall_m: 0.6717 - precision_m: 0.4130 - f1_m: 0.4863 - f2_m: 0.5700 - val_loss: 0.2865 - val_acc: 0.9264 - val_recall_m: 0.5774 - val_precision_m: 0.3300 - val_f1_m: 0.4084 - val_f2_m: 0.4897
# Epoch 40/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2697 - acc: 0.9363 - recall_m: 0.6962 - precision_m: 0.4270 - f1_m: 0.5063 - f2_m: 0.5940 - val_loss: 0.3060 - val_acc: 0.9264 - val_recall_m: 0.5747 - val_precision_m: 0.3373 - val_f1_m: 0.4119 - val_f2_m: 0.4892
# Epoch 41/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3038 - acc: 0.9330 - recall_m: 0.6464 - precision_m: 0.4209 - f1_m: 0.4759 - f2_m: 0.5496 - val_loss: 0.3496 - val_acc: 0.9226 - val_recall_m: 0.5747 - val_precision_m: 0.3221 - val_f1_m: 0.4009 - val_f2_m: 0.4829
# Epoch 42/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2973 - acc: 0.9519 - recall_m: 0.6547 - precision_m: 0.4745 - f1_m: 0.5350 - f2_m: 0.5951 - val_loss: 0.2480 - val_acc: 0.9321 - val_recall_m: 0.6264 - val_precision_m: 0.3728 - val_f1_m: 0.4567 - val_f2_m: 0.5390
# Epoch 43/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2759 - acc: 0.9495 - recall_m: 0.7208 - precision_m: 0.5106 - f1_m: 0.5697 - f2_m: 0.6399 - val_loss: 0.2249 - val_acc: 0.9472 - val_recall_m: 0.6226 - val_precision_m: 0.4203 - val_f1_m: 0.4909 - val_f2_m: 0.5574
# Epoch 44/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2376 - acc: 0.9486 - recall_m: 0.6358 - precision_m: 0.4545 - f1_m: 0.5100 - f2_m: 0.5702 - val_loss: 0.1971 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4509 - val_f1_m: 0.5143 - val_f2_m: 0.5752
# Epoch 45/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2654 - acc: 0.9495 - recall_m: 0.6717 - precision_m: 0.4728 - f1_m: 0.5298 - f2_m: 0.5976 - val_loss: 0.2321 - val_acc: 0.9302 - val_recall_m: 0.6377 - val_precision_m: 0.3792 - val_f1_m: 0.4658 - val_f2_m: 0.5501
# Epoch 46/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2449 - acc: 0.9476 - recall_m: 0.6053 - precision_m: 0.4492 - f1_m: 0.4879 - f2_m: 0.5420 - val_loss: 0.2132 - val_acc: 0.9453 - val_recall_m: 0.6377 - val_precision_m: 0.3988 - val_f1_m: 0.4790 - val_f2_m: 0.5570
# Epoch 47/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2344 - acc: 0.9467 - recall_m: 0.6864 - precision_m: 0.4457 - f1_m: 0.5146 - f2_m: 0.5934 - val_loss: 0.2020 - val_acc: 0.9472 - val_recall_m: 0.6377 - val_precision_m: 0.4195 - val_f1_m: 0.4932 - val_f2_m: 0.5645
# Epoch 48/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2359 - acc: 0.9561 - recall_m: 0.6236 - precision_m: 0.4733 - f1_m: 0.5163 - f2_m: 0.5659 - val_loss: 0.2288 - val_acc: 0.9396 - val_recall_m: 0.6377 - val_precision_m: 0.3798 - val_f1_m: 0.4644 - val_f2_m: 0.5478
# Epoch 49/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2604 - acc: 0.9486 - recall_m: 0.6745 - precision_m: 0.4696 - f1_m: 0.5227 - f2_m: 0.5910 - val_loss: 0.2433 - val_acc: 0.9453 - val_recall_m: 0.5860 - val_precision_m: 0.3783 - val_f1_m: 0.4494 - val_f2_m: 0.5174
# Epoch 50/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2071 - acc: 0.9571 - recall_m: 0.6679 - precision_m: 0.4983 - f1_m: 0.5482 - f2_m: 0.6058 - val_loss: 0.1755 - val_acc: 0.9528 - val_recall_m: 0.6377 - val_precision_m: 0.4326 - val_f1_m: 0.5038 - val_f2_m: 0.5711
# Epoch 51/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2539 - acc: 0.9467 - recall_m: 0.6430 - precision_m: 0.4685 - f1_m: 0.5204 - f2_m: 0.5786 - val_loss: 0.1788 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4326 - val_f1_m: 0.5038 - val_f2_m: 0.5711
# Epoch 52/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2248 - acc: 0.9542 - recall_m: 0.7185 - precision_m: 0.5238 - f1_m: 0.5806 - f2_m: 0.6449 - val_loss: 0.1768 - val_acc: 0.9585 - val_recall_m: 0.6377 - val_precision_m: 0.4420 - val_f1_m: 0.5119 - val_f2_m: 0.5761
# Epoch 53/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2212 - acc: 0.9566 - recall_m: 0.6962 - precision_m: 0.5021 - f1_m: 0.5592 - f2_m: 0.6238 - val_loss: 0.1837 - val_acc: 0.9491 - val_recall_m: 0.6377 - val_precision_m: 0.4174 - val_f1_m: 0.4931 - val_f2_m: 0.5650
# Epoch 54/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1991 - acc: 0.9566 - recall_m: 0.6726 - precision_m: 0.5045 - f1_m: 0.5572 - f2_m: 0.6118 - val_loss: 0.2030 - val_acc: 0.9472 - val_recall_m: 0.6377 - val_precision_m: 0.4327 - val_f1_m: 0.5027 - val_f2_m: 0.5692
# Epoch 55/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2211 - acc: 0.9557 - recall_m: 0.6981 - precision_m: 0.4966 - f1_m: 0.5564 - f2_m: 0.6230 - val_loss: 0.1921 - val_acc: 0.9415 - val_recall_m: 0.6377 - val_precision_m: 0.4075 - val_f1_m: 0.4843 - val_f2_m: 0.5590
# Epoch 56/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2498 - acc: 0.9557 - recall_m: 0.7368 - precision_m: 0.5421 - f1_m: 0.5940 - f2_m: 0.6588 - val_loss: 0.2015 - val_acc: 0.9415 - val_recall_m: 0.6377 - val_precision_m: 0.4091 - val_f1_m: 0.4863 - val_f2_m: 0.5605
# Epoch 57/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1899 - acc: 0.9571 - recall_m: 0.7104 - precision_m: 0.4883 - f1_m: 0.5612 - f2_m: 0.6342 - val_loss: 0.1971 - val_acc: 0.9415 - val_recall_m: 0.6377 - val_precision_m: 0.4091 - val_f1_m: 0.4863 - val_f2_m: 0.5605
# Epoch 58/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2379 - acc: 0.9519 - recall_m: 0.7066 - precision_m: 0.5109 - f1_m: 0.5659 - f2_m: 0.6295 - val_loss: 0.1918 - val_acc: 0.9434 - val_recall_m: 0.6377 - val_precision_m: 0.4101 - val_f1_m: 0.4876 - val_f2_m: 0.5617
# Epoch 59/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2150 - acc: 0.9519 - recall_m: 0.6057 - precision_m: 0.4413 - f1_m: 0.4931 - f2_m: 0.5468 - val_loss: 0.1880 - val_acc: 0.9472 - val_recall_m: 0.6377 - val_precision_m: 0.4125 - val_f1_m: 0.4901 - val_f2_m: 0.5635
# Epoch 60/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1977 - acc: 0.9557 - recall_m: 0.7066 - precision_m: 0.4911 - f1_m: 0.5540 - f2_m: 0.6247 - val_loss: 0.1887 - val_acc: 0.9509 - val_recall_m: 0.6377 - val_precision_m: 0.4412 - val_f1_m: 0.5092 - val_f2_m: 0.5730
# Epoch 61/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1909 - acc: 0.9632 - recall_m: 0.7094 - precision_m: 0.5632 - f1_m: 0.6059 - f2_m: 0.6553 - val_loss: 0.1830 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4557 - val_f1_m: 0.5187 - val_f2_m: 0.5778
# Epoch 62/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1933 - acc: 0.9608 - recall_m: 0.7491 - precision_m: 0.5651 - f1_m: 0.6215 - f2_m: 0.6818 - val_loss: 0.1828 - val_acc: 0.9509 - val_recall_m: 0.6377 - val_precision_m: 0.4412 - val_f1_m: 0.5092 - val_f2_m: 0.5730
# Epoch 63/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1792 - acc: 0.9613 - recall_m: 0.7396 - precision_m: 0.5555 - f1_m: 0.6126 - f2_m: 0.6733 - val_loss: 0.1793 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4537 - val_f1_m: 0.5171 - val_f2_m: 0.5772
# Epoch 64/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2048 - acc: 0.9524 - recall_m: 0.7123 - precision_m: 0.4917 - f1_m: 0.5544 - f2_m: 0.6271 - val_loss: 0.1791 - val_acc: 0.9509 - val_recall_m: 0.6377 - val_precision_m: 0.4412 - val_f1_m: 0.5092 - val_f2_m: 0.5730
# Epoch 65/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2006 - acc: 0.9623 - recall_m: 0.6311 - precision_m: 0.5083 - f1_m: 0.5432 - f2_m: 0.5846 - val_loss: 0.1859 - val_acc: 0.9491 - val_recall_m: 0.6377 - val_precision_m: 0.4344 - val_f1_m: 0.5043 - val_f2_m: 0.5705
# Epoch 66/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1869 - acc: 0.9623 - recall_m: 0.7094 - precision_m: 0.5500 - f1_m: 0.6005 - f2_m: 0.6534 - val_loss: 0.1795 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 67/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1738 - acc: 0.9632 - recall_m: 0.7208 - precision_m: 0.5368 - f1_m: 0.5955 - f2_m: 0.6569 - val_loss: 0.1787 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 68/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2179 - acc: 0.9575 - recall_m: 0.7292 - precision_m: 0.5360 - f1_m: 0.5894 - f2_m: 0.6554 - val_loss: 0.1786 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 69/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1918 - acc: 0.9613 - recall_m: 0.6953 - precision_m: 0.5460 - f1_m: 0.5893 - f2_m: 0.6404 - val_loss: 0.1814 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 70/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2092 - acc: 0.9533 - recall_m: 0.6775 - precision_m: 0.5019 - f1_m: 0.5535 - f2_m: 0.6119 - val_loss: 0.1820 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 71/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1849 - acc: 0.9599 - recall_m: 0.6745 - precision_m: 0.4994 - f1_m: 0.5546 - f2_m: 0.6121 - val_loss: 0.1805 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 72/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1947 - acc: 0.9561 - recall_m: 0.6830 - precision_m: 0.5115 - f1_m: 0.5608 - f2_m: 0.6178 - val_loss: 0.1792 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 73/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1804 - acc: 0.9533 - recall_m: 0.7255 - precision_m: 0.5098 - f1_m: 0.5764 - f2_m: 0.6468 - val_loss: 0.1790 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 74/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1802 - acc: 0.9613 - recall_m: 0.6204 - precision_m: 0.5062 - f1_m: 0.5434 - f2_m: 0.5818 - val_loss: 0.1774 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 75/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2116 - acc: 0.9575 - recall_m: 0.6660 - precision_m: 0.5187 - f1_m: 0.5629 - f2_m: 0.6123 - val_loss: 0.1782 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 76/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1915 - acc: 0.9604 - recall_m: 0.6642 - precision_m: 0.5094 - f1_m: 0.5533 - f2_m: 0.6046 - val_loss: 0.1786 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 77/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1970 - acc: 0.9557 - recall_m: 0.6038 - precision_m: 0.4589 - f1_m: 0.5073 - f2_m: 0.5549 - val_loss: 0.1790 - val_acc: 0.9528 - val_recall_m: 0.6377 - val_precision_m: 0.4444 - val_f1_m: 0.5122 - val_f2_m: 0.5750
# Epoch 78/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2116 - acc: 0.9505 - recall_m: 0.6283 - precision_m: 0.4562 - f1_m: 0.5041 - f2_m: 0.5607 - val_loss: 0.1782 - val_acc: 0.9528 - val_recall_m: 0.6377 - val_precision_m: 0.4444 - val_f1_m: 0.5122 - val_f2_m: 0.5750
# Epoch 79/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2032 - acc: 0.9519 - recall_m: 0.6502 - precision_m: 0.4932 - f1_m: 0.5385 - f2_m: 0.5919 - val_loss: 0.1780 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 80/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2342 - acc: 0.9561 - recall_m: 0.6491 - precision_m: 0.4889 - f1_m: 0.5354 - f2_m: 0.5889 - val_loss: 0.1783 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 81/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1935 - acc: 0.9575 - recall_m: 0.6443 - precision_m: 0.5149 - f1_m: 0.5560 - f2_m: 0.5989 - val_loss: 0.1763 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 82/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2498 - acc: 0.9552 - recall_m: 0.6025 - precision_m: 0.4657 - f1_m: 0.5060 - f2_m: 0.5520 - val_loss: 0.1780 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 83/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2110 - acc: 0.9604 - recall_m: 0.6845 - precision_m: 0.5460 - f1_m: 0.5873 - f2_m: 0.6330 - val_loss: 0.1781 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 84/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2087 - acc: 0.9571 - recall_m: 0.6609 - precision_m: 0.5194 - f1_m: 0.5602 - f2_m: 0.6084 - val_loss: 0.1793 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 85/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2131 - acc: 0.9608 - recall_m: 0.6798 - precision_m: 0.5626 - f1_m: 0.5904 - f2_m: 0.6297 - val_loss: 0.1777 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 86/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2124 - acc: 0.9552 - recall_m: 0.6426 - precision_m: 0.4926 - f1_m: 0.5335 - f2_m: 0.5843 - val_loss: 0.1796 - val_acc: 0.9509 - val_recall_m: 0.6377 - val_precision_m: 0.4412 - val_f1_m: 0.5092 - val_f2_m: 0.5730
# Epoch 87/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2132 - acc: 0.9542 - recall_m: 0.6434 - precision_m: 0.4781 - f1_m: 0.5235 - f2_m: 0.5791 - val_loss: 0.1785 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 88/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2151 - acc: 0.9580 - recall_m: 0.6236 - precision_m: 0.4572 - f1_m: 0.5054 - f2_m: 0.5594 - val_loss: 0.1783 - val_acc: 0.9528 - val_recall_m: 0.6377 - val_precision_m: 0.4424 - val_f1_m: 0.5107 - val_f2_m: 0.5743
# Epoch 89/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1628 - acc: 0.9608 - recall_m: 0.7245 - precision_m: 0.5368 - f1_m: 0.5958 - f2_m: 0.6587 - val_loss: 0.1775 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 90/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2282 - acc: 0.9608 - recall_m: 0.6321 - precision_m: 0.4877 - f1_m: 0.5371 - f2_m: 0.5848 - val_loss: 0.1790 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 91/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2138 - acc: 0.9585 - recall_m: 0.6453 - precision_m: 0.4725 - f1_m: 0.5268 - f2_m: 0.5843 - val_loss: 0.1795 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 92/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1882 - acc: 0.9519 - recall_m: 0.6874 - precision_m: 0.4779 - f1_m: 0.5375 - f2_m: 0.6053 - val_loss: 0.1782 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 93/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1840 - acc: 0.9632 - recall_m: 0.7321 - precision_m: 0.5783 - f1_m: 0.6272 - f2_m: 0.6774 - val_loss: 0.1780 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 94/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1909 - acc: 0.9557 - recall_m: 0.7009 - precision_m: 0.4985 - f1_m: 0.5648 - f2_m: 0.6310 - val_loss: 0.1779 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 95/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1912 - acc: 0.9642 - recall_m: 0.7726 - precision_m: 0.5791 - f1_m: 0.6363 - f2_m: 0.7010 - val_loss: 0.1771 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 96/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2255 - acc: 0.9580 - recall_m: 0.6443 - precision_m: 0.4770 - f1_m: 0.5315 - f2_m: 0.5864 - val_loss: 0.1783 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 97/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2030 - acc: 0.9590 - recall_m: 0.6445 - precision_m: 0.4794 - f1_m: 0.5271 - f2_m: 0.5838 - val_loss: 0.1788 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 98/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1887 - acc: 0.9557 - recall_m: 0.6953 - precision_m: 0.5066 - f1_m: 0.5690 - f2_m: 0.6305 - val_loss: 0.1779 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 99/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1751 - acc: 0.9660 - recall_m: 0.6472 - precision_m: 0.5085 - f1_m: 0.5495 - f2_m: 0.5953 - val_loss: 0.1781 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 100/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2163 - acc: 0.9604 - recall_m: 0.6321 - precision_m: 0.4738 - f1_m: 0.5242 - f2_m: 0.5761 - val_loss: 0.1776 - val_acc: 0.9547 - val_recall_m: 0.6377 - val_precision_m: 0.4457 - val_f1_m: 0.5137 - val_f2_m: 0.5763
# Epoch 00100: early stopping

# %%
def plot_history(history):
  plt.figure(figsize=(12,15))
  plt.subplot(3,2,1)
  name = 'loss'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,2)
  name = 'acc'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,3)
  name = 'recall_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,4)
  name = 'precision_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,5)
  name = 'f1_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,6)
  name = 'f2_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

plot_history(history)

# %%
from sklearn.metrics import recall_score, precision_score, f1_score, fbeta_score, cohen_kappa_score, roc_auc_score, accuracy_score

model.load_weights(f"/content/gdrive/My Drive/CNN_LSTM_{I}_adj_watermask_5day.hdf5")
preds = model.predict([x_val_0, x_val_1, x_val_2, num_val_0, num_val_1, num_val_2, adj_val_0, adj_val_1, adj_val_2])

print(recall_score(y_val, preds.round()))
print(fbeta_score(y_val, preds.round(), 2))
print(f1_score(y_val, preds.round()))
print(cohen_kappa_score(y_val, preds.round().flatten()))
print(roc_auc_score(y_val, preds.round()))
print(accuracy_score(y_val, preds.round()))
print(precision_score(y_val, preds.round()))
np.save(f'/content/gdrive/My Drive/preds_{I}', preds.flatten())
# Out:
# 1.0
# 0.8863636363636364
# 0.7572815533980582
# 0.7328521311343199
# 0.9745417515274949
# 0.9528301886792453
# 0.609375
