# %%
import os
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
from PIL import Image
import matplotlib
from sklearn.model_selection import StratifiedKFold
import keras
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, TensorBoard
from keras import optimizers
from keras.models import Model
from keras.layers import Input, Dropout, UpSampling2D, BatchNormalization, Activation, Dense, Lambda, TimeDistributed, Flatten
from keras.layers import LSTM, GRU, RNN, Reshape, CuDNNGRU, CuDNNLSTM
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, MaxPooling3D
from keras.layers.merge import concatenate
from keras.models import Sequential
from keras.layers.convolutional import Conv3D
from keras.layers.convolutional_recurrent import ConvLSTM2D
from keras import backend as K
from keras.losses import binary_crossentropy
from keras.optimizers import Adam
from keras.optimizers import Adam
from keras.callbacks import Callback
import tensorflow as tf
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import confusion_matrix
import tensorflow as tf
import gc
import torch
from torch.utils.data import Dataset, DataLoader
from keras import layers, models, applications
from keras.layers import concatenate
from matplotlib import pyplot as plt
import tensorflow as tf
from torch.utils.data import Dataset, DataLoader
from keras import layers, models, applications
import albumentations
from albumentations import (
    HorizontalFlip, VerticalFlip, IAAPerspective, ShiftScaleRotate, CLAHE, RandomRotate90, ToFloat,
    Transpose, ShiftScaleRotate, Blur, OpticalDistortion, GridDistortion, HueSaturationValue,
    IAAAdditiveGaussianNoise, GaussNoise, MotionBlur, MedianBlur, IAAPiecewiseAffine, 
    IAASharpen, IAAEmboss, RandomContrast, RandomBrightness, Flip, OneOf, Compose, RandomGamma, ElasticTransform, ChannelShuffle,RGBShift, Rotate
)

from keras.backend.tensorflow_backend import set_session
from keras.backend.tensorflow_backend import clear_session
from keras.backend.tensorflow_backend import get_session
import tensorflow
# Reset Keras Session
def reset_keras():
    sess = get_session()
    clear_session()
    sess.close()
    sess = get_session()
    try:
        del classifier # this is from global space - change this as you need
    except:
        pass

    print(gc.collect()) # if it's done something you should see a number being outputted

    # use the same config as you used to create the session
    config = tensorflow.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 1
    config.gpu_options.visible_device_list = "0"
    set_session(tensorflow.Session(config=config))

def random_everything(seed=42):
  os.environ['PYTHONHASHSEED'] = str(42)
  random.seed(42)
  np.random.seed(42)
  tf.set_random_seed(42)

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

def f2_m(y_true, y_pred, beta=2):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return (1+beta**2) * (precision*recall) / ((beta**2)*(precision)+recall+K.epsilon())

'''
a = []
while(1):
  a.append('1')
'''
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# "\na = []\nwhile(1):\n  a.append('1')\n"

# %%
from google.colab import drive
#drive.mount('/content/gdrive')
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
def generate_sector(imgs, labs, idx=0):
  assert idx <= 24
  alphabets = "ABCDEFGHIJKLMNOPQRSTUVW"
  name = alphabets[idx]
  row_idx = idx//5
  col_idx = idx%5
  return imgs[:108, row_idx*200:(row_idx+1)*200, col_idx*200:(col_idx+1)*200, :], labs[:, row_idx*200:(row_idx+1)*200, col_idx*200:(col_idx+1)*200, :]

def calculate_burnt_ratio(labs):
  ratio = np.zeros((labs.shape[0],))
  for i in range(len(labs)):
    ratio[i] = labs[i,:,:,:].mean()
  return ratio

def generate_sectos_combined(imgs, labs, indices=np.arange(20)):
  combined_imgs, combined_labs = generate_sector(imgs, labs, indices[0])
  for idx in range(1, len(indices)):
    sector_imgs, sector_labs = generate_sector(imgs, labs, idx)
    combined_imgs = np.concatenate([combined_imgs, sector_imgs], 0)
    combined_labs = np.concatenate([combined_labs, sector_labs], 0)
  combined_area = calculate_burnt_ratio(combined_labs)
  return combined_imgs, combined_area

def binarize(y, thres=0.05):
  return (y>thres).astype(int)

def dissect_data(imgs, labs, size=108):
  idx = np.array([i for i in range(len(imgs)) if i%size not in [size-2, size-1, size]])
  imgs_0 = imgs[idx, :,:,:]
  imgs_1 = imgs[idx+1, :,:,:]
  imgs_2 = imgs[idx+2, :,:,:]
  labs   = binarize(labs[idx+2])
  return imgs_0, imgs_1, imgs_2, labs

# %%
water_mask = np.load('/content/gdrive/My Drive/water_mask_based_on_ndvi_565.npy')
water_mask = np.expand_dims(water_mask, 2)

# %%
I = 0
trn_idx = [i for i in range(25) if i not in range(5*I, 5*I+5)]
val_idx = [i for i in range(25) if i in range(5*I, 5*I+5)]

imgs = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['imgs']
dnbr = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['dnbr']
labs = (dnbr>0.66).astype(int)
del dnbr
gc.collect()
### apply water mask
for i in range(len(labs)):
  labs[i,:][water_mask==1] = 0

x_trn, y_trn = generate_sectos_combined(imgs, labs, indices=trn_idx)
del imgs, labs
gc.collect()
## normalize
x_trn = x_trn.astype('float32')
x_trn = x_trn / x_trn.max()

x_trn_0, x_trn_1, x_trn_2, y_trn = dissect_data(x_trn, y_trn)
del x_trn
gc.collect()
# Out:
# 0

# %%
imgs = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['imgs']
dnbr = np.load('/content/gdrive/My Drive/cloud_control_data.npz')['dnbr']
labs = (dnbr>0.66).astype(int)
del dnbr
gc.collect()
### apply water mask
for i in range(len(labs)):
  labs[i,:][water_mask==1] = 0

x_val, y_val = generate_sectos_combined(imgs, labs, indices=val_idx)
del imgs, labs
gc.collect()
## normalize
x_val = x_val.astype('float32')
x_val = x_val / x_val.max()

x_val_0, x_val_1, x_val_2, y_val = dissect_data(x_val, y_val)
del x_val
gc.collect()

del water_mask
gc.collect()
# Out:
# 0

# %%
gsod = pd.read_csv('/content/gdrive/My Drive/flinders_chase_clean_5day.csv').values
gsod = np.array(gsod, dtype='float')
## normalize
gsod = gsod/gsod.max(axis=0)

num_trn_0, num_trn_1, num_trn_2 = gsod[:-2,:], gsod[1:-1,:], gsod[2:,:10]
num_val_0, num_val_1, num_val_2 = gsod[:-2,:], gsod[1:-1,:], gsod[2:,:10]
for i in range(len(trn_idx)-1):
  num_trn_0 = np.concatenate([num_trn_0, gsod[:-2,:]])
  num_trn_1 = np.concatenate([num_trn_1, gsod[1:-1,:]])
  ### the last series should only have day_0 data!
  num_trn_2 = np.concatenate([num_trn_2, gsod[2:,:10]])
for i in range(len(val_idx)-1):
  num_val_0 = np.concatenate([num_val_0, gsod[:-2,:]])
  num_val_1 = np.concatenate([num_val_1, gsod[1:-1,:]])
  ### the last series should only have day_0 data!
  num_val_2 = np.concatenate([num_val_2, gsod[2:,:10]])

# %%
trn_adjacency = pd.read_csv('/content/gdrive/My Drive/trn_adjacency.csv')
val_adjacency = pd.read_csv('/content/gdrive/My Drive/val_adjacency.csv')
sub_columns = [i for i in trn_adjacency.columns if i.startswith(f"f_{I}")]
trn_adjacency = trn_adjacency[sub_columns]
val_adjacency = val_adjacency[sub_columns]

## normalize
MAX = pd.concat([trn_adjacency, val_adjacency], 0).max()
trn_adjacency = trn_adjacency/MAX
val_adjacency = val_adjacency/MAX

s = 0
adj_trn_0 = trn_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 1
adj_trn_1 = trn_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 2
adj_trn_2 = trn_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]

s = 0
adj_val_0 = val_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 1
adj_val_1 = val_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]
s = 2
adj_val_2 = val_adjacency[[f'f_{I}_s_{s}_d_south', f'f_{I}_s_{s}_d_north',f'f_{I}_s_{s}_d_west',f'f_{I}_s_{s}_d_east', f'f_{I}_s_{s}_d_southwest', f'f_{I}_s_{s}_d_northwest',f'f_{I}_s_{s}_d_southeast',f'f_{I}_s_{s}_d_northeast']]

# %%
def ConvBlock(inputs, suffix=0, prefix="cnn"):
    """no final linear dense layer!"""
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_1a")(inputs)
    conv1 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_1a")(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_1b")(conv1)
    conv1 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_1b")(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2), name=f"{prefix}_{suffix}_maxpool_1")(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_2a")(pool1)
    conv2 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_2a")(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_2b")(conv2)
    conv2 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_2b")(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2), name=f"index_{suffix}_maxpool_2")(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_3a")(pool2)
    conv3 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_3a")(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_3b")(conv3)
    conv3 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_3b")(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2), name=f"index_{suffix}_maxpool_3")(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_4a")(pool3)
    conv4 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_4a")(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal', name=f"{prefix}_{suffix}_conv_4b")(conv4)
    conv4 = BatchNormalization(name=f"{prefix}_{suffix}_batchnorm_4b")(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2), name=f"{prefix}_{suffix}_maxpool_4")(conv4)    
    
    flatten= Flatten(name=f"{prefix}_{suffix}_flatten")(pool4)
    dense1 = Dense(64, activation="relu", name=f"{prefix}_{suffix}_relu_1")(flatten)
    drop1  = Dropout(0.4, name=f"{prefix}_{suffix}_drop_1")(dense1)
    dense2 = Dense(32, activation="relu", name=f"{prefix}_{suffix}_relu_2")(drop1)
    drop2  = Dropout(0.3, name=f"{prefix}_{suffix}_drop_2")(dense2)
    dense3 = Dense(16, activation="relu", name=f"{prefix}_{suffix}_relu_3")(drop2)
    drop3  = Dropout(0.2, name=f"{prefix}_{suffix}_drop_3")(dense3)
    dense4 = Dense(8, activation="relu",  name=f"{prefix}_{suffix}_relu_4")(drop3)
    #dense4 = Dense(1, activation="linear", name=f"{prefix}_{suffix}_linear")(drop3)
    return dense4

def MLP(inputs, suffix=0, prefix='mlp'):
    dense = Dense(8, activation='relu', name=f"{prefix}_{suffix}_relu_1")(inputs)
    dense = Dense(4, activation='relu', name=f"{prefix}_{suffix}_relu_2")(dense)
    #dense = Dense(1, activation='linear', name=f"{prefix}_{suffix}_linear")(dense)
    return dense

# %%
n_channels = 14
sector_dim = 200

img_0 = Input((sector_dim,sector_dim,n_channels), name="cnn_input_0")
img_1 = Input((sector_dim,sector_dim,n_channels), name="cnn_input_1")
img_2 = Input((sector_dim,sector_dim,n_channels), name="cnn_input_2")

num_0 = Input((50,), name="gsod_input_0")
num_1 = Input((50,), name="gsod_input_1")
num_2 = Input((10,), name="gsod_input_2")

adj_0 = Input((8,), name="adj_input_0")
adj_1 = Input((8,), name="adj_input_1")
adj_2 = Input((8,), name="adj_input_2")

cnn_0 = ConvBlock(img_0, suffix=0)
cnn_1 = ConvBlock(img_1, suffix=1)
cnn_2 = ConvBlock(img_2, suffix=2)

num_0_m = MLP(num_0, suffix=0, prefix="gsod")
num_1_m = MLP(num_1, suffix=1, prefix="gsod")
num_2_m = MLP(num_2, suffix=2, prefix="gsod")

adj_0_m = MLP(adj_0, suffix=0, prefix="adj")
adj_1_m = MLP(adj_1, suffix=1, prefix="adj")
adj_2_m = MLP(adj_2, suffix=2, prefix="adj")

mixed_0 = concatenate([cnn_0, num_0_m, adj_0_m], name='mixed_0')
mixed_1 = concatenate([cnn_1, num_1_m, adj_0_m], name='mixed_1')
mixed_2 = concatenate([cnn_2, num_2_m, adj_0_m], name='mixed_2')

concat   = concatenate([mixed_0, mixed_1, mixed_2], name="concat_mixed")
reshape    = Reshape((3, -1), name="reshape")(concat)
lstm       = CuDNNLSTM(256, name='lstm_1', return_sequences=True)(reshape)
lstm       = Dropout(0.4, name='lstm_drop_1')(lstm)
lstm       = CuDNNLSTM(256, name='lstm_2')(lstm)
lstm       = Dropout(0.4, name='lstm_drop_2')(lstm)
dense      = Dense(10, activation="relu", name="fc_relu")(lstm)
dense      = Dense(1, activation="sigmoid", name="fc_sigmoid")(dense)

model = Model(inputs=[img_0, img_1, img_2, num_0, num_1, num_2, adj_0, adj_1, adj_2], output=dense)
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# cnn_input_0 (InputLayer)        (None, 200, 200, 14) 0
# __________________________________________________________________________________________________
# cnn_input_1 (InputLayer)        (None, 200, 200, 14) 0
# __________________________________________________________________________________________________
# cnn_input_2 (InputLayer)        (None, 200, 200, 14) 0
# __________________________________________________________________________________________________
# cnn_0_conv_1a (Conv2D)          (None, 200, 200, 64) 8128        cnn_input_0[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_1a (Conv2D)          (None, 200, 200, 64) 8128        cnn_input_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_1a (Conv2D)          (None, 200, 200, 64) 8128        cnn_input_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_1a (BatchNormal (None, 200, 200, 64) 256         cnn_0_conv_1a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_1a (BatchNormal (None, 200, 200, 64) 256         cnn_1_conv_1a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_1a (BatchNormal (None, 200, 200, 64) 256         cnn_2_conv_1a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_1b (Conv2D)          (None, 200, 200, 64) 36928       cnn_0_batchnorm_1a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_1b (Conv2D)          (None, 200, 200, 64) 36928       cnn_1_batchnorm_1a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_1b (Conv2D)          (None, 200, 200, 64) 36928       cnn_2_batchnorm_1a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_1b (BatchNormal (None, 200, 200, 64) 256         cnn_0_conv_1b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_1b (BatchNormal (None, 200, 200, 64) 256         cnn_1_conv_1b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_1b (BatchNormal (None, 200, 200, 64) 256         cnn_2_conv_1b[0][0]
# __________________________________________________________________________________________________
# cnn_0_maxpool_1 (MaxPooling2D)  (None, 100, 100, 64) 0           cnn_0_batchnorm_1b[0][0]
# __________________________________________________________________________________________________
# cnn_1_maxpool_1 (MaxPooling2D)  (None, 100, 100, 64) 0           cnn_1_batchnorm_1b[0][0]
# __________________________________________________________________________________________________
# cnn_2_maxpool_1 (MaxPooling2D)  (None, 100, 100, 64) 0           cnn_2_batchnorm_1b[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_2a (Conv2D)          (None, 100, 100, 128 73856       cnn_0_maxpool_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_2a (Conv2D)          (None, 100, 100, 128 73856       cnn_1_maxpool_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_2a (Conv2D)          (None, 100, 100, 128 73856       cnn_2_maxpool_1[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_2a (BatchNormal (None, 100, 100, 128 512         cnn_0_conv_2a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_2a (BatchNormal (None, 100, 100, 128 512         cnn_1_conv_2a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_2a (BatchNormal (None, 100, 100, 128 512         cnn_2_conv_2a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_2b (Conv2D)          (None, 100, 100, 128 147584      cnn_0_batchnorm_2a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_2b (Conv2D)          (None, 100, 100, 128 147584      cnn_1_batchnorm_2a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_2b (Conv2D)          (None, 100, 100, 128 147584      cnn_2_batchnorm_2a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_2b (BatchNormal (None, 100, 100, 128 512         cnn_0_conv_2b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_2b (BatchNormal (None, 100, 100, 128 512         cnn_1_conv_2b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_2b (BatchNormal (None, 100, 100, 128 512         cnn_2_conv_2b[0][0]
# __________________________________________________________________________________________________
# index_0_maxpool_2 (MaxPooling2D (None, 50, 50, 128)  0           cnn_0_batchnorm_2b[0][0]
# __________________________________________________________________________________________________
# index_1_maxpool_2 (MaxPooling2D (None, 50, 50, 128)  0           cnn_1_batchnorm_2b[0][0]
# __________________________________________________________________________________________________
# index_2_maxpool_2 (MaxPooling2D (None, 50, 50, 128)  0           cnn_2_batchnorm_2b[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_3a (Conv2D)          (None, 50, 50, 256)  295168      index_0_maxpool_2[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_3a (Conv2D)          (None, 50, 50, 256)  295168      index_1_maxpool_2[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_3a (Conv2D)          (None, 50, 50, 256)  295168      index_2_maxpool_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_3a (BatchNormal (None, 50, 50, 256)  1024        cnn_0_conv_3a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_3a (BatchNormal (None, 50, 50, 256)  1024        cnn_1_conv_3a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_3a (BatchNormal (None, 50, 50, 256)  1024        cnn_2_conv_3a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_3b (Conv2D)          (None, 50, 50, 256)  590080      cnn_0_batchnorm_3a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_3b (Conv2D)          (None, 50, 50, 256)  590080      cnn_1_batchnorm_3a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_3b (Conv2D)          (None, 50, 50, 256)  590080      cnn_2_batchnorm_3a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_3b (BatchNormal (None, 50, 50, 256)  1024        cnn_0_conv_3b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_3b (BatchNormal (None, 50, 50, 256)  1024        cnn_1_conv_3b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_3b (BatchNormal (None, 50, 50, 256)  1024        cnn_2_conv_3b[0][0]
# __________________________________________________________________________________________________
# index_0_maxpool_3 (MaxPooling2D (None, 25, 25, 256)  0           cnn_0_batchnorm_3b[0][0]
# __________________________________________________________________________________________________
# index_1_maxpool_3 (MaxPooling2D (None, 25, 25, 256)  0           cnn_1_batchnorm_3b[0][0]
# __________________________________________________________________________________________________
# index_2_maxpool_3 (MaxPooling2D (None, 25, 25, 256)  0           cnn_2_batchnorm_3b[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_4a (Conv2D)          (None, 25, 25, 512)  1180160     index_0_maxpool_3[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_4a (Conv2D)          (None, 25, 25, 512)  1180160     index_1_maxpool_3[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_4a (Conv2D)          (None, 25, 25, 512)  1180160     index_2_maxpool_3[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_4a (BatchNormal (None, 25, 25, 512)  2048        cnn_0_conv_4a[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_4a (BatchNormal (None, 25, 25, 512)  2048        cnn_1_conv_4a[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_4a (BatchNormal (None, 25, 25, 512)  2048        cnn_2_conv_4a[0][0]
# __________________________________________________________________________________________________
# cnn_0_conv_4b (Conv2D)          (None, 25, 25, 512)  2359808     cnn_0_batchnorm_4a[0][0]
# __________________________________________________________________________________________________
# cnn_1_conv_4b (Conv2D)          (None, 25, 25, 512)  2359808     cnn_1_batchnorm_4a[0][0]
# __________________________________________________________________________________________________
# cnn_2_conv_4b (Conv2D)          (None, 25, 25, 512)  2359808     cnn_2_batchnorm_4a[0][0]
# __________________________________________________________________________________________________
# cnn_0_batchnorm_4b (BatchNormal (None, 25, 25, 512)  2048        cnn_0_conv_4b[0][0]
# __________________________________________________________________________________________________
# cnn_1_batchnorm_4b (BatchNormal (None, 25, 25, 512)  2048        cnn_1_conv_4b[0][0]
# __________________________________________________________________________________________________
# cnn_2_batchnorm_4b (BatchNormal (None, 25, 25, 512)  2048        cnn_2_conv_4b[0][0]
# __________________________________________________________________________________________________
# cnn_0_maxpool_4 (MaxPooling2D)  (None, 12, 12, 512)  0           cnn_0_batchnorm_4b[0][0]
# __________________________________________________________________________________________________
# cnn_1_maxpool_4 (MaxPooling2D)  (None, 12, 12, 512)  0           cnn_1_batchnorm_4b[0][0]
# __________________________________________________________________________________________________
# cnn_2_maxpool_4 (MaxPooling2D)  (None, 12, 12, 512)  0           cnn_2_batchnorm_4b[0][0]
# __________________________________________________________________________________________________
# cnn_0_flatten (Flatten)         (None, 73728)        0           cnn_0_maxpool_4[0][0]
# __________________________________________________________________________________________________
# cnn_1_flatten (Flatten)         (None, 73728)        0           cnn_1_maxpool_4[0][0]
# __________________________________________________________________________________________________
# cnn_2_flatten (Flatten)         (None, 73728)        0           cnn_2_maxpool_4[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_1 (Dense)            (None, 64)           4718656     cnn_0_flatten[0][0]
# __________________________________________________________________________________________________
# cnn_1_relu_1 (Dense)            (None, 64)           4718656     cnn_1_flatten[0][0]
# __________________________________________________________________________________________________
# cnn_2_relu_1 (Dense)            (None, 64)           4718656     cnn_2_flatten[0][0]
# __________________________________________________________________________________________________
# cnn_0_drop_1 (Dropout)          (None, 64)           0           cnn_0_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_drop_1 (Dropout)          (None, 64)           0           cnn_1_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_drop_1 (Dropout)          (None, 64)           0           cnn_2_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_2 (Dense)            (None, 32)           2080        cnn_0_drop_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_relu_2 (Dense)            (None, 32)           2080        cnn_1_drop_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_relu_2 (Dense)            (None, 32)           2080        cnn_2_drop_1[0][0]
# __________________________________________________________________________________________________
# cnn_0_drop_2 (Dropout)          (None, 32)           0           cnn_0_relu_2[0][0]
# __________________________________________________________________________________________________
# cnn_1_drop_2 (Dropout)          (None, 32)           0           cnn_1_relu_2[0][0]
# __________________________________________________________________________________________________
# cnn_2_drop_2 (Dropout)          (None, 32)           0           cnn_2_relu_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_3 (Dense)            (None, 16)           528         cnn_0_drop_2[0][0]
# __________________________________________________________________________________________________
# gsod_input_0 (InputLayer)       (None, 50)           0
# __________________________________________________________________________________________________
# adj_input_0 (InputLayer)        (None, 8)            0
# __________________________________________________________________________________________________
# cnn_1_relu_3 (Dense)            (None, 16)           528         cnn_1_drop_2[0][0]
# __________________________________________________________________________________________________
# gsod_input_1 (InputLayer)       (None, 50)           0
# __________________________________________________________________________________________________
# cnn_2_relu_3 (Dense)            (None, 16)           528         cnn_2_drop_2[0][0]
# __________________________________________________________________________________________________
# gsod_input_2 (InputLayer)       (None, 10)           0
# __________________________________________________________________________________________________
# cnn_0_drop_3 (Dropout)          (None, 16)           0           cnn_0_relu_3[0][0]
# __________________________________________________________________________________________________
# gsod_0_relu_1 (Dense)           (None, 8)            408         gsod_input_0[0][0]
# __________________________________________________________________________________________________
# adj_0_relu_1 (Dense)            (None, 8)            72          adj_input_0[0][0]
# __________________________________________________________________________________________________
# cnn_1_drop_3 (Dropout)          (None, 16)           0           cnn_1_relu_3[0][0]
# __________________________________________________________________________________________________
# gsod_1_relu_1 (Dense)           (None, 8)            408         gsod_input_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_drop_3 (Dropout)          (None, 16)           0           cnn_2_relu_3[0][0]
# __________________________________________________________________________________________________
# gsod_2_relu_1 (Dense)           (None, 8)            88          gsod_input_2[0][0]
# __________________________________________________________________________________________________
# cnn_0_relu_4 (Dense)            (None, 8)            136         cnn_0_drop_3[0][0]
# __________________________________________________________________________________________________
# gsod_0_relu_2 (Dense)           (None, 4)            36          gsod_0_relu_1[0][0]
# __________________________________________________________________________________________________
# adj_0_relu_2 (Dense)            (None, 4)            36          adj_0_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_1_relu_4 (Dense)            (None, 8)            136         cnn_1_drop_3[0][0]
# __________________________________________________________________________________________________
# gsod_1_relu_2 (Dense)           (None, 4)            36          gsod_1_relu_1[0][0]
# __________________________________________________________________________________________________
# cnn_2_relu_4 (Dense)            (None, 8)            136         cnn_2_drop_3[0][0]
# __________________________________________________________________________________________________
# gsod_2_relu_2 (Dense)           (None, 4)            36          gsod_2_relu_1[0][0]
# __________________________________________________________________________________________________
# mixed_0 (Concatenate)           (None, 16)           0           cnn_0_relu_4[0][0]
#                                                                  gsod_0_relu_2[0][0]
#                                                                  adj_0_relu_2[0][0]
# __________________________________________________________________________________________________
# mixed_1 (Concatenate)           (None, 16)           0           cnn_1_relu_4[0][0]
#                                                                  gsod_1_relu_2[0][0]
#                                                                  adj_0_relu_2[0][0]
# __________________________________________________________________________________________________
# mixed_2 (Concatenate)           (None, 16)           0           cnn_2_relu_4[0][0]
#                                                                  gsod_2_relu_2[0][0]
#                                                                  adj_0_relu_2[0][0]
# __________________________________________________________________________________________________
# concat_mixed (Concatenate)      (None, 48)           0           mixed_0[0][0]
#                                                                  mixed_1[0][0]
#                                                                  mixed_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 3, 16)        0           concat_mixed[0][0]
# __________________________________________________________________________________________________
# lstm_1 (CuDNNLSTM)              (None, 3, 256)       280576      reshape[0][0]
# __________________________________________________________________________________________________
# lstm_drop_1 (Dropout)           (None, 3, 256)       0           lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (CuDNNLSTM)              (None, 256)          526336      lstm_drop_1[0][0]
# __________________________________________________________________________________________________
# lstm_drop_2 (Dropout)           (None, 256)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# fc_relu (Dense)                 (None, 10)           2570        lstm_drop_2[0][0]
# __________________________________________________________________________________________________
# fc_sigmoid (Dense)              (None, 1)            11          fc_relu[0][0]
# ==================================================================================================
# Total params: 29,072,989
# Trainable params: 29,061,469
# Non-trainable params: 11,520
# __________________________________________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("fc...)`

# %%
def custom_loss(y_true, y_pred):
  crossentropy_loss = K.binary_crossentropy(y_true, y_pred)
  weight  = (y_true*9)+1
  return crossentropy_loss*(weight)

# %%
random_everything(seed=42)
#model = Model(inputs=[img_0, img_1, img_2, num_0, num_1, num_2, adj_0, adj_1, adj_2], output=dense)

model.compile(optimizer = Adam(lr=1e-4, decay=1e-6), 
              loss=custom_loss,
              metrics=['acc', recall_m, precision_m, f1_m, f2_m])

ckpt = ModelCheckpoint(f"/content/gdrive/My Drive/CNN_LSTM_{I}_adj_watermask_5day.hdf5", monitor = "val_loss", save_best_only = True, mode = "min", save_weights_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

history = model.fit([x_trn_0, x_trn_1, x_trn_2, num_trn_0, num_trn_1, num_trn_2, adj_trn_0, adj_trn_1, adj_trn_2], y_trn,
                        validation_data=([x_val_0, x_val_1, x_val_2, num_val_0, num_val_1, num_val_2, adj_val_0, adj_val_1, adj_val_2], y_val),
                        batch_size=24, epochs=300,
                        callbacks=[es, ckpt, 
                                   keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7)
                                   ]
                        )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 2120 samples, validate on 530 samples
# Epoch 1/300
# 2120/2120 [==============================] - 73s 35ms/step - loss: 0.9357 - acc: 0.9458 - recall_m: 0.0038 - precision_m: 0.0038 - f1_m: 0.0038 - f2_m: 0.0038 - val_loss: 1.1509 - val_acc: 0.9264 - val_recall_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_f1_m: 0.0000e+00 - val_f2_m: 0.0000e+00
# Epoch 2/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8751 - acc: 0.9377 - recall_m: 0.0811 - precision_m: 0.0887 - f1_m: 0.0781 - f2_m: 0.0781 - val_loss: 1.0358 - val_acc: 0.9302 - val_recall_m: 0.0981 - val_precision_m: 0.2264 - val_f1_m: 0.1358 - val_f2_m: 0.1103
# Epoch 3/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8319 - acc: 0.9104 - recall_m: 0.2066 - precision_m: 0.1792 - f1_m: 0.1718 - f2_m: 0.1831 - val_loss: 1.0401 - val_acc: 0.8736 - val_recall_m: 0.2771 - val_precision_m: 0.2038 - val_f1_m: 0.2222 - val_f2_m: 0.2469
# Epoch 4/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8281 - acc: 0.8368 - recall_m: 0.3170 - precision_m: 0.1526 - f1_m: 0.1919 - f2_m: 0.2430 - val_loss: 1.0869 - val_acc: 0.9189 - val_recall_m: 0.1073 - val_precision_m: 0.2166 - val_f1_m: 0.1372 - val_f2_m: 0.1164
# Epoch 5/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7908 - acc: 0.8542 - recall_m: 0.2472 - precision_m: 0.1494 - f1_m: 0.1708 - f2_m: 0.2027 - val_loss: 0.8747 - val_acc: 0.8755 - val_recall_m: 0.3229 - val_precision_m: 0.2134 - val_f1_m: 0.2310 - val_f2_m: 0.2706
# Epoch 6/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7950 - acc: 0.8193 - recall_m: 0.4198 - precision_m: 0.1660 - f1_m: 0.2236 - f2_m: 0.3006 - val_loss: 1.1636 - val_acc: 0.7283 - val_recall_m: 0.3213 - val_precision_m: 0.1285 - val_f1_m: 0.1553 - val_f2_m: 0.2145
# Epoch 7/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7779 - acc: 0.8439 - recall_m: 0.3953 - precision_m: 0.2168 - f1_m: 0.2527 - f2_m: 0.3062 - val_loss: 0.7537 - val_acc: 0.8849 - val_recall_m: 0.4248 - val_precision_m: 0.2583 - val_f1_m: 0.3127 - val_f2_m: 0.3678
# Epoch 8/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7414 - acc: 0.8344 - recall_m: 0.3989 - precision_m: 0.1787 - f1_m: 0.2239 - f2_m: 0.2901 - val_loss: 0.8148 - val_acc: 0.9132 - val_recall_m: 0.3315 - val_precision_m: 0.3284 - val_f1_m: 0.3161 - val_f2_m: 0.3219
# Epoch 9/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6631 - acc: 0.8759 - recall_m: 0.4368 - precision_m: 0.2526 - f1_m: 0.2917 - f2_m: 0.3504 - val_loss: 0.6464 - val_acc: 0.8792 - val_recall_m: 0.4916 - val_precision_m: 0.2481 - val_f1_m: 0.3251 - val_f2_m: 0.4049
# Epoch 10/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6417 - acc: 0.8769 - recall_m: 0.4047 - precision_m: 0.2498 - f1_m: 0.2803 - f2_m: 0.3313 - val_loss: 0.7829 - val_acc: 0.7981 - val_recall_m: 0.4992 - val_precision_m: 0.1867 - val_f1_m: 0.2673 - val_f2_m: 0.3663
# Epoch 11/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6702 - acc: 0.8481 - recall_m: 0.5038 - precision_m: 0.2240 - f1_m: 0.2835 - f2_m: 0.3690 - val_loss: 0.7350 - val_acc: 0.9377 - val_recall_m: 0.3854 - val_precision_m: 0.4515 - val_f1_m: 0.3879 - val_f2_m: 0.3804
# Epoch 12/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5894 - acc: 0.8868 - recall_m: 0.5123 - precision_m: 0.2736 - f1_m: 0.3259 - f2_m: 0.4012 - val_loss: 0.6893 - val_acc: 0.8113 - val_recall_m: 0.5067 - val_precision_m: 0.2171 - val_f1_m: 0.2917 - val_f2_m: 0.3826
# Epoch 13/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6344 - acc: 0.8726 - recall_m: 0.5313 - precision_m: 0.2528 - f1_m: 0.3162 - f2_m: 0.4004 - val_loss: 0.6009 - val_acc: 0.8906 - val_recall_m: 0.4879 - val_precision_m: 0.3393 - val_f1_m: 0.3674 - val_f2_m: 0.4171
# Epoch 14/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5765 - acc: 0.8901 - recall_m: 0.5104 - precision_m: 0.2829 - f1_m: 0.3374 - f2_m: 0.4104 - val_loss: 0.7247 - val_acc: 0.8887 - val_recall_m: 0.4550 - val_precision_m: 0.2425 - val_f1_m: 0.3090 - val_f2_m: 0.3786
# Epoch 15/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5883 - acc: 0.8561 - recall_m: 0.5179 - precision_m: 0.2246 - f1_m: 0.3023 - f2_m: 0.3949 - val_loss: 0.8015 - val_acc: 0.7604 - val_recall_m: 0.5294 - val_precision_m: 0.1581 - val_f1_m: 0.2354 - val_f2_m: 0.3440
# Epoch 16/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6153 - acc: 0.8608 - recall_m: 0.4868 - precision_m: 0.2386 - f1_m: 0.2872 - f2_m: 0.3639 - val_loss: 0.7921 - val_acc: 0.7189 - val_recall_m: 0.5962 - val_precision_m: 0.1500 - val_f1_m: 0.2350 - val_f2_m: 0.3627
# Epoch 17/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5042 - acc: 0.8835 - recall_m: 0.5657 - precision_m: 0.3058 - f1_m: 0.3678 - f2_m: 0.4491 - val_loss: 0.6661 - val_acc: 0.7132 - val_recall_m: 0.5935 - val_precision_m: 0.1602 - val_f1_m: 0.2463 - val_f2_m: 0.3717
# Epoch 18/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4927 - acc: 0.8764 - recall_m: 0.5660 - precision_m: 0.2786 - f1_m: 0.3509 - f2_m: 0.4424 - val_loss: 0.5369 - val_acc: 0.8868 - val_recall_m: 0.5154 - val_precision_m: 0.2530 - val_f1_m: 0.3300 - val_f2_m: 0.4161
# Epoch 19/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.4630 - acc: 0.8991 - recall_m: 0.5855 - precision_m: 0.3123 - f1_m: 0.3797 - f2_m: 0.4658 - val_loss: 0.7118 - val_acc: 0.8698 - val_recall_m: 0.5003 - val_precision_m: 0.2690 - val_f1_m: 0.3281 - val_f2_m: 0.4031
# Epoch 20/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5319 - acc: 0.8877 - recall_m: 0.5085 - precision_m: 0.2805 - f1_m: 0.3396 - f2_m: 0.4116 - val_loss: 0.6513 - val_acc: 0.8528 - val_recall_m: 0.4992 - val_precision_m: 0.2265 - val_f1_m: 0.3009 - val_f2_m: 0.3889
# Epoch 21/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5154 - acc: 0.8750 - recall_m: 0.6009 - precision_m: 0.2864 - f1_m: 0.3658 - f2_m: 0.4634 - val_loss: 0.6255 - val_acc: 0.7698 - val_recall_m: 0.5558 - val_precision_m: 0.1540 - val_f1_m: 0.2377 - val_f2_m: 0.3582
# Epoch 22/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3809 - acc: 0.9061 - recall_m: 0.5745 - precision_m: 0.3379 - f1_m: 0.3978 - f2_m: 0.4731 - val_loss: 0.4726 - val_acc: 0.8943 - val_recall_m: 0.5267 - val_precision_m: 0.3825 - val_f1_m: 0.4005 - val_f2_m: 0.4525
# Epoch 23/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6869 - acc: 0.8278 - recall_m: 0.5274 - precision_m: 0.2135 - f1_m: 0.2865 - f2_m: 0.3819 - val_loss: 0.6182 - val_acc: 0.8283 - val_recall_m: 0.4992 - val_precision_m: 0.1847 - val_f1_m: 0.2665 - val_f2_m: 0.3671
# Epoch 24/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5779 - acc: 0.8533 - recall_m: 0.5085 - precision_m: 0.2392 - f1_m: 0.3036 - f2_m: 0.3863 - val_loss: 0.5761 - val_acc: 0.8906 - val_recall_m: 0.5218 - val_precision_m: 0.2810 - val_f1_m: 0.3490 - val_f2_m: 0.4273
# Epoch 25/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5228 - acc: 0.8873 - recall_m: 0.5758 - precision_m: 0.3018 - f1_m: 0.3674 - f2_m: 0.4538 - val_loss: 0.6932 - val_acc: 0.8736 - val_recall_m: 0.5154 - val_precision_m: 0.2500 - val_f1_m: 0.3248 - val_f2_m: 0.4102
# Epoch 26/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5388 - acc: 0.9019 - recall_m: 0.5170 - precision_m: 0.3147 - f1_m: 0.3640 - f2_m: 0.4289 - val_loss: 0.9080 - val_acc: 0.9132 - val_recall_m: 0.3553 - val_precision_m: 0.3212 - val_f1_m: 0.2995 - val_f2_m: 0.3210
# Epoch 27/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5180 - acc: 0.8825 - recall_m: 0.5557 - precision_m: 0.2767 - f1_m: 0.3410 - f2_m: 0.4288 - val_loss: 0.5005 - val_acc: 0.8566 - val_recall_m: 0.5558 - val_precision_m: 0.2149 - val_f1_m: 0.3040 - val_f2_m: 0.4129
# Epoch 28/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.
300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3223 - acc: 0.9292 - recall_m: 0.6170 - precision_m: 0.4155 - f1_m: 0.4668 - f2_m: 0.5322 - val_loss: 0.4165 - val_acc: 0.8906 - val_recall_m: 0.5644 - val_precision_m: 0.2953 - val_f1_m: 0.3765 - val_f2_m: 0.4645
# Epoch 40/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3169 - acc: 0.9278 - recall_m: 0.6698 - precision_m: 0.3974 - f1_m: 0.4678 - f2_m: 0.5567 - val_loss: 0.3214 - val_acc: 0.9057 - val_recall_m: 0.6032 - val_precision_m: 0.3092 - val_f1_m: 0.3979 - val_f2_m: 0.4943
# Epoch 41/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.3135 - acc: 0.9165 - recall_m: 0.6408 - precision_m: 0.3594 - f1_m: 0.4381 - f2_m: 0.5278 - val_loss: 0.4069 - val_acc: 0.9189 - val_recall_m: 0.5720 - val_precision_m: 0.3590 - val_f1_m: 0.4182 - val_f2_m: 0.4890
# Epoch 42/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2857 - acc: 0.9373 - recall_m: 0.6736 - precision_m: 0.4562 - f1_m: 0.5177 - f2_m: 0.5884 - val_loss: 0.4361 - val_acc: 0.9094 - val_recall_m: 0.5493 - val_precision_m: 0.3494 - val_f1_m: 0.3961 - val_f2_m: 0.4653
# Epoch 43/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2900 - acc: 0.9311 - recall_m: 0.7047 - precision_m: 0.4043 - f1_m: 0.4957 - f2_m: 0.5934 - val_loss: 0.3502 - val_acc: 0.9208 - val_recall_m: 0.5720 - val_precision_m: 0.3860 - val_f1_m: 0.4381 - val_f2_m: 0.5001
# Epoch 44/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2659 - acc: 0.9392 - recall_m: 0.6506 - precision_m: 0.4155 - f1_m: 0.4881 - f2_m: 0.5644 - val_loss: 0.3098 - val_acc: 0.9208 - val_recall_m: 0.6097 - val_precision_m: 0.3747 - val_f1_m: 0.4482 - val_f2_m: 0.5253
# Epoch 45/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2684 - acc: 0.9392 - recall_m: 0.6868 - precision_m: 0.4443 - f1_m: 0.5134 - f2_m: 0.5937 - val_loss: 0.3247 - val_acc: 0.9113 - val_recall_m: 0.5644 - val_precision_m: 0.3270 - val_f1_m: 0.4016 - val_f2_m: 0.4792
# Epoch 46/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2992 - acc: 0.9425 - recall_m: 0.6355 - precision_m: 0.4492 - f1_m: 0.5023 - f2_m: 0.5642 - val_loss: 0.3754 - val_acc: 0.9075 - val_recall_m: 0.5709 - val_precision_m: 0.3185 - val_f1_m: 0.3972 - val_f2_m: 0.4796
# Epoch 47/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2714 - acc: 0.9321 - recall_m: 0.6785 - precision_m: 0.3896 - f1_m: 0.4686 - f2_m: 0.5619 - val_loss: 0.2846 - val_acc: 0.9302 - val_recall_m: 0.5935 - val_precision_m: 0.4171 - val_f1_m: 0.4625 - val_f2_m: 0.5226
# Epoch 48/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2793 - acc: 0.9354 - recall_m: 0.6066 - precision_m: 0.4077 - f1_m: 0.4639 - f2_m: 0.5285 - val_loss: 0.2655 - val_acc: 0.9151 - val_recall_m: 0.6162 - val_precision_m: 0.3466 - val_f1_m: 0.4336 - val_f2_m: 0.5220
# Epoch 49/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2512 - acc: 0.9382 - recall_m: 0.7132 - precision_m: 0.4347 - f1_m: 0.5158 - f2_m: 0.6057 - val_loss: 0.2705 - val_acc: 0.9264 - val_recall_m: 0.5644 - val_precision_m: 0.3521 - val_f1_m: 0.4216 - val_f2_m: 0.4910
# Epoch 50/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2506 - acc: 0.9505 - recall_m: 0.6283 - precision_m: 0.4557 - f1_m: 0.5050 - f2_m: 0.5622 - val_loss: 0.2547 - val_acc: 0.9302 - val_recall_m: 0.6162 - val_precision_m: 0.4125 - val_f1_m: 0.4748 - val_f2_m: 0.5416
# Epoch 51/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2524 - acc: 0.9387 - recall_m: 0.6509 - precision_m: 0.4036 - f1_m: 0.4773 - f2_m: 0.5572 - val_loss: 0.2672 - val_acc: 0.9226 - val_recall_m: 0.6226 - val_precision_m: 0.3918 - val_f1_m: 0.4603 - val_f2_m: 0.5362
# Epoch 52/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2931 - acc: 0.9212 - recall_m: 0.6706 - precision_m: 0.3760 - f1_m: 0.4550 - f2_m: 0.5507 - val_loss: 0.2749 - val_acc: 0.9283 - val_recall_m: 0.6162 - val_precision_m: 0.4156 - val_f1_m: 0.4759 - val_f2_m: 0.5421
# Epoch 53/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2843 - acc: 0.9288 - recall_m: 0.6425 - precision_m: 0.3674 - f1_m: 0.4429 - f2_m: 0.5311 - val_loss: 0.3152 - val_acc: 0.9113 - val_recall_m: 0.5709 - val_precision_m: 0.3336 - val_f1_m: 0.4067 - val_f2_m: 0.4841
# Epoch 54/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2163 - acc: 0.9434 - recall_m: 0.6675 - precision_m: 0.4460 - f1_m: 0.5093 - f2_m: 0.5824 - val_loss: 0.2932 - val_acc: 0.9358 - val_recall_m: 0.5935 - val_precision_m: 0.4345 - val_f1_m: 0.4788 - val_f2_m: 0.5336
# Epoch 55/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2450 - acc: 0.9410 - recall_m: 0.6906 - precision_m: 0.4692 - f1_m: 0.5349 - f2_m: 0.6069 - val_loss: 0.4340 - val_acc: 0.9302 - val_recall_m: 0.5509 - val_precision_m: 0.4500 - val_f1_m: 0.4604 - val_f2_m: 0.4997
# Epoch 56/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2130 - acc: 0.9509 - recall_m: 0.7340 - precision_m: 0.5015 - f1_m: 0.5662 - f2_m: 0.6432 - val_loss: 0.2524 - val_acc: 0.9321 - val_recall_m: 0.6226 - val_precision_m: 0.4266 - val_f1_m: 0.4858 - val_f2_m: 0.5503
# Epoch 57/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2686 - acc: 0.9425 - recall_m: 0.6849 - precision_m: 0.4536 - f1_m: 0.5208 - f2_m: 0.5965 - val_loss: 0.2539 - val_acc: 0.9321 - val_recall_m: 0.6162 - val_precision_m: 0.4373 - val_f1_m: 0.4898 - val_f2_m: 0.5485
# Epoch 58/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2518 - acc: 0.9467 - recall_m: 0.6811 - precision_m: 0.4840 - f1_m: 0.5406 - f2_m: 0.6054 - val_loss: 0.2477 - val_acc: 0.9302 - val_recall_m: 0.6162 - val_precision_m: 0.4244 - val_f1_m: 0.4823 - val_f2_m: 0.5453
# Epoch 59/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2434 - acc: 0.9448 - recall_m: 0.6251 - precision_m: 0.4457 - f1_m: 0.4931 - f2_m: 0.5519 - val_loss: 0.2526 - val_acc: 0.9226 - val_recall_m: 0.6162 - val_precision_m: 0.3945 - val_f1_m: 0.4630 - val_f2_m: 0.5355
# Epoch 60/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2184 - acc: 0.9561 - recall_m: 0.6774 - precision_m: 0.4798 - f1_m: 0.5430 - f2_m: 0.6088 - val_loss: 0.2519 - val_acc: 0.9245 - val_recall_m: 0.6162 - val_precision_m: 0.3962 - val_f1_m: 0.4644 - val_f2_m: 0.5363
# Epoch 61/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2049 - acc: 0.9443 - recall_m: 0.6925 - precision_m: 0.4583 - f1_m: 0.5258 - f2_m: 0.6039 - val_loss: 0.2310 - val_acc: 0.9264 - val_recall_m: 0.6162 - val_precision_m: 0.3977 - val_f1_m: 0.4662 - val_f2_m: 0.5378
# Epoch 62/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2702 - acc: 0.9392 - recall_m: 0.7360 - precision_m: 0.4794 - f1_m: 0.5459 - f2_m: 0.6292 - val_loss: 0.2304 - val_acc: 0.9377 - val_recall_m: 0.6226 - val_precision_m: 0.4243 - val_f1_m: 0.4888 - val_f2_m: 0.5543
# Epoch 63/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2213 - acc: 0.9453 - recall_m: 0.7038 - precision_m: 0.4581 - f1_m: 0.5243 - f2_m: 0.6062 - val_loss: 0.2227 - val_acc: 0.9396 - val_recall_m: 0.6377 - val_precision_m: 0.4263 - val_f1_m: 0.4959 - val_f2_m: 0.5656
# Epoch 64/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2334 - acc: 0.9448 - recall_m: 0.7066 - precision_m: 0.4923 - f1_m: 0.5561 - f2_m: 0.6259 - val_loss: 0.2260 - val_acc: 0.9302 - val_recall_m: 0.6226 - val_precision_m: 0.4017 - val_f1_m: 0.4745 - val_f2_m: 0.5472
# Epoch 65/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2096 - acc: 0.9462 - recall_m: 0.6245 - precision_m: 0.4308 - f1_m: 0.4827 - f2_m: 0.5468 - val_loss: 0.2278 - val_acc: 0.9340 - val_recall_m: 0.5935 - val_precision_m: 0.4150 - val_f1_m: 0.4721 - val_f2_m: 0.5311
# Epoch 66/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1973 - acc: 0.9514 - recall_m: 0.6783 - precision_m: 0.4891 - f1_m: 0.5393 - f2_m: 0.6014 - val_loss: 0.2935 - val_acc: 0.9396 - val_recall_m: 0.5633 - val_precision_m: 0.4379 - val_f1_m: 0.4707 - val_f2_m: 0.5158
# Epoch 67/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2233 - acc: 0.9505 - recall_m: 0.6934 - precision_m: 0.5072 - f1_m: 0.5567 - f2_m: 0.6196 - val_loss: 0.2463 - val_acc: 0.9264 - val_recall_m: 0.6151 - val_precision_m: 0.3878 - val_f1_m: 0.4601 - val_f2_m: 0.5349
# Epoch 68/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2244 - acc: 0.9458 - recall_m: 0.7189 - precision_m: 0.4881 - f1_m: 0.5578 - f2_m: 0.6332 - val_loss: 0.2438 - val_acc: 0.9245 - val_recall_m: 0.5935 - val_precision_m: 0.3971 - val_f1_m: 0.4592 - val_f2_m: 0.5236
# Epoch 69/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1948 - acc: 0.9462 - recall_m: 0.6925 - precision_m: 0.4706 - f1_m: 0.5330 - f2_m: 0.6060 - val_loss: 0.2314 - val_acc: 0.9321 - val_recall_m: 0.6000 - val_precision_m: 0.4072 - val_f1_m: 0.4673 - val_f2_m: 0.5309
# Epoch 70/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2395 - acc: 0.9542 - recall_m: 0.6968 - precision_m: 0.5025 - f1_m: 0.5566 - f2_m: 0.6212 - val_loss: 0.2362 - val_acc: 0.9415 - val_recall_m: 0.6151 - val_precision_m: 0.4298 - val_f1_m: 0.4912 - val_f2_m: 0.5520
# Epoch 71/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1841 - acc: 0.9561 - recall_m: 0.6764 - precision_m: 0.4887 - f1_m: 0.5440 - f2_m: 0.6053 - val_loss: 0.2199 - val_acc: 0.9358 - val_recall_m: 0.6151 - val_precision_m: 0.4092 - val_f1_m: 0.4772 - val_f2_m: 0.5448
# Epoch 72/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1948 - acc: 0.9566 - recall_m: 0.6604 - precision_m: 0.5015 - f1_m: 0.5501 - f2_m: 0.6024 - val_loss: 0.2206 - val_acc: 0.9340 - val_recall_m: 0.6151 - val_precision_m: 0.4064 - val_f1_m: 0.4744 - val_f2_m: 0.5428
# Epoch 73/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1892 - acc: 0.9524 - recall_m: 0.7142 - precision_m: 0.5030 - f1_m: 0.5576 - f2_m: 0.6285 - val_loss: 0.2353 - val_acc: 0.9321 - val_recall_m: 0.6086 - val_precision_m: 0.4092 - val_f1_m: 0.4729 - val_f2_m: 0.5384
# Epoch 74/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2356 - acc: 0.9500 - recall_m: 0.6236 - precision_m: 0.4554 - f1_m: 0.5061 - f2_m: 0.5612 - val_loss: 0.2245 - val_acc: 0.9321 - val_recall_m: 0.5935 - val_precision_m: 0.4092 - val_f1_m: 0.4691 - val_f2_m: 0.5297
# Epoch 75/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1712 - acc: 0.9528 - recall_m: 0.6755 - precision_m: 0.4834 - f1_m: 0.5403 - f2_m: 0.6026 - val_loss: 0.2277 - val_acc: 0.9358 - val_recall_m: 0.5935 - val_precision_m: 0.4167 - val_f1_m: 0.4725 - val_f2_m: 0.5305
# Epoch 76/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1995 - acc: 0.9547 - recall_m: 0.6717 - precision_m: 0.4821 - f1_m: 0.5355 - f2_m: 0.5986 - val_loss: 0.2048 - val_acc: 0.9415 - val_recall_m: 0.6162 - val_precision_m: 0.4277 - val_f1_m: 0.4898 - val_f2_m: 0.5521
# Epoch 77/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1909 - acc: 0.9538 - recall_m: 0.6189 - precision_m: 0.4504 - f1_m: 0.5035 - f2_m: 0.5588 - val_loss: 0.2005 - val_acc: 0.9415 - val_recall_m: 0.6162 - val_precision_m: 0.4277 - val_f1_m: 0.4904 - val_f2_m: 0.5527
# Epoch 78/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2088 - acc: 0.9566 - recall_m: 0.6349 - precision_m: 0.4515 - f1_m: 0.5024 - f2_m: 0.5634 - val_loss: 0.2115 - val_acc: 0.9377 - val_recall_m: 0.5935 - val_precision_m: 0.4264 - val_f1_m: 0.4782 - val_f2_m: 0.5334
# Epoch 79/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.1860 - acc: 0.9552 - recall_m: 0.6547 - precision_m: 0.5006 - f1_m: 0.5478 - f2_m: 0.5995 - val_loss: 0.2124 - val_acc: 0.9415 - val_recall_m: 0.5935 - val_precision_m: 0.4304 - val_f1_m: 0.4851 - val_f2_m: 0.5388
# Epoch 80/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.
300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.2195 - acc: 0.9552 - recall_m: 0.6028 - precision_m: 0.4432 - f1_m: 0.4923 - f2_m: 0.5450 - val_loss: 0.1903 - val_acc: 0.9434 - val_recall_m: 0.6377 - val_precision_m: 0.4469 - val_f1_m: 0.5100 - val_f2_m: 0.5728
# Epoch 00146: early stopping

# %%
def plot_history(history):
  plt.figure(figsize=(12,15))
  plt.subplot(3,2,1)
  name = 'loss'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,2)
  name = 'acc'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,3)
  name = 'recall_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,4)
  name = 'precision_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,5)
  name = 'f1_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

  plt.subplot(3,2,6)
  name = 'f2_m'
  plt.plot(history.history[name])
  plt.plot(history.history[f'val_{name}'])
  plt.title(f'model {name}')
  plt.ylabel(f'{name}')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')

plot_history(history)

# %%
from sklearn.metrics import recall_score, precision_score, f1_score, fbeta_score, cohen_kappa_score, roc_auc_score, accuracy_score

model.load_weights(f"/content/gdrive/My Drive/CNN_LSTM_{I}_adj_watermask_5day.hdf5")
preds = model.predict([x_val_0, x_val_1, x_val_2, num_val_0, num_val_1, num_val_2, adj_val_0, adj_val_1, adj_val_2])

print(recall_score(y_val, preds.round()))
print(fbeta_score(y_val, preds.round(), 2))
print(f1_score(y_val, preds.round()))
print(cohen_kappa_score(y_val, preds.round().flatten()))
print(roc_auc_score(y_val, preds.round()))
print(accuracy_score(y_val, preds.round()))
print(precision_score(y_val, preds.round()))
np.save(f'/content/gdrive/My Drive/preds_{I}', preds.flatten())
# Out:
# 1.0
# 0.8590308370044053
# 0.7090909090909091
# 0.6785565369015579
# 0.9674134419551934
# 0.939622641509434
# 0.5492957746478874

# %%
random_everything(seed=42)
#model = Model(inputs=[img_0, img_1, img_2, num_0, num_1, num_2, adj_0, adj_1, adj_2], output=dense)

model.compile(optimizer = Adam(lr=2e-4, decay=1e-6), 
              loss=custom_loss,
              metrics=['acc', recall_m, precision_m, f1_m, f2_m])

ckpt = ModelCheckpoint(f"/content/gdrive/My Drive/CNN_LSTM_{I}_adj_watermask_5day.hdf5", monitor = "val_loss", save_best_only = True, mode = "min", save_weights_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

history = model.fit([x_trn_0, x_trn_1, x_trn_2, num_trn_0, num_trn_1, num_trn_2, adj_trn_0, adj_trn_1, adj_trn_2], y_trn,
                        validation_data=([x_val_0, x_val_1, x_val_2, num_val_0, num_val_1, num_val_2, adj_val_0, adj_val_1, adj_val_2], y_val),
                        batch_size=24, epochs=300,
                        callbacks=[es, ckpt, 
                                   keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7)
                                   ]
                        )
# Out:
# Train on 2120 samples, validate on 530 samples
# Epoch 1/300
# 2120/2120 [==============================] - 64s 30ms/step - loss: 0.8974 - acc: 0.8307 - recall_m: 0.2072 - precision_m: 0.1043 - f1_m: 0.1288 - f2_m: 0.1595 - val_loss: 1.0921 - val_acc: 0.7189 - val_recall_m: 0.4043 - val_precision_m: 0.1304 - val_f1_m: 0.1841 - val_f2_m: 0.2664
# Epoch 2/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8586 - acc: 0.8307 - recall_m: 0.2151 - precision_m: 0.1009 - f1_m: 0.1259 - f2_m: 0.1612 - val_loss: 1.0317 - val_acc: 0.7717 - val_recall_m: 0.4022 - val_precision_m: 0.1585 - val_f1_m: 0.2194 - val_f2_m: 0.2954
# Epoch 3/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8473 - acc: 0.8033 - recall_m: 0.3791 - precision_m: 0.1324 - f1_m: 0.1841 - f2_m: 0.2551 - val_loss: 1.0311 - val_acc: 0.7057 - val_recall_m: 0.4701 - val_precision_m: 0.1520 - val_f1_m: 0.2235 - val_f2_m: 0.3201
# Epoch 4/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8347 - acc: 0.8066 - recall_m: 0.4057 - precision_m: 0.1373 - f1_m: 0.1951 - f2_m: 0.2750 - val_loss: 1.0957 - val_acc: 0.7887 - val_recall_m: 0.2889 - val_precision_m: 0.1268 - val_f1_m: 0.1715 - val_f2_m: 0.2236
# Epoch 5/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8252 - acc: 0.8226 - recall_m: 0.3613 - precision_m: 0.1465 - f1_m: 0.1916 - f2_m: 0.2559 - val_loss: 1.1976 - val_acc: 0.8472 - val_recall_m: 0.1704 - val_precision_m: 0.1075 - val_f1_m: 0.1261 - val_f2_m: 0.1470
# Epoch 6/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8281 - acc: 0.8000 - recall_m: 0.4321 - precision_m: 0.1364 - f1_m: 0.2003 - f2_m: 0.2876 - val_loss: 0.9767 - val_acc: 0.6962 - val_recall_m: 0.4992 - val_precision_m: 0.1530 - val_f1_m: 0.2280 - val_f2_m: 0.3315
# Epoch 7/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8627 - acc: 0.7302 - recall_m: 0.3736 - precision_m: 0.1140 - f1_m: 0.1628 - f2_m: 0.2333 - val_loss: 1.0127 - val_acc: 0.7811 - val_recall_m: 0.4162 - val_precision_m: 0.1651 - val_f1_m: 0.2313 - val_f2_m: 0.3107
# Epoch 8/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7917 - acc: 0.7896 - recall_m: 0.3932 - precision_m: 0.1502 - f1_m: 0.2018 - f2_m: 0.2737 - val_loss: 1.0244 - val_acc: 0.7679 - val_recall_m: 0.4237 - val_precision_m: 0.1571 - val_f1_m: 0.2225 - val_f2_m: 0.3058
# Epoch 9/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8482 - acc: 0.7344 - recall_m: 0.4104 - precision_m: 0.1114 - f1_m: 0.1661 - f2_m: 0.2475 - val_loss: 1.1399 - val_acc: 0.8113 - val_recall_m: 0.3515 - val_precision_m: 0.1620 - val_f1_m: 0.2102 - val_f2_m: 0.2705
# Epoch 10/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8316 - acc: 0.7415 - recall_m: 0.4670 - precision_m: 0.1305 - f1_m: 0.1952 - f2_m: 0.2888 - val_loss: 0.9987 - val_acc: 0.7642 - val_recall_m: 0.4615 - val_precision_m: 0.1584 - val_f1_m: 0.2317 - val_f2_m: 0.3265
# Epoch 11/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7926 - acc: 0.8009 - recall_m: 0.4377 - precision_m: 0.1468 - f1_m: 0.2052 - f2_m: 0.2891 - val_loss: 1.0350 - val_acc: 0.8019 - val_recall_m: 0.3504 - val_precision_m: 0.1434 - val_f1_m: 0.2003 - val_f2_m: 0.2670
# Epoch 12/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.8034 - acc: 0.8396 - recall_m: 0.3292 - precision_m: 0.1328 - f1_m: 0.1777 - f2_m: 0.2367 - val_loss: 1.0126 - val_acc: 0.7736 - val_recall_m: 0.4173 - val_precision_m: 0.1648 - val_f1_m: 0.2316 - val_f2_m: 0.3119
# Epoch 13/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7507 - acc: 0.8274 - recall_m: 0.5128 - precision_m: 0.1851 - f1_m: 0.2576 - f2_m: 0.3549 - val_loss: 1.0051 - val_acc: 0.7717 - val_recall_m: 0.4173 - val_precision_m: 0.1649 - val_f1_m: 0.2298 - val_f2_m: 0.3094
# Epoch 14/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7842 - acc: 0.8321 - recall_m: 0.4670 - precision_m: 0.1822 - f1_m: 0.2445 - f2_m: 0.3300 - val_loss: 0.9851 - val_acc: 0.7811 - val_recall_m: 0.4550 - val_precision_m: 0.1726 - val_f1_m: 0.2444 - val_f2_m: 0.3333
# Epoch 15/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7628 - acc: 0.8000 - recall_m: 0.4491 - precision_m: 0.1601 - f1_m: 0.2234 - f2_m: 0.3085 - val_loss: 1.0072 - val_acc: 0.7830 - val_recall_m: 0.4173 - val_precision_m: 0.1600 - val_f1_m: 0.2269 - val_f2_m: 0.3086
# Epoch 16/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7821 - acc: 0.8042 - recall_m: 0.4604 - precision_m: 0.1661 - f1_m: 0.2268 - f2_m: 0.3133 - val_loss: 0.9986 - val_acc: 0.7755 - val_recall_m: 0.4323 - val_precision_m: 0.1633 - val_f1_m: 0.2325 - val_f2_m: 0.3178
# Epoch 17/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7462 - acc: 0.8241 - recall_m: 0.4921 - precision_m: 0.1798 - f1_m: 0.2486 - f2_m: 0.3421 - val_loss: 0.9696 - val_acc: 0.7962 - val_recall_m: 0.4323 - val_precision_m: 0.1739 - val_f1_m: 0.2424 - val_f2_m: 0.3244
# Epoch 18/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7596 - acc: 0.8288 - recall_m: 0.4792 - precision_m: 0.1723 - f1_m: 0.2437 - f2_m: 0.3364 - val_loss: 0.9184 - val_acc: 0.8151 - val_recall_m: 0.4237 - val_precision_m: 0.1830 - val_f1_m: 0.2510 - val_f2_m: 0.3285
# Epoch 19/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7528 - acc: 0.8264 - recall_m: 0.4723 - precision_m: 0.1761 - f1_m: 0.2404 - f2_m: 0.3274 - val_loss: 0.9284 - val_acc: 0.8264 - val_recall_m: 0.4011 - val_precision_m: 0.1814 - val_f1_m: 0.2456 - val_f2_m: 0.3164
# Epoch 20/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7771 - acc: 0.8113 - recall_m: 0.3898 - precision_m: 0.1673 - f1_m: 0.2183 - f2_m: 0.2859 - val_loss: 0.9348 - val_acc: 0.8226 - val_recall_m: 0.4173 - val_precision_m: 0.1926 - val_f1_m: 0.2589 - val_f2_m: 0.3315
# Epoch 21/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7522 - acc: 0.8146 - recall_m: 0.5255 - precision_m: 0.1831 - f1_m: 0.2587 - f2_m: 0.3602 - val_loss: 0.9096 - val_acc: 0.7736 - val_recall_m: 0.4388 - val_precision_m: 0.1628 - val_f1_m: 0.2337 - val_f2_m: 0.3213
# Epoch 22/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7394 - acc: 0.8259 - recall_m: 0.4689 - precision_m: 0.2007 - f1_m: 0.2612 - f2_m: 0.3410 - val_loss: 0.9022 - val_acc: 0.7925 - val_recall_m: 0.4388 - val_precision_m: 0.1695 - val_f1_m: 0.2406 - val_f2_m: 0.3265
# Epoch 23/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7380 - acc: 0.8208 - recall_m: 0.5226 - precision_m: 0.1772 - f1_m: 0.2529 - f2_m: 0.3562 - val_loss: 0.9214 - val_acc: 0.8264 - val_recall_m: 0.4323 - val_precision_m: 0.1907 - val_f1_m: 0.2596 - val_f2_m: 0.3375
# Epoch 24/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7432 - acc: 0.8193 - recall_m: 0.4632 - precision_m: 0.1785 - f1_m: 0.2404 - f2_m: 0.3252 - val_loss: 0.8727 - val_acc: 0.8472 - val_recall_m: 0.4323 - val_precision_m: 0.2171 - val_f1_m: 0.2833 - val_f2_m: 0.3532
# Epoch 25/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7211 - acc: 0.8127 - recall_m: 0.4808 - precision_m: 0.1642 - f1_m: 0.2292 - f2_m: 0.3226 - val_loss: 0.8312 - val_acc: 0.8340 - val_recall_m: 0.4690 - val_precision_m: 0.2072 - val_f1_m: 0.2806 - val_f2_m: 0.3646
# Epoch 26/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7168 - acc: 0.8288 - recall_m: 0.4651 - precision_m: 0.1764 - f1_m: 0.2435 - f2_m: 0.3302 - val_loss: 0.8228 - val_acc: 0.8377 - val_recall_m: 0.4539 - val_precision_m: 0.2003 - val_f1_m: 0.2710 - val_f2_m: 0.3524
# Epoch 27/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7026 - acc: 0.8321 - recall_m: 0.4709 - precision_m: 0.1832 - f1_m: 0.2437 - f2_m: 0.3288 - val_loss: 0.8139 - val_acc: 0.8226 - val_recall_m: 0.4690 - val_precision_m: 0.1926 - val_f1_m: 0.2682 - val_f2_m: 0.3567
# Epoch 28/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7057 - acc: 0.8269 - recall_m: 0.4991 - precision_m: 0.1861 - f1_m: 0.2559 - f2_m: 0.3487 - val_loss: 0.8015 - val_acc: 0.8358 - val_recall_m: 0.4464 - val_precision_m: 0.1937 - val_f1_m: 0.2634 - val_f2_m: 0.3442
# Epoch 29/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6753 - acc: 0.8373 - recall_m: 0.4774 - precision_m: 0.2025 - f1_m: 0.2746 - f2_m: 0.3598 - val_loss: 0.7779 - val_acc: 0.8736 - val_recall_m: 0.4313 - val_precision_m: 0.2419 - val_f1_m: 0.2901 - val_f2_m: 0.3538
# Epoch 30/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6666 - acc: 0.8509 - recall_m: 0.4925 - precision_m: 0.1987 - f1_m: 0.2678 - f2_m: 0.3573 - val_loss: 0.8001 - val_acc: 0.8547 - val_recall_m: 0.4539 - val_precision_m: 0.2137 - val_f1_m: 0.2852 - val_f2_m: 0.3631
# Epoch 31/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.7162 - acc: 0.8462 - recall_m: 0.4338 - precision_m: 0.1851 - f1_m: 0.2471 - f2_m: 0.3239 - val_loss: 0.8202 - val_acc: 0.8717 - val_recall_m: 0.3482 - val_precision_m: 0.2076 - val_f1_m: 0.2508 - val_f2_m: 0.2972
# Epoch 32/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6758 - acc: 0.8358 - recall_m: 0.5094 - precision_m: 0.1917 - f1_m: 0.2645 - f2_m: 0.3604 - val_loss: 0.7609 - val_acc: 0.8604 - val_recall_m: 0.4539 - val_precision_m: 0.2101 - val_f1_m: 0.2825 - val_f2_m: 0.3620
# Epoch 33/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6593 - acc: 0.8462 - recall_m: 0.5047 - precision_m: 0.2109 - f1_m: 0.2781 - f2_m: 0.3667 - val_loss: 0.7935 - val_acc: 0.8528 - val_recall_m: 0.4388 - val_precision_m: 0.2025 - val_f1_m: 0.2707 - val_f2_m: 0.3471
# Epoch 34/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6613 - acc: 0.8566 - recall_m: 0.5460 - precision_m: 0.2201 - f1_m: 0.2900 - f2_m: 0.3870 - val_loss: 0.7864 - val_acc: 0.8623 - val_recall_m: 0.4275 - val_precision_m: 0.2233 - val_f1_m: 0.2787 - val_f2_m: 0.3465
# Epoch 35/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6446 - acc: 0.8458 - recall_m: 0.4685 - precision_m: 0.1908 - f1_m: 0.2576 - f2_m: 0.3424 - val_loss: 0.7455 - val_acc: 0.8472 - val_recall_m: 0.4728 - val_precision_m: 0.2318 - val_f1_m: 0.2969 - val_f2_m: 0.3736
# Epoch 36/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6675 - acc: 0.8495 - recall_m: 0.4660 - precision_m: 0.2212 - f1_m: 0.2749 - f2_m: 0.3499 - val_loss: 0.8475 - val_acc: 0.8340 - val_recall_m: 0.3305 - val_precision_m: 0.1524 - val_f1_m: 0.2037 - val_f2_m: 0.2612
# Epoch 37/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6521 - acc: 0.8382 - recall_m: 0.5660 - precision_m: 0.1928 - f1_m: 0.2756 - f2_m: 0.3868 - val_loss: 0.8134 - val_acc: 0.8075 - val_recall_m: 0.3984 - val_precision_m: 0.1939 - val_f1_m: 0.2484 - val_f2_m: 0.3128
# Epoch 38/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6638 - acc: 0.8325 - recall_m: 0.4728 - precision_m: 0.1993 - f1_m: 0.2638 - f2_m: 0.3482 - val_loss: 0.6855 - val_acc: 0.8509 - val_recall_m: 0.4954 - val_precision_m: 0.2172 - val_f1_m: 0.2953 - val_f2_m: 0.3846
# Epoch 39/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6297 - acc: 0.8552 - recall_m: 0.5085 - precision_m: 0.2362 - f1_m: 0.2964 - f2_m: 0.3788 - val_loss: 0.7398 - val_acc: 0.8528 - val_recall_m: 0.4275 - val_precision_m: 0.2084 - val_f1_m: 0.2724 - val_f2_m: 0.3429
# Epoch 40/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6267 - acc: 0.8476 - recall_m: 0.5255 - precision_m: 0.1992 - f1_m: 0.2718 - f2_m: 0.3688 - val_loss: 0.6829 - val_acc: 0.8453 - val_recall_m: 0.5105 - val_precision_m: 0.2160 - val_f1_m: 0.2963 - val_f2_m: 0.3902
# Epoch 41/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6649 - acc: 0.8321 - recall_m: 0.4896 - precision_m: 0.1920 - f1_m: 0.2579 - f2_m: 0.3454 - val_loss: 0.6538 - val_acc: 0.8679 - val_recall_m: 0.4841 - val_precision_m: 0.2528 - val_f1_m: 0.3207 - val_f2_m: 0.3957
# Epoch 42/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6522 - acc: 0.8656 - recall_m: 0.5321 - precision_m: 0.2372 - f1_m: 0.3094 - f2_m: 0.4001 - val_loss: 0.7375 - val_acc: 0.8736 - val_recall_m: 0.4162 - val_precision_m: 0.2531 - val_f1_m: 0.3051 - val_f2_m: 0.3588
# Epoch 43/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6177 - acc: 0.8703 - recall_m: 0.5547 - precision_m: 0.2468 - f1_m: 0.3246 - f2_m: 0.4204 - val_loss: 0.6761 - val_acc: 0.8528 - val_recall_m: 0.4841 - val_precision_m: 0.2211 - val_f1_m: 0.2936 - val_f2_m: 0.3780
# Epoch 44/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6673 - acc: 0.8689 - recall_m: 0.4462 - precision_m: 0.2196 - f1_m: 0.2773 - f2_m: 0.3468 - val_loss: 0.7236 - val_acc: 0.8283 - val_recall_m: 0.5105 - val_precision_m: 0.2300 - val_f1_m: 0.3021 - val_f2_m: 0.3899
# Epoch 45/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6444 - acc: 0.8552 - recall_m: 0.5179 - precision_m: 0.2161 - f1_m: 0.2863 - f2_m: 0.3783 - val_loss: 0.6889 - val_acc: 0.8491 - val_recall_m: 0.4992 - val_precision_m: 0.2230 - val_f1_m: 0.3019 - val_f2_m: 0.3911
# Epoch 46/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5864 - acc: 0.8717 - recall_m: 0.5068 - precision_m: 0.2432 - f1_m: 0.3055 - f2_m: 0.3867 - val_loss: 0.6771 - val_acc: 0.8792 - val_recall_m: 0.4464 - val_precision_m: 0.2492 - val_f1_m: 0.3099 - val_f2_m: 0.3742
# Epoch 47/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6682 - acc: 0.8575 - recall_m: 0.4540 - precision_m: 0.2065 - f1_m: 0.2710 - f2_m: 0.3482 - val_loss: 0.6705 - val_acc: 0.8830 - val_recall_m: 0.4765 - val_precision_m: 0.2609 - val_f1_m: 0.3291 - val_f2_m: 0.3994
# Epoch 48/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5814 - acc: 0.8618 - recall_m: 0.4755 - precision_m: 0.2300 - f1_m: 0.2907 - f2_m: 0.3654 - val_loss: 0.6543 - val_acc: 0.8679 - val_recall_m: 0.4841 - val_precision_m: 0.2508 - val_f1_m: 0.3193 - val_f2_m: 0.3951
# Epoch 49/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6375 - acc: 0.8472 - recall_m: 0.5434 - precision_m: 0.2020 - f1_m: 0.2781 - f2_m: 0.3802 - val_loss: 0.6500 - val_acc: 0.8660 - val_recall_m: 0.4954 - val_precision_m: 0.2466 - val_f1_m: 0.3156 - val_f2_m: 0.3946
# Epoch 50/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6431 - acc: 0.8491 - recall_m: 0.5094 - precision_m: 0.2164 - f1_m: 0.2879 - f2_m: 0.3780 - val_loss: 0.6519 - val_acc: 0.8604 - val_recall_m: 0.4954 - val_precision_m: 0.2279 - val_f1_m: 0.3021 - val_f2_m: 0.3872
# Epoch 51/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6150 - acc: 0.8613 - recall_m: 0.5298 - precision_m: 0.2377 - f1_m: 0.3078 - f2_m: 0.3966 - val_loss: 0.6463 - val_acc: 0.8830 - val_recall_m: 0.4464 - val_precision_m: 0.2422 - val_f1_m: 0.3034 - val_f2_m: 0.3697
# Epoch 52/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6788 - acc: 0.8542 - recall_m: 0.5042 - precision_m: 0.2038 - f1_m: 0.2702 - f2_m: 0.3605 - val_loss: 0.6429 - val_acc: 0.8755 - val_recall_m: 0.4992 - val_precision_m: 0.2490 - val_f1_m: 0.3246 - val_f2_m: 0.4056
# Epoch 53/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6032 - acc: 0.8608 - recall_m: 0.5421 - precision_m: 0.2341 - f1_m: 0.3045 - f2_m: 0.3975 - val_loss: 0.6444 - val_acc: 0.8811 - val_recall_m: 0.4690 - val_precision_m: 0.2475 - val_f1_m: 0.3150 - val_f2_m: 0.3869
# Epoch 54/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6226 - acc: 0.8670 - recall_m: 0.5162 - precision_m: 0.2360 - f1_m: 0.2991 - f2_m: 0.3860 - val_loss: 0.6358 - val_acc: 0.8849 - val_recall_m: 0.4841 - val_precision_m: 0.2574 - val_f1_m: 0.3268 - val_f2_m: 0.4004
# Epoch 55/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5971 - acc: 0.8660 - recall_m: 0.5406 - precision_m: 0.2430 - f1_m: 0.3175 - f2_m: 0.4099 - val_loss: 0.6479 - val_acc: 0.8830 - val_recall_m: 0.4690 - val_precision_m: 0.2611 - val_f1_m: 0.3224 - val_f2_m: 0.3898
# Epoch 56/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5671 - acc: 0.8656 - recall_m: 0.5925 - precision_m: 0.2418 - f1_m: 0.3239 - f2_m: 0.4304 - val_loss: 0.6426 - val_acc: 0.8660 - val_recall_m: 0.4739 - val_precision_m: 0.2376 - val_f1_m: 0.3025 - val_f2_m: 0.3770
# Epoch 57/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5841 - acc: 0.8745 - recall_m: 0.6160 - precision_m: 0.2741 - f1_m: 0.3607 - f2_m: 0.4668 - val_loss: 0.6336 - val_acc: 0.8849 - val_recall_m: 0.4577 - val_precision_m: 0.2525 - val_f1_m: 0.3105 - val_f2_m: 0.3758
# Epoch 58/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5919 - acc: 0.8708 - recall_m: 0.4934 - precision_m: 0.2276 - f1_m: 0.2911 - f2_m: 0.3727 - val_loss: 0.6337 - val_acc: 0.8792 - val_recall_m: 0.4728 - val_precision_m: 0.2409 - val_f1_m: 0.3088 - val_f2_m: 0.3832
# Epoch 59/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6144 - acc: 0.8580 - recall_m: 0.5034 - precision_m: 0.2426 - f1_m: 0.3034 - f2_m: 0.3823 - val_loss: 0.6268 - val_acc: 0.8792 - val_recall_m: 0.5105 - val_precision_m: 0.2566 - val_f1_m: 0.3317 - val_f2_m: 0.4123
# Epoch 60/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5806 - acc: 0.8585 - recall_m: 0.5415 - precision_m: 0.2384 - f1_m: 0.3030 - f2_m: 0.3934 - val_loss: 0.6298 - val_acc: 0.8774 - val_recall_m: 0.4954 - val_precision_m: 0.2529 - val_f1_m: 0.3231 - val_f2_m: 0.4000
# Epoch 61/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5749 - acc: 0.8660 - recall_m: 0.5349 - precision_m: 0.2504 - f1_m: 0.3161 - f2_m: 0.4043 - val_loss: 0.6187 - val_acc: 0.8830 - val_recall_m: 0.5105 - val_precision_m: 0.2642 - val_f1_m: 0.3360 - val_f2_m: 0.4142
# Epoch 62/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6189 - acc: 0.8580 - recall_m: 0.5398 - precision_m: 0.2207 - f1_m: 0.2935 - f2_m: 0.3895 - val_loss: 0.6168 - val_acc: 0.8811 - val_recall_m: 0.5105 - val_precision_m: 0.2566 - val_f1_m: 0.3317 - val_f2_m: 0.4123
# Epoch 63/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5718 - acc: 0.8613 - recall_m: 0.5925 - precision_m: 0.2583 - f1_m: 0.3391 - f2_m: 0.4431 - val_loss: 0.6255 - val_acc: 0.8849 - val_recall_m: 0.5105 - val_precision_m: 0.2688 - val_f1_m: 0.3410 - val_f2_m: 0.4184
# Epoch 64/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5652 - acc: 0.8679 - recall_m: 0.5396 - precision_m: 0.2299 - f1_m: 0.3046 - f2_m: 0.3993 - val_loss: 0.6241 - val_acc: 0.8830 - val_recall_m: 0.4879 - val_precision_m: 0.2553 - val_f1_m: 0.3211 - val_f2_m: 0.3946
# Epoch 65/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5712 - acc: 0.8755 - recall_m: 0.5236 - precision_m: 0.2539 - f1_m: 0.3222 - f2_m: 0.4059 - val_loss: 0.6176 - val_acc: 0.8887 - val_recall_m: 0.5105 - val_precision_m: 0.2838 - val_f1_m: 0.3496 - val_f2_m: 0.4213
# Epoch 66/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5961 - acc: 0.8693 - recall_m: 0.5113 - precision_m: 0.2290 - f1_m: 0.2983 - f2_m: 0.3855 - val_loss: 0.6237 - val_acc: 0.8830 - val_recall_m: 0.4954 - val_precision_m: 0.2741 - val_f1_m: 0.3382 - val_f2_m: 0.4083
# Epoch 67/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5579 - acc: 0.8703 - recall_m: 0.5189 - precision_m: 0.2408 - f1_m: 0.3076 - f2_m: 0.3937 - val_loss: 0.6181 - val_acc: 0.8792 - val_recall_m: 0.4728 - val_precision_m: 0.2349 - val_f1_m: 0.3039 - val_f2_m: 0.3798
# Epoch 68/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6137 - acc: 0.8608 - recall_m: 0.5660 - precision_m: 0.2322 - f1_m: 0.3099 - f2_m: 0.4115 - val_loss: 0.6195 - val_acc: 0.8755 - val_recall_m: 0.4728 - val_precision_m: 0.2332 - val_f1_m: 0.3022 - val_f2_m: 0.3785
# Epoch 69/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6170 - acc: 0.8561 - recall_m: 0.5047 - precision_m: 0.2267 - f1_m: 0.2921 - f2_m: 0.3777 - val_loss: 0.6160 - val_acc: 0.8792 - val_recall_m: 0.4879 - val_precision_m: 0.2370 - val_f1_m: 0.3108 - val_f2_m: 0.3907
# Epoch 70/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6095 - acc: 0.8632 - recall_m: 0.5181 - precision_m: 0.2423 - f1_m: 0.3068 - f2_m: 0.3932 - val_loss: 0.6097 - val_acc: 0.8792 - val_recall_m: 0.5105 - val_precision_m: 0.2583 - val_f1_m: 0.3319 - val_f2_m: 0.4122
# Epoch 71/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5980 - acc: 0.8684 - recall_m: 0.5055 - precision_m: 0.2278 - f1_m: 0.2927 - f2_m: 0.3782 - val_loss: 0.6070 - val_acc: 0.8774 - val_recall_m: 0.5105 - val_precision_m: 0.2583 - val_f1_m: 0.3319 - val_f2_m: 0.4122
# Epoch 72/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5932 - acc: 0.8651 - recall_m: 0.5189 - precision_m: 0.2587 - f1_m: 0.3171 - f2_m: 0.4000 - val_loss: 0.6034 - val_acc: 0.8830 - val_recall_m: 0.5105 - val_precision_m: 0.2658 - val_f1_m: 0.3395 - val_f2_m: 0.4176
# Epoch 73/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5834 - acc: 0.8712 - recall_m: 0.5717 - precision_m: 0.2764 - f1_m: 0.3385 - f2_m: 0.4305 - val_loss: 0.6016 - val_acc: 0.8830 - val_recall_m: 0.5105 - val_precision_m: 0.2642 - val_f1_m: 0.3377 - val_f2_m: 0.4163
# Epoch 74/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5543 - acc: 0.8783 - recall_m: 0.5077 - precision_m: 0.2531 - f1_m: 0.3172 - f2_m: 0.3970 - val_loss: 0.6023 - val_acc: 0.8830 - val_recall_m: 0.4879 - val_precision_m: 0.2477 - val_f1_m: 0.3179 - val_f2_m: 0.3943
# Epoch 75/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5531 - acc: 0.8726 - recall_m: 0.5198 - precision_m: 0.2611 - f1_m: 0.3217 - f2_m: 0.4016 - val_loss: 0.6072 - val_acc: 0.8811 - val_recall_m: 0.4879 - val_precision_m: 0.2402 - val_f1_m: 0.3136 - val_f2_m: 0.3925
# Epoch 76/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5855 - acc: 0.8689 - recall_m: 0.4755 - precision_m: 0.2438 - f1_m: 0.3014 - f2_m: 0.3742 - val_loss: 0.5970 - val_acc: 0.8792 - val_recall_m: 0.4879 - val_precision_m: 0.2356 - val_f1_m: 0.3093 - val_f2_m: 0.3895
# Epoch 77/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5864 - acc: 0.8618 - recall_m: 0.4579 - precision_m: 0.2353 - f1_m: 0.2858 - f2_m: 0.3555 - val_loss: 0.6027 - val_acc: 0.8792 - val_recall_m: 0.4879 - val_precision_m: 0.2356 - val_f1_m: 0.3093 - val_f2_m: 0.3895
# Epoch 78/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5304 - acc: 0.8792 - recall_m: 0.5119 - precision_m: 0.2477 - f1_m: 0.3112 - f2_m: 0.3935 - val_loss: 0.5974 - val_acc: 0.8830 - val_recall_m: 0.4879 - val_precision_m: 0.2417 - val_f1_m: 0.3150 - val_f2_m: 0.3935
# Epoch 79/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5797 - acc: 0.8816 - recall_m: 0.4668 - precision_m: 0.2506 - f1_m: 0.3095 - f2_m: 0.3796 - val_loss: 0.6098 - val_acc: 0.8774 - val_recall_m: 0.4879 - val_precision_m: 0.2302 - val_f1_m: 0.3059 - val_f2_m: 0.3882
# Epoch 80/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5381 - acc: 0.8778 - recall_m: 0.5679 - precision_m: 0.2618 - f1_m: 0.3392 - f2_m: 0.4359 - val_loss: 0.6018 - val_acc: 0.8830 - val_recall_m: 0.4879 - val_precision_m: 0.2349 - val_f1_m: 0.3102 - val_f2_m: 0.3910
# Epoch 81/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5937 - acc: 0.8637 - recall_m: 0.4783 - precision_m: 0.2358 - f1_m: 0.2961 - f2_m: 0.3726 - val_loss: 0.6012 - val_acc: 0.8849 - val_recall_m: 0.4879 - val_precision_m: 0.2595 - val_f1_m: 0.3273 - val_f2_m: 0.4000
# Epoch 82/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6207 - acc: 0.8684 - recall_m: 0.4749 - precision_m: 0.2463 - f1_m: 0.2901 - f2_m: 0.3594 - val_loss: 0.5972 - val_acc: 0.8849 - val_recall_m: 0.4879 - val_precision_m: 0.2575 - val_f1_m: 0.3253 - val_f2_m: 0.3986
# Epoch 83/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5539 - acc: 0.8670 - recall_m: 0.5562 - precision_m: 0.2532 - f1_m: 0.3226 - f2_m: 0.4145 - val_loss: 0.5953 - val_acc: 0.8830 - val_recall_m: 0.4879 - val_precision_m: 0.2559 - val_f1_m: 0.3235 - val_f2_m: 0.3973
# Epoch 84/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5642 - acc: 0.8717 - recall_m: 0.5364 - precision_m: 0.2424 - f1_m: 0.3123 - f2_m: 0.4026 - val_loss: 0.5982 - val_acc: 0.8811 - val_recall_m: 0.4879 - val_precision_m: 0.2559 - val_f1_m: 0.3235 - val_f2_m: 0.3973
# Epoch 85/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5398 - acc: 0.8896 - recall_m: 0.5630 - precision_m: 0.2857 - f1_m: 0.3578 - f2_m: 0.4470 - val_loss: 0.5971 - val_acc: 0.8830 - val_recall_m: 0.4879 - val_precision_m: 0.2559 - val_f1_m: 0.3235 - val_f2_m: 0.3973
# Epoch 86/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5423 - acc: 0.8807 - recall_m: 0.5043 - precision_m: 0.2704 - f1_m: 0.3305 - f2_m: 0.4037 - val_loss: 0.5984 - val_acc: 0.8830 - val_recall_m: 0.4879 - val_precision_m: 0.2559 - val_f1_m: 0.3235 - val_f2_m: 0.3973
# Epoch 87/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6015 - acc: 0.8722 - recall_m: 0.4991 - precision_m: 0.2399 - f1_m: 0.3101 - f2_m: 0.3920 - val_loss: 0.5989 - val_acc: 0.8849 - val_recall_m: 0.4879 - val_precision_m: 0.2575 - val_f1_m: 0.3253 - val_f2_m: 0.3986
# Epoch 88/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5712 - acc: 0.8736 - recall_m: 0.4915 - precision_m: 0.2332 - f1_m: 0.2973 - f2_m: 0.3769 - val_loss: 0.6019 - val_acc: 0.8868 - val_recall_m: 0.5030 - val_precision_m: 0.2688 - val_f1_m: 0.3382 - val_f2_m: 0.4127
# Epoch 89/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5230 - acc: 0.8741 - recall_m: 0.6132 - precision_m: 0.2848 - f1_m: 0.3665 - f2_m: 0.4680 - val_loss: 0.6001 - val_acc: 0.8868 - val_recall_m: 0.5030 - val_precision_m: 0.2688 - val_f1_m: 0.3382 - val_f2_m: 0.4127
# Epoch 90/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5189 - acc: 0.8684 - recall_m: 0.5264 - precision_m: 0.2336 - f1_m: 0.3103 - f2_m: 0.4021 - val_loss: 0.6000 - val_acc: 0.8887 - val_recall_m: 0.5030 - val_precision_m: 0.2734 - val_f1_m: 0.3425 - val_f2_m: 0.4156
# Epoch 91/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6059 - acc: 0.8642 - recall_m: 0.4906 - precision_m: 0.2301 - f1_m: 0.2915 - f2_m: 0.3715 - val_loss: 0.5987 - val_acc: 0.8887 - val_recall_m: 0.5030 - val_precision_m: 0.2734 - val_f1_m: 0.3425 - val_f2_m: 0.4156
# Epoch 92/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5426 - acc: 0.8660 - recall_m: 0.5219 - precision_m: 0.2488 - f1_m: 0.3132 - f2_m: 0.3980 - val_loss: 0.6013 - val_acc: 0.8887 - val_recall_m: 0.5030 - val_precision_m: 0.2734 - val_f1_m: 0.3425 - val_f2_m: 0.4156
# Epoch 93/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5401 - acc: 0.8741 - recall_m: 0.5972 - precision_m: 0.2749 - f1_m: 0.3507 - f2_m: 0.4520 - val_loss: 0.5968 - val_acc: 0.8868 - val_recall_m: 0.5030 - val_precision_m: 0.2688 - val_f1_m: 0.3382 - val_f2_m: 0.4127
# Epoch 94/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6340 - acc: 0.8778 - recall_m: 0.5092 - precision_m: 0.2674 - f1_m: 0.3220 - f2_m: 0.3987 - val_loss: 0.5984 - val_acc: 0.8906 - val_recall_m: 0.5030 - val_precision_m: 0.2734 - val_f1_m: 0.3425 - val_f2_m: 0.4156
# Epoch 95/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5499 - acc: 0.8849 - recall_m: 0.5717 - precision_m: 0.2923 - f1_m: 0.3599 - f2_m: 0.4487 - val_loss: 0.5969 - val_acc: 0.8887 - val_recall_m: 0.5030 - val_precision_m: 0.2734 - val_f1_m: 0.3425 - val_f2_m: 0.4156
# Epoch 96/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6139 - acc: 0.8698 - recall_m: 0.4660 - precision_m: 0.2453 - f1_m: 0.2924 - f2_m: 0.3608 - val_loss: 0.5939 - val_acc: 0.8868 - val_recall_m: 0.5030 - val_precision_m: 0.2688 - val_f1_m: 0.3382 - val_f2_m: 0.4127
# Epoch 97/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5777 - acc: 0.8792 - recall_m: 0.4764 - precision_m: 0.2745 - f1_m: 0.3193 - f2_m: 0.3840 - val_loss: 0.5974 - val_acc: 0.8849 - val_recall_m: 0.4879 - val_precision_m: 0.2590 - val_f1_m: 0.3271 - val_f2_m: 0.4000
# Epoch 98/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.
300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5697 - acc: 0.8745 - recall_m: 0.5358 - precision_m: 0.2551 - f1_m: 0.3254 - f2_m: 0.4134 - val_loss: 0.5963 - val_acc: 0.8849 - val_recall_m: 0.5030 - val_precision_m: 0.2658 - val_f1_m: 0.3357 - val_f2_m: 0.4112
# Epoch 133/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5669 - acc: 0.8726 - recall_m: 0.5528 - precision_m: 0.2606 - f1_m: 0.3289 - f2_m: 0.4193 - val_loss: 0.5963 - val_acc: 0.8849 - val_recall_m: 0.5030 - val_precision_m: 0.2658 - val_f1_m: 0.3357 - val_f2_m: 0.4112
# Epoch 134/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5104 - acc: 0.8745 - recall_m: 0.5815 - precision_m: 0.2671 - f1_m: 0.3403 - f2_m: 0.4384 - val_loss: 0.5980 - val_acc: 0.8849 - val_recall_m: 0.5030 - val_precision_m: 0.2658 - val_f1_m: 0.3357 - val_f2_m: 0.4112
# Epoch 135/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5633 - acc: 0.8684 - recall_m: 0.4553 - precision_m: 0.2293 - f1_m: 0.2832 - f2_m: 0.3512 - val_loss: 0.5966 - val_acc: 0.8849 - val_recall_m: 0.5030 - val_precision_m: 0.2658 - val_f1_m: 0.3357 - val_f2_m: 0.4112
# Epoch 136/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5558 - acc: 0.8689 - recall_m: 0.4632 - precision_m: 0.2327 - f1_m: 0.2914 - f2_m: 0.3628 - val_loss: 0.5965 - val_acc: 0.8849 - val_recall_m: 0.5030 - val_precision_m: 0.2658 - val_f1_m: 0.3357 - val_f2_m: 0.4112
# Epoch 137/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5567 - acc: 0.8722 - recall_m: 0.5802 - precision_m: 0.2857 - f1_m: 0.3523 - f2_m: 0.4431 - val_loss: 0.5943 - val_acc: 0.8849 - val_recall_m: 0.5030 - val_precision_m: 0.2658 - val_f1_m: 0.3357 - val_f2_m: 0.4112
# Epoch 138/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5356 - acc: 0.8783 - recall_m: 0.6113 - precision_m: 0.2709 - f1_m: 0.3512 - f2_m: 0.4556 - val_loss: 0.5957 - val_acc: 0.8830 - val_recall_m: 0.4879 - val_precision_m: 0.2545 - val_f1_m: 0.3227 - val_f2_m: 0.3971
# Epoch 139/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5384 - acc: 0.8745 - recall_m: 0.5585 - precision_m: 0.2470 - f1_m: 0.3242 - f2_m: 0.4196 - val_loss: 0.5971 - val_acc: 0.8849 - val_recall_m: 0.5030 - val_precision_m: 0.2658 - val_f1_m: 0.3357 - val_f2_m: 0.4112
# Epoch 140/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5472 - acc: 0.8755 - recall_m: 0.5719 - precision_m: 0.2414 - f1_m: 0.3194 - f2_m: 0.4218 - val_loss: 0.5968 - val_acc: 0.8830 - val_recall_m: 0.4879 - val_precision_m: 0.2545 - val_f1_m: 0.3227 - val_f2_m: 0.3971
# Epoch 141/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5594 - acc: 0.8665 - recall_m: 0.5943 - precision_m: 0.2496 - f1_m: 0.3316 - f2_m: 0.4368 - val_loss: 0.5968 - val_acc: 0.8849 - val_recall_m: 0.5030 - val_precision_m: 0.2658 - val_f1_m: 0.3357 - val_f2_m: 0.4112
# Epoch 142/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5222 - acc: 0.8722 - recall_m: 0.5726 - precision_m: 0.2382 - f1_m: 0.3231 - f2_m: 0.4267 - val_loss: 0.5961 - val_acc: 0.8849 - val_recall_m: 0.5030 - val_precision_m: 0.2658 - val_f1_m: 0.3357 - val_f2_m: 0.4112
# Epoch 143/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.6199 - acc: 0.8722 - recall_m: 0.4604 - precision_m: 0.2251 - f1_m: 0.2859 - f2_m: 0.3589 - val_loss: 0.5957 - val_acc: 0.8849 - val_recall_m: 0.5030 - val_precision_m: 0.2658 - val_f1_m: 0.3357 - val_f2_m: 0.4112
# Epoch 144/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5448 - acc: 0.8792 - recall_m: 0.5085 - precision_m: 0.2729 - f1_m: 0.3266 - f2_m: 0.4008 - val_loss: 0.5982 - val_acc: 0.8849 - val_recall_m: 0.5030 - val_precision_m: 0.2658 - val_f1_m: 0.3357 - val_f2_m: 0.4112
# Epoch 145/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5654 - acc: 0.8788 - recall_m: 0.5321 - precision_m: 0.2618 - f1_m: 0.3269 - f2_m: 0.4115 - val_loss: 0.5966 - val_acc: 0.8868 - val_recall_m: 0.5030 - val_precision_m: 0.2688 - val_f1_m: 0.3382 - val_f2_m: 0.4127
# Epoch 146/300
# 2120/2120 [==============================] - 55s 26ms/step - loss: 0.5687 - acc: 0.8759 - recall_m: 0.4689 - precision_m: 0.2462 - f1_m: 0.2967 - f2_m: 0.3675 - val_loss: 0.5950 - val_acc: 0.8849 - val_recall_m: 0.5030 - val_precision_m: 0.2658 - val_f1_m: 0.3357 - val_f2_m: 0.4112
# Epoch 00146: early stopping

# %%
model.load_weights(f"/content/gdrive/My Drive/CNN_LSTM_{I}_adj_watermask.hdf5")
preds = model.predict([x_val_0, x_val_1, x_val_2, num_val_0, num_val_1, num_val_2, adj_val_0, adj_val_1, adj_val_2])
